# %% [markdown]
# # tushare 财务数据
# ## 利润表
# ## 资产负债表

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.income(ts_code='600031.SH', start_date='20160101', end_date='20200531',
               fields='ts_code, ann_date, end_date, n_income_attr_p, update_flag')
df[df['end_date'].isin(['20161231', '20171231', '20181231', '20191231'])]
# Out:
#       ts_code  ann_date  end_date  n_income_attr_p update_flag
# 1   600031.SH  20200424  20191231     1.120666e+10           1
# 2   600031.SH  20200424  20191231     1.120666e+10           0
# 9   600031.SH  20190401  20181231     6.116288e+09           1
# 13  600031.SH  20180417  20171231     2.092253e+09           1
# 17  600031.SH  20170428  20161231     2.034570e+08           0

# %%
len(df[df['end_date'].isin(['20161231', '20171231', '20181231', '20191231'])].index)
# Out:
# 5

# %%
df
# Out:
#       ts_code  ann_date  end_date  n_income_attr_p update_flag
# 0   600031.SH  20200429  20200331     2.193674e+09           1
# 1   600031.SH  20200424  20191231     1.120666e+10           1
# 2   600031.SH  20200424  20191231     1.120666e+10           0
# 3   600031.SH  20191031  20190930     9.159443e+09           1
# 4   600031.SH  20191031  20190930     9.159443e+06           0
# 5   600031.SH  20190830  20190630     6.748013e+09           1
# 6   600031.SH  20190830  20190630     6.748013e+09           0
# 7   600031.SH  20190429  20190331     3.221072e+09           1
# 8   600031.SH  20190429  20190331     3.221072e+09           0
# 9   600031.SH  20190401  20181231     6.116288e+09           1
# 10  600031.SH  20181030  20180930     4.883396e+09           1
# 11  600031.SH  20180827  20180630     3.388559e+09           1
# 12  600031.SH  20180426  20180331     1.500185e+09           1
# 13  600031.SH  20180417  20171231     2.092253e+09           1
# ...

# %%
len(df)
# Out:
# 22

# %%
len(df.index)
# Out:
# 22

# %%
df = pro.income(ts_code='600031.SH', period='20191231',
               fields='ts_code, ann_date, end_date, n_income_attr_p, update_flag')

# %%
df
# Out:
#      ts_code  ann_date  end_date  n_income_attr_p update_flag
# 0  600031.SH  20200424  20191231     1.120666e+10           0
# 1  600031.SH  20200424  20191231     1.120666e+10           1

# %%
df = pro.income(ts_code='600031.SH', start_date='20160101', end_date='20200531',
               fields='ts_code, ann_date, end_date, n_income_attr_p, update_flag')
df1 = df[df['end_date'].isin(['20161231', '20171231', '20181231', '20191231'])]
df1
# Out:
#       ts_code  ann_date  end_date  n_income_attr_p update_flag
# 1   600031.SH  20200424  20191231     1.120666e+10           1
# 2   600031.SH  20200424  20191231     1.120666e+10           0
# 9   600031.SH  20190401  20181231     6.116288e+09           1
# 13  600031.SH  20180417  20171231     2.092253e+09           1
# 17  600031.SH  20170428  20161231     2.034570e+08           0

# %%
df1.shape
# Out:
# (5, 5)

# %%
df1.index
# Out:
# Int64Index([1, 2, 9, 13, 17], dtype='int64')

# %%
df1[3:4]
# Out:
#       ts_code  ann_date  end_date  n_income_attr_p update_flag
# 13  600031.SH  20180417  20171231     2.092253e+09           1

# %%
len(df1)
# Out:
# 5

# %%
len(df1.index)
# Out:
# 5

# %%
timeit len(df1.index)
# Out:
# 690 ns ± 71.8 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
timeit len(df1)
# Out:
# 977 ns ± 66.2 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
timeit df1.shape
# Out:
# 1.96 µs ± 607 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
df1
# Out:
#       ts_code  ann_date  end_date  n_income_attr_p update_flag
# 1   600031.SH  20200424  20191231     1.120666e+10           1
# 2   600031.SH  20200424  20191231     1.120666e+10           0
# 9   600031.SH  20190401  20181231     6.116288e+09           1
# 13  600031.SH  20180417  20171231     2.092253e+09           1
# 17  600031.SH  20170428  20161231     2.034570e+08           0

# %%
df1.drop_duplicates(subset=['end_date'])
# Out:
#       ts_code  ann_date  end_date  n_income_attr_p update_flag
# 1   600031.SH  20200424  20191231     1.120666e+10           1
# 9   600031.SH  20190401  20181231     6.116288e+09           1
# 13  600031.SH  20180417  20171231     2.092253e+09           1
# 17  600031.SH  20170428  20161231     2.034570e+08           0

# %%
# df2 为去重后的数据
df2 = df1.drop_duplicates(subset=['end_date'])
df2
# Out:
#       ts_code  ann_date  end_date  n_income_attr_p update_flag
# 1   600031.SH  20200424  20191231     1.120666e+10           1
# 9   600031.SH  20190401  20181231     6.116288e+09           1
# 13  600031.SH  20180417  20171231     2.092253e+09           1
# 17  600031.SH  20170428  20161231     2.034570e+08           0

# %%
df2.n_income_attr_p.idxmin()
# Out:
# 17

# %%
df2.n_income_attr_p[17] > 0
# Out:
# True

# %% [markdown]
# ## 资产负债表

# %%
pro.balancesheet(ts_code='600031.SH', period='20191231',
                     fields='ts_code, end_date, report_type, comp_type, total_share, cap_rese, undistr_porfit')
# Out:
#      ts_code  end_date report_type comp_type   total_share      cap_rese  \
# 0  600031.SH  20191231           1         1  8.426246e+09  5.948317e+09
# 1  600031.SH  20191231           1         1  8.426246e+09  5.948317e+09
#
#    undistr_porfit
# 0    2.895223e+10
# 1    2.895223e+10

# %%
pro.balancesheet(ts_code='600031.SH', period='20191231',
                     fields='ts_code, end_date, surplus_rese, special_rese, money_cap, trad_asset, notes_receiv')
# Out:
#      ts_code  end_date  surplus_rese special_rese     money_cap    trad_asset  \
# 0  600031.SH  20191231  3.225142e+09         None  1.352674e+10  8.367396e+09
# 1  600031.SH  20191231  3.225142e+09         None  1.352674e+10  8.367396e+09
#
#   notes_receiv
# 0         None
# 1         None

# %%
pro.balancesheet(ts_code='600031.SH', period='20191231',
                     fields='ts_code, ann_date, end_date, accounts_receiv, oth_receiv, prepayment, update_flag')
# Out:
#      ts_code  ann_date  end_date  accounts_receiv    oth_receiv   prepayment  \
# 0  600031.SH  20200424  20191231     2.179289e+10           NaN  633585000.0
# 1  600031.SH  20200424  20191231     2.179289e+10  2.786500e+09  633585000.0
#
#   update_flag
# 0           0
# 1           1

# %%
df = pro.balancesheet(ts_code='600031.SH', period='20191231',
                     fields='ts_code, ann_date, end_date, accounts_receiv, oth_receiv, prepayment, update_flag')
df.drop_duplicates(subset=['end_date'])
# Out:
#      ts_code  ann_date  end_date  accounts_receiv  oth_receiv   prepayment  \
# 0  600031.SH  20200424  20191231     2.179289e+10         NaN  633585000.0
#
#   update_flag
# 0           0

# %%
df.drop_duplicates(subset=['end_date'], keep='last')
# Out:
#      ts_code  ann_date  end_date  accounts_receiv    oth_receiv   prepayment  \
# 1  600031.SH  20200424  20191231     2.179289e+10  2.786500e+09  633585000.0
#
#   update_flag
# 1           1

# %%
df = pro.balancesheet(ts_code='600031.SH', period='20191231',
                     fields='ts_code, ann_date, end_date, accounts_receiv, oth_receiv, prepayment, update_flag')

# %%
df
# Out:
#      ts_code  ann_date  end_date  accounts_receiv    oth_receiv   prepayment  \
# 0  600031.SH  20200424  20191231     2.179289e+10           NaN  633585000.0
# 1  600031.SH  20200424  20191231     2.179289e+10  2.786500e+09  633585000.0
#
#   update_flag
# 0           0
# 1           1

# %%
df2 = pro.income(ts_code='600031.SH', start_date='20160101', end_date='20200531', 
                       fields='ts_code, ann_date, end_date, n_income_attr_p, update_flag')
df_year = df2[df2['end_date'].isin(['20161231', '20171231', '20181231', '20191231'])]
df_year
# Out:
#       ts_code  ann_date  end_date  n_income_attr_p update_flag
# 1   600031.SH  20200424  20191231     1.120666e+10           1
# 2   600031.SH  20200424  20191231     1.120666e+10           0
# 9   600031.SH  20190401  20181231     6.116288e+09           1
# 13  600031.SH  20180417  20171231     2.092253e+09           1
# 17  600031.SH  20170428  20161231     2.034570e+08           0

# %%
df[df.update_flag.eq('1')]
# Out:
#      ts_code  ann_date  end_date  accounts_receiv    oth_receiv   prepayment  \
# 1  600031.SH  20200424  20191231     2.179289e+10  2.786500e+09  633585000.0
#
#   update_flag
# 1           1

# %%
df.duplicated(subset=['end_date'])
# Out:
# 0    False
# 1     True
# dtype: bool

# %%
df[df.duplicated(subset=['end_date'])]
# Out:
#      ts_code  ann_date  end_date  accounts_receiv    oth_receiv   prepayment  \
# 1  600031.SH  20200424  20191231     2.179289e+10  2.786500e+09  633585000.0
#
#   update_flag
# 1           1

# %%
df_year
# Out:
#       ts_code  ann_date  end_date  n_income_attr_p update_flag
# 1   600031.SH  20200424  20191231     1.120666e+10           1
# 2   600031.SH  20200424  20191231     1.120666e+10           0
# 9   600031.SH  20190401  20181231     6.116288e+09           1
# 13  600031.SH  20180417  20171231     2.092253e+09           1
# 17  600031.SH  20170428  20161231     2.034570e+08           0

# %%
df_year[df_year.duplicated(subset=['end_date'])]
# Out:
#      ts_code  ann_date  end_date  n_income_attr_p update_flag
# 2  600031.SH  20200424  20191231     1.120666e+10           0

# %%
df
# Out:
#      ts_code  ann_date  end_date  accounts_receiv    oth_receiv   prepayment  \
# 0  600031.SH  20200424  20191231     2.179289e+10           NaN  633585000.0
# 1  600031.SH  20200424  20191231     2.179289e+10  2.786500e+09  633585000.0
#
#   update_flag
# 0           0
# 1           1

# %%
df[df.duplicated(subset=['end_date'])]
# Out:
#      ts_code  ann_date  end_date  accounts_receiv    oth_receiv   prepayment  \
# 1  600031.SH  20200424  20191231     2.179289e+10  2.786500e+09  633585000.0
#
#   update_flag
# 1           1

# %%
df[df.duplicated(subset=['end_date']) & df.update_flag.eq('0')]
# Out:
# Empty DataFrame
# Columns: [ts_code, ann_date, end_date, accounts_receiv, oth_receiv, prepayment, update_flag]
# Index: []

# %%
df[df.duplicated(subset=['end_date'], keep=False) & df.update_flag.eq('0')]
# Out:
#      ts_code  ann_date  end_date  accounts_receiv  oth_receiv   prepayment  \
# 0  600031.SH  20200424  20191231     2.179289e+10         NaN  633585000.0
#
#   update_flag
# 0           0

# %%
df.sort_values(['end_date', 'update_flag']).drop_duplicates(subset=['end_date'], keep='last')
# Out:
#      ts_code  ann_date  end_date  accounts_receiv    oth_receiv   prepayment  \
# 1  600031.SH  20200424  20191231     2.179289e+10  2.786500e+09  633585000.0
#
#   update_flag
# 1           1

# %%
df_year
# Out:
#       ts_code  ann_date  end_date  n_income_attr_p update_flag
# 1   600031.SH  20200424  20191231     1.120666e+10           1
# 2   600031.SH  20200424  20191231     1.120666e+10           0
# 9   600031.SH  20190401  20181231     6.116288e+09           1
# 13  600031.SH  20180417  20171231     2.092253e+09           1
# 17  600031.SH  20170428  20161231     2.034570e+08           0

# %%
df_year.sort_values(['end_date', 'update_flag'])
# Out:
#       ts_code  ann_date  end_date  n_income_attr_p update_flag
# 17  600031.SH  20170428  20161231     2.034570e+08           0
# 13  600031.SH  20180417  20171231     2.092253e+09           1
# 9   600031.SH  20190401  20181231     6.116288e+09           1
# 2   600031.SH  20200424  20191231     1.120666e+10           0
# 1   600031.SH  20200424  20191231     1.120666e+10           1

# %%
df_year.sort_values(['end_date', 'update_flag'], ascending=[False, False])
# Out:
#       ts_code  ann_date  end_date  n_income_attr_p update_flag
# 1   600031.SH  20200424  20191231     1.120666e+10           1
# 2   600031.SH  20200424  20191231     1.120666e+10           0
# 9   600031.SH  20190401  20181231     6.116288e+09           1
# 13  600031.SH  20180417  20171231     2.092253e+09           1
# 17  600031.SH  20170428  20161231     2.034570e+08           0

# %%
df.sort_values(['end_date', 'update_flag'], ascending=[False, False])
# Out:
#      ts_code  ann_date  end_date  accounts_receiv    oth_receiv   prepayment  \
# 1  600031.SH  20200424  20191231     2.179289e+10  2.786500e+09  633585000.0
# 0  600031.SH  20200424  20191231     2.179289e+10           NaN  633585000.0
#
#   update_flag
# 1           1
# 0           0

# %%
df.sort_values(by=['end_date', 'update_flag'], ascending=[False, False]).drop_duplicates(subset=['end_date'])
# Out:
#      ts_code  ann_date  end_date  accounts_receiv    oth_receiv   prepayment  \
# 1  600031.SH  20200424  20191231     2.179289e+10  2.786500e+09  633585000.0
#
#   update_flag
# 1           1

# %% [markdown]
# pandas DataFrame 按多列排序并删除重复的行

# %%
df_year.sort_values(by=['end_date', 'update_flag'], ascending=[False, False]).drop_duplicates(subset=['end_date'])
# Out:
#       ts_code  ann_date  end_date  n_income_attr_p update_flag
# 1   600031.SH  20200424  20191231     1.120666e+10           1
# 9   600031.SH  20190401  20181231     6.116288e+09           1
# 13  600031.SH  20180417  20171231     2.092253e+09           1
# 17  600031.SH  20170428  20161231     2.034570e+08           0

# %% [markdown]
# ## 根据最近4年的盈利情况过滤股票
# 最近4个会计年度如果有净利润为负的情况，则从股票池中剔除

# %%
df_income = pro.income(ts_code='600031.SH', start_date='20160101', end_date='20200531', 
                       fields='ts_code, ann_date, end_date, n_income_attr_p, update_flag')
df_income_year = df_income[df_income['end_date'].isin(['20161231', '20171231', '20181231', '20191231'])]
df_sort = df_income_year.sort_values(by=['end_date', 'update_flag'], ascending=[False, False]).drop_duplicates(subset=['end_date'])
df_index = df_sort.n_income_attr_p.idxmin()
df_min = df_sort.n_income_attr_p[df_index]
df_min > 0
# Out:
# True

# %%
df_min
# Out:
# 203457000.0

# %%
c1 = df_min > 0

# %%
c1
# Out:
# True

# %%
if c1:
    print('最小值大于0')
# Out:
# 最小值大于0

# %%
pro.daily_basic(ts_code='002607.SZ', trade_date='20200601', fields='ts_code, trade_date, close, pb, pe_ttm')
# Out:
#      ts_code trade_date  close    pe_ttm        pb
# 0  002607.SZ   20200601  29.67  100.8381  304.4968

# %%
pro.daily_basic(ts_code='600745.SH', trade_date='20200601', fields='ts_code, trade_date, close, pb, pe_ttm')
# Out:
#      ts_code trade_date  close   pe_ttm      pb
# 0  600745.SH   20200601  103.0  62.7145  5.3428

# %%
df_fina = pro.fina_indicator(ts_code='600031.SH', start_date='20160101', end_date='20200531',
                            fields='ts_code, ann_date, end_date, netprofit_yoy, update_flag')
df_fina_year = df_fina[df_fina['end_date'].isin(['20161231', '20171231', '20181231', '20191231'])]
if len(df_fina_year.index) != 4:
    df_fina_year = df_fina_year.sort_values(by=['end_date', 'update_flag'], ascending=[False, False]).drop_duplicates(subset=['end_date'])
df_fina_year
# Out:
#       ts_code  ann_date  end_date  netprofit_yoy update_flag
# 1   600031.SH  20200424  20191231        83.2265           1
# 5   600031.SH  20190401  20181231       192.3302           1
# 9   600031.SH  20180417  20171231       928.3514           1
# 13  600031.SH  20170428  20161231      4001.1288           1

# %%
df_fina = pro.fina_indicator(ts_code='002509.SZ', start_date='20160101', end_date='20200531',
                            fields='ts_code, ann_date, end_date, netprofit_yoy, update_flag')
df_fina_year = df_fina[df_fina['end_date'].isin(['20161231', '20171231', '20181231', '20191231'])]
if len(df_fina_year.index) != 4:
    df_fina_year = df_fina_year.sort_values(by=['end_date', 'update_flag'], ascending=[False, False]).drop_duplicates(subset=['end_date'])
df_fina_year
# Out:
#       ts_code  ann_date  end_date  netprofit_yoy update_flag
# 4   002509.SZ  20190430  20181231      -177.1249           1
# 8   002509.SZ  20180424  20171231        39.0436           1
# 12  002509.SZ  20170425  20161231       294.4578           1

# %%
df_fina = pro.fina_indicator(ts_code='603323.SH', start_date='20160101', end_date='20200531',
                                fields='ts_code, ann_date, end_date, netprofit_yoy, update_flag')
df_fina_year = df_fina[df_fina['end_date'].isin(['20161231', '20171231', '20181231', '20191231'])]
df_fina_year
# Out:
#       ts_code  ann_date  end_date  netprofit_yoy update_flag
# 4   603323.SH  20190426  20181231         9.7194           1
# 8   603323.SH  20180426  20171231        12.4291           1
# 12  603323.SH  20170428  20161231         7.5841           1

# %%
pro.fina_indicator(ts_code='603323.SH', start_date='20160101', end_date='20200531',
                                fields='ts_code, ann_date, end_date, netprofit_yoy, update_flag')
# Out:
#       ts_code  ann_date  end_date  netprofit_yoy update_flag
# 0   603323.SH  20200424  20200331        10.9587           1
# 1   603323.SH  20191030  20190930        15.1150           1
# 2   603323.SH  20190823  20190630        14.7867           1
# 3   603323.SH  20190426  20190331        12.0064           1
# 4   603323.SH  20190426  20181231         9.7194           1
# 5   603323.SH  20181031  20180930        16.2474           1
# 6   603323.SH  20180830  20180630        15.4090           1
# 7   603323.SH  20180426  20180331        14.6313           1
# 8   603323.SH  20180426  20171231        12.4291           1
# 9   603323.SH  20171025  20170930         9.9497           1
# 10  603323.SH  20170825  20170630        11.7986           1
# 11  603323.SH  20170428  20170331         9.8236           1
# 12  603323.SH  20170428  20161231         7.5841           1
# 13  603323.SH  20161128  20160930         5.0593           1
# ...

# %%
CSV_FILE = 'C:\\Users\\YWH\\Downloads\\20200603stockdaily.csv'
import pandas as pd
df = pd.read_csv(CSV_FILE)
df
# Out:
#       Unnamed: 0    ts_code  trade_date   close   pe_ttm      pb    zf2016  \
# 0              0  000001.SZ    20200603   13.54   8.9687  0.9446    3.3570
# 1              0  000002.SZ    20200603   26.84   7.7780  1.6079   16.0226
# 2              0  000005.SZ    20200603    2.64  16.2993  1.8215  296.7029
# 3              0  000006.SZ    20200603    5.14   8.4804  1.0110   86.8208
# 4              0  000008.SZ    20200603    3.02  26.7087  1.1470  181.0696
# ...          ...        ...         ...     ...      ...     ...       ...
# 2180           0  603998.SH    20200603    6.55  38.0470  2.4823  -23.0719
# 2181           0  603999.SH    20200603    5.80  51.0773  1.9665  -17.0419
# 2182           0  605001.SH    20200603   22.33  28.7240  2.4828       NaN
# 191     38  000069.SZ    20200603    6.03    4.1285    0.7308   48.4360
# 192     92  000537.SZ    20200603    6.75    4.0506    0.8827  142.5437
# 193    410  002146.SZ    20200603    8.12    3.8292    0.8477   72.0668
#
#        zf2017    zf2018   zf2019       ROE
# 0    145.6105   83.5044  39.8331  0.142495
# ...

# %%
df3.drop(labels='Unnamed: 0', axis=1).reset_index(drop=True)
# Out:
#        ts_code  trade_date   close    pe_ttm        pb    zf2016    zf2017  \
# 0    603290.SH    20200603  147.34  164.5607   23.4490   66.1949  145.6105
# 1    600763.SH    20200603  142.09  130.2374   25.7955    9.4406   59.0535
# 2    603039.SH    20200603   63.27   96.4215   14.9255   29.4138   33.3508
# 3    002607.SZ    20200603   28.27   96.0800  290.1289  336.3441   11.5059
# 4    601888.SH    20200603  102.18   90.5568   10.0496   20.0742   39.9611
# ..         ...         ...     ...       ...       ...       ...       ...
# 189  600466.SH    20200603    5.25    4.5528    0.9971   11.2758   52.4884
# 190  601997.SH    20200603    7.79    4.1764    0.7023   13.4245   23.9814
# 191  000069.SZ    20200603    6.03    4.1285    0.7308   48.4360   25.4750
# 192  000537.SZ    20200603    6.75    4.0506    0.8827  142.5437  275.5364
# 193  002146.SZ    20200603    8.12    3.8292    0.8477   72.0668   38.8775
#
#        zf2018   zf2019       ROE
# 0     83.5044  39.8331  0.142495
# ...

# %%
for ts_code in ts_codes:
        df_price = pro.daily_basic(ts_code=ts_code, start_date='20200101', end_date=today,
                                   fields='ts_code, trade_date, close')
        df_price_index = df_price.close.idxmax()
        df_price_max = df_price.close[df_price_index]
        max_price.append(df_price_max)
        sleep(0.3)
    df_max = DataFrame({'max_price': max_price})
    df2['max_price'] = df_max['max_price']
    df2.drop(labels='Unnamed: 0', axis=1).reset_index(drop=True)
    df2.to_csv(stockfinal)

# %%
df_price = pro.daily_basic(ts_code='600745.SH', start_date='20200101', end_date='20200604',
                                   fields='ts_code, trade_date, close')

# %%
df_price
# Out:
#       ts_code trade_date   close
# 0   600745.SH   20200604  106.51
# 1   600745.SH   20200603  106.67
# 2   600745.SH   20200602  103.15
# 3   600745.SH   20200601  103.00
# 4   600745.SH   20200529   97.78
# ..        ...        ...     ...
# 86  600745.SH   20200108   90.68
# 87  600745.SH   20200107   91.95
# 88  600745.SH   20200106   92.26
# 89  600745.SH   20200103   92.58
# 90  600745.SH   20200102   96.23
#
# [91 rows x 3 columns]

# %%
df_price_index = df_price.close.idxmax()
df_price_index
# Out:
# 58

# %%
df_price_max = df_price.close[df_price_index]
df_price_max
# Out:
# 166.33

# %%
df_price.trade_date[58]
# Out:
# '20200225'

# %%
max_price = []
max_price.append(df_price_max)
max_price
# Out:
# [166.33]

# %%
    max_price = []
    for ts_code in ts_codes:
        df_price = pro.daily_basic(ts_code=ts_code, start_date='20200101', end_date=today,
                                   fields='ts_code, trade_date, close')
        df_price_index = df_price.close.idxmax()
        df_price_max = df_price.close[df_price_index]
        max_price.append(df_price_max)
        sleep(0.3)
    df_max = DataFrame({'max_price': max_price})
    df2['max_price'] = df_max['max_price']
    df2.drop(labels='Unnamed: 0', axis=1).reset_index(drop=True)
    df2.to_csv(stockfinal)

# %%
from pandas.core.frame import DataFrame
DataFrame(max_price)
# Out:
#         0
# 0  166.33

# %%
DataFrame({'max_price': max_price})
# Out:
#    max_price
# 0     166.33

# %%
max_price.append(180)
max_price
# Out:
# [166.33, '180', 180]

# %%
max_price
# Out:
# [166.33, '180', 180]

# %%
max_price.remove('180')

# %%
max_price
# Out:
# [166.33, 180]

# %%
df = DataFrame({'max_price': max_price})
df
# Out:
#    max_price
# 0     166.33
# 1     180.00

# %%
df2['max_price'] = df['max_price']
# Out:
# d:\program files\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
zm = ['a', 'b']
df3 = DataFrame({'zmb': zm})
df3
# Out:
#   zmb
# 0   a
# 1   b

# %%
df3['jiage'] = df['max_price']

# %%
df3
# Out:
#   zmb   jiage
# 0   a  166.33
# 1   b  180.00

# %%
df2
# Out:
#       Unnamed: 0    ts_code  trade_date   close   pe_ttm       pb    zf2016  \
# 1              0  000002.SZ    20200603   26.84   7.7780   1.6079   16.0226
# 27             0  000049.SZ    20200603   47.12  20.2749   4.3406   10.8929
# 38             0  000069.SZ    20200603    6.03   4.1285   0.7308   48.4360
# 43             0  000090.SZ    20200603    6.44   5.5836   1.2334   13.6952
# 53             0  000333.SZ    20200603   58.33  17.8341   4.3034   15.5637
# ...          ...        ...         ...     ...      ...      ...       ...
# 2136           0  603915.SH    20200603   13.34  23.1775   2.7085   27.5798
# 2143           0  603927.SH    20200603   58.73  71.5177  12.6753   17.4423
# 2150           0  603939.SH    20200603   77.23  69.7440   8.9067   27.2571
# 2156           0  603960.SH    20200603   24.01  56.3446   9.7650   16.8850
# 2183           0  605168.SH    20200603  127.80  40.3479   6.2820  196.3608
#
#        zf2017   zf2018   zf2019       ROE  max_price
# ...

# %%
   for ts_code in ts_codes:
        df_price = pro.daily_basic(ts_code=ts_code, start_date='20200101', end_date=today,
                                   fields='ts_code, trade_date, close')
        df_price_index = df_price.close.idxmax()  # 最高收盘价所在行的索引
        df_price_max = df_price.close[df_price_index]  # 最高收盘价所在行
        if exists(stockprice):
            data = df_price_max.to_csv(stockprice, mode='a', header=None)
        else:
            data = df_price_max.to_csv(stockprice)
        sleep(0.3)

# %%
df_price = pro.daily_basic(ts_code='600745.SH', start_date='20200101', end_date='20200604',
                                   fields='ts_code, trade_date, close')
df_price
# Out:
#       ts_code trade_date   close
# 0   600745.SH   20200604  106.51
# 1   600745.SH   20200603  106.67
# 2   600745.SH   20200602  103.15
# 3   600745.SH   20200601  103.00
# 4   600745.SH   20200529   97.78
# ..        ...        ...     ...
# 86  600745.SH   20200108   90.68
# 87  600745.SH   20200107   91.95
# 88  600745.SH   20200106   92.26
# 89  600745.SH   20200103   92.58
# 90  600745.SH   20200102   96.23
#
# [91 rows x 3 columns]

# %%
df_price_index = df_price.close.idxmax()
df_price_index
# Out:
# 58

# %%
df_price_max = df_price.close[df_price_index]
df_price_max
# Out:
# 166.33

# %%
df_price[df_price_index:df_price_index + 1]
# Out:
#       ts_code trade_date   close
# 58  600745.SH   20200225  166.33

# %%
import pandas as pd
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_lib',
# ...

# %%
dir(pd.Series)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %%
dir(pd.core)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'accessor',
#  'algorithms',
#  'api',
#  'arrays',
#  'base',
#  'common',
#  'computation',
#  'config_init',
#  'dtypes',
#  'frame',
#  'generic',
#  'groupby',
#  'index',
#  'indexers',
#  'indexes',
#  'indexing',
#  'internals',
#  'missing',
#  'nanops',
#  'ops',
#  'reshape',
#  'series',
#  'sorting',
#  'sparse',
#  'strings',
#  'tools',
#  'util',
#  'window']

# %%
dir(pd.core.frame)
# Out:
# ['ABCDataFrame',
#  'ABCIndexClass',
#  'ABCMultiIndex',
#  'ABCSeries',
#  'Appender',
#  'BlockManager',
#  'CachedAccessor',
#  'Categorical',
#  'DataFrame',
#  'DatetimeIndex',
#  'DatetimeLikeArray',
#  'ExtensionArray',
#  'FrozenSet',
#  'Index',
#  'List',
#  'MultiIndex',
#  'NDFrame',
#  'Optional',
#  'OrderedDict',
#  'PY36',
#  'PeriodIndex',
#  'Series',
#  'Set',
#  'SparseFrameAccessor',
#  'StringIO',
#  'Substitution',
#  'Tuple',
#  'Type',
#  'Union',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_from_nested_dict',
#  '_merge_doc',
#  '_numeric_only_doc',
#  '_put_str',
#  '_shared_doc_kwargs',
#  '_shared_docs',
#  'abc',
#  'algorithms',
#  'arrays_to_mgr',
#  'cast_scalar_to_array',
#  'check_bool_indexer',
#  'coerce_to_dtypes',
#  'collections',
#  'com',
#  'console',
#  'convert_to_index_sliceable',
#  'dedent',
#  'deprecate_kwarg',
#  'dispatch_fill_zeros',
# ...

# %%
dir(pd.core.series)
# Out:
# ['ABCDataFrame',
#  'ABCDatetimeArray',
#  'ABCDatetimeIndex',
#  'ABCSeries',
#  'ABCSparseArray',
#  'ABCSparseSeries',
#  'Any',
#  'Appender',
#  'CachedAccessor',
#  'Callable',
#  'Categorical',
#  'CategoricalAccessor',
#  'CombinedDatetimelikeProperties',
#  'DatetimeIndex',
#  'DirNamesMixin',
#  'ExtensionArray',
#  'Float64Index',
#  'Index',
#  'InvalidIndexError',
#  'MultiIndex',
#  'OrderedDict',
#  'PY36',
#  'PeriodIndex',
#  'Series',
#  'SingleBlockManager',
#  'SparseAccessor',
#  'SparseArray',
#  'StringIO',
#  'StringMethods',
#  'Substitution',
#  'TimedeltaIndex',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_coerce_method',
#  '_is_unorderable_exception',
#  '_shared_doc_kwargs',
#  'algorithms',
#  'base',
#  'check_bool_indexer',
#  'com',
#  'dedent',
#  'deprecate',
#  'ensure_index',
#  'ensure_platform_int',
#  'fmt',
#  'generic',
#  'get_option',
# ...

# %%
dir(pd.core.series.Series)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %%
obj = pd.Series(['blue', 'purple', 'yellow'], index=[0, 2, 4])
obj
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: object

# %%
type(obj)
# Out:
# pandas.core.series.Series

# %%
obj2 = obj.reset_index(drop=True)
obj2
# Out:
# 0      blue
# 1    purple
# 2    yellow
# dtype: object

# %%
type(obj2)
# Out:
# pandas.core.series.Series
