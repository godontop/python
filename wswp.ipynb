# %% [markdown]
# # Web Scraping with Python

# %%
import re
import urllib.request
import urllib.error


def download(url, user_agent='wswp', num_retries=2):
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    try:
        html = urllib.request.urlopen(request).read()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                return download(url, user_agent, num_retries - 1)
    return html


def crawl_sitemap(url):
    # download the sitemap file
    sitemap = download(url)
    # extract the sitemap links
    links = re.findall('<loc>(.*?)</loc>', sitemap.decode())
    # download each link
    for link in links:
        html = download(link)
        # scrape html here
        # ...


crawl_sitemap('https://webscraping.com/sitemap.xml')
# Out:
# Downloading: https://webscraping.com/sitemap.xml
# Downloading: http://webscraping.com
# Downloading: http://webscraping.com/about
# Downloading: http://webscraping.com/blog
# Downloading: http://webscraping.com/blog/10/
# Downloading: http://webscraping.com/blog/11/
# Downloading: http://webscraping.com/blog/12/
# Downloading: http://webscraping.com/blog/13/
# Downloading: http://webscraping.com/blog/2/
# Downloading: http://webscraping.com/blog/3/
# Downloading: http://webscraping.com/blog/4/
# Downloading: http://webscraping.com/blog/5/
# Downloading: http://webscraping.com/blog/6/
# Downloading: http://webscraping.com/blog/7/
# Downloading: http://webscraping.com/blog/8/
# Downloading: http://webscraping.com/blog/9/
# Downloading: http://webscraping.com/blog/All-your-data-are-belong-to-us/
# Downloading: http://webscraping.com/blog/Android-Apps-Update/
# Downloading: http://webscraping.com/blog/Apple-Apps-Update/
# Downloading: http://webscraping.com/blog/Asynchronous-support-in-Python/
# Downloading: http://webscraping.com/blog/Automatic-web-scraping/
# Downloading: http://webscraping.com/blog/Automating-CAPTCHAs/
# Downloading: http://webscraping.com/blog/Automating-webkit/
# Downloading: http://webscraping.com/blog/Best-website-for-freelancers/
# Downloading: http://webscraping.com/blog/Bitcoin/
# Downloading: http://webscraping.com/blog/Caching-crawled-webpages/
# Downloading: http://webscraping.com/blog/Caching-data-efficiently/
# Downloading: http://webscraping.com/blog/Can-you-extract-data-from-this-website/
# Downloading: http://webscraping.com/blog/Client-Feedback/
# Downloading: http://webscraping.com/blog/Converting-UK-Easting-Northing-coordinates/
# Downloading: http://webscraping.com/blog/Crawling-with-threads/
# Downloading: http://webscraping.com/blog/Discount-coupons-for-data-store/
# Downloading: http://webscraping.com/blog/Extracting-article-summaries/
# Downloading: http://webscraping.com/blog/Fixed-fee-or-hourly/
# Downloading: http://webscraping.com/blog/Free-service-to-extract-article-from-webpage/
# Downloading: http://webscraping.com/blog/Generate-website-screenshot-history/
# Downloading: http://webscraping.com/blog/Google-App-Engine-limitations/
# Downloading: http://webscraping.com/blog/Google-Storage/
# Downloading: http://webscraping.com/blog/Google-interview/
# Downloading: http://webscraping.com/blog/How-to-automatically-find-contact-details/
# Downloading: http://webscraping.com/blog/How-to-crawl-websites-without-being-blocked/
# Downloading: http://webscraping.com/blog/How-to-find-what-technology-a-website-uses/
# Downloading: http://webscraping.com/blog/How-to-make-python-faster/
# Downloading: http://webscraping.com/blog/How-to-protect-your-data/
# Downloading: http://webscraping.com/blog/How-to-scrape-Android-Apps/
# Downloading: http://webscraping.com/blog/How-to-teach-yourself-web-scraping/
# Downloading: http://webscraping.com/blog/How-to-use-XPaths-robustly/
# Downloading: http://webscraping.com/blog/How-to-use-proxies/
# Downloading: http://webscraping.com/blog/I-love-AJAX/
# Downloading: http://webscraping.com/blog/Image-efficiencies/
# Downloading: http://webscraping.com/blog/Importing-CSV-into-MySQL/
# Downloading: http://webscraping.com/blog/Increase-your-Google-App-Engine-quotas-for-free/
# Downloading: http://webscraping.com/blog/Is-Web-Scraping-Legal/
# Downloading: http://webscraping.com/blog/Loading-Cookies-from-the-Browser/
# Downloading: http://webscraping.com/blog/Luminati/
# Downloading: http://webscraping.com/blog/New-scraping-quote-tool/
# Downloading: http://webscraping.com/blog/New-store-for-buying-databases/
# Downloading: http://webscraping.com/blog/Open-sourced-web-scraping-code/
# Downloading: http://webscraping.com/blog/Parsing-Flash-with-Swiffy/
# Downloading: http://webscraping.com/blog/Parsing-HTML-with-Python/
# Downloading: http://webscraping.com/blog/Rebranding-sitescraper-as-webscraping/
# Downloading: http://webscraping.com/blog/Reverse-Geocode/
# Downloading: http://webscraping.com/blog/Scraping-Flash-based-websites/
# Downloading: http://webscraping.com/blog/Scraping-JavaScript-based-web-pages-with-Chickenfoot/
# Downloading: http://webscraping.com/blog/Scraping-JavaScript-webpages-with-webkit/
# Downloading: http://webscraping.com/blog/Scraping-dynamic-data/
# Downloading: http://webscraping.com/blog/Scraping-multiple-JavaScript-webpages-with-webkit/
# Downloading: http://webscraping.com/blog/Services/
# Downloading: http://webscraping.com/blog/Solving-CAPTCHA/
# Downloading: http://webscraping.com/blog/Startup/
# Downloading: http://webscraping.com/blog/Taking-advantage-of-mobile-interfaces/
# Downloading: http://webscraping.com/blog/The-SiteScraper-module/
# Downloading: http://webscraping.com/blog/Threading-with-webkit/
# Downloading: http://webscraping.com/blog/Typical-web-scraping-job/
# Downloading: http://webscraping.com/blog/UPC-Database-Update/
# Downloading: http://webscraping.com/blog/Useful-business-directories/
# Downloading: http://webscraping.com/blog/User-agents/
# Downloading: http://webscraping.com/blog/Using-Google-Cache-to-crawl-a-website/
# Downloading: http://webscraping.com/blog/Using-Google-Translate-to-crawl-a-website/
# Downloading: http://webscraping.com/blog/Using-the-internet-archive-to-crawl-a-website/
# Downloading: http://webscraping.com/blog/Web-Scraping-Interface/
# Downloading: http://webscraping.com/blog/Web-Scrapping/
# Downloading: http://webscraping.com/blog/Web-scraping-with-regular-expressions/
# Downloading: http://webscraping.com/blog/Webpage-screenshots-with-webkit/
# Downloading: http://webscraping.com/blog/What-is-CSV/
# Downloading: http://webscraping.com/blog/What-is-web-scraping/
# Downloading: http://webscraping.com/blog/Why-Google-App-Engine/
# Downloading: http://webscraping.com/blog/Why-Python/
# Downloading: http://webscraping.com/blog/Why-reinvent-the-wheel/
# Downloading: http://webscraping.com/blog/Why-web2py/
# Downloading: http://webscraping.com/blog/category/ajax
# Downloading: http://webscraping.com/blog/category/android/
# Downloading: http://webscraping.com/blog/category/beautifulsoup
# Downloading: http://webscraping.com/blog/category/big picture
# Downloading: http://webscraping.com/blog/category/business/
# Downloading: http://webscraping.com/blog/category/cache
# Downloading: http://webscraping.com/blog/category/captcha
# Downloading: http://webscraping.com/blog/category/chickenfoot
# Downloading: http://webscraping.com/blog/category/concurrent
# Downloading: http://webscraping.com/blog/category/cookies
# Downloading: http://webscraping.com/blog/category/crawling
# Downloading: http://webscraping.com/blog/category/database/
# Downloading: http://webscraping.com/blog/category/efficiency
# Downloading: http://webscraping.com/blog/category/elance
# Downloading: http://webscraping.com/blog/category/example
# Downloading: http://webscraping.com/blog/category/flash
# Downloading: http://webscraping.com/blog/category/freelancing
# Downloading: http://webscraping.com/blog/category/gae
# Downloading: http://webscraping.com/blog/category/google/
# Downloading: http://webscraping.com/blog/category/html
# Downloading: http://webscraping.com/blog/category/image
# Downloading: http://webscraping.com/blog/category/ip
# Downloading: http://webscraping.com/blog/category/ir
# Downloading: http://webscraping.com/blog/category/javascript
# Downloading: http://webscraping.com/blog/category/learn
# Downloading: http://webscraping.com/blog/category/linux
# Downloading: http://webscraping.com/blog/category/lxml
# Downloading: http://webscraping.com/blog/category/mobile
# Downloading: http://webscraping.com/blog/category/mobile apps/
# Downloading: http://webscraping.com/blog/category/ocr
# Downloading: http://webscraping.com/blog/category/opensource
# Downloading: http://webscraping.com/blog/category/proxies/
# Downloading: http://webscraping.com/blog/category/python
# Downloading: http://webscraping.com/blog/category/qt
# Downloading: http://webscraping.com/blog/category/regex
# Downloading: http://webscraping.com/blog/category/scrapy
# Downloading: http://webscraping.com/blog/category/screenshot
# Downloading: http://webscraping.com/blog/category/sitescraper
# Downloading: http://webscraping.com/blog/category/sqlite
# Downloading: http://webscraping.com/blog/category/user-agent
# Downloading: http://webscraping.com/blog/category/web2py
# Downloading: http://webscraping.com/blog/category/webkit
# Downloading: http://webscraping.com/blog/category/website/
# Downloading: http://webscraping.com/blog/category/xpath
# Downloading: http://webscraping.com/contact
# Downloading: http://webscraping.com/data
# Downloading: http://webscraping.com/data/default/database/1/belgium-zip-codes
# Downloading: http://webscraping.com/data/default/database/10/usa-restaurants
# Downloading: http://webscraping.com/data/default/database/11/android-apps
# Downloading: http://webscraping.com/data/default/database/12/universal-product-codes-upc-details
# Downloading: http://webscraping.com/data/default/database/13/international-standard-book-numbers-isbn
# Downloading: http://webscraping.com/data/default/database/14/hotel-details
# Downloading: http://webscraping.com/data/default/database/17/aircraft-models
# Downloading: http://webscraping.com/data/default/database/2/usa-cities
# Downloading: http://webscraping.com/data/default/database/23/films
# Downloading: http://webscraping.com/data/default/database/29/popular-websites
# Downloading: http://webscraping.com/data/default/database/3/world-cities
# Downloading: http://webscraping.com/data/default/database/31/german-businesses
# Downloading: http://webscraping.com/data/default/database/33/australian-businesses
# Downloading: http://webscraping.com/data/default/database/37/united-kingdom-postcodes
# Downloading: http://webscraping.com/data/default/database/4/united-kingdom-cities
# Downloading: http://webscraping.com/data/default/database/41/world-zip-codes
# Downloading: http://webscraping.com/data/default/database/5/famous-quotes
# Downloading: http://webscraping.com/data/default/database/52/universal-product-codes-upc-list
# Downloading: http://webscraping.com/data/default/database/53/summer-olympic-medals
# Downloading: http://webscraping.com/data/default/database/54/winter-olympic-medal-count
# Downloading: http://webscraping.com/data/default/database/55/song-lyrics
# Downloading: http://webscraping.com/data/default/database/57/amazon-standard-identification-numbers-asin-details
# Downloading: http://webscraping.com/data/default/database/58/salaries
# Downloading: http://webscraping.com/data/default/database/59/usa-people
# Downloading: http://webscraping.com/data/default/database/6/canada-cities
# Downloading: http://webscraping.com/data/default/database/60/blackberry-apps
# Downloading: http://webscraping.com/data/default/database/62/windows-phone-apps
# Downloading: http://webscraping.com/data/default/database/64/recipes
# Downloading: http://webscraping.com/data/default/database/65/australian-real-estate-agents
# Downloading: http://webscraping.com/data/default/database/66/european-businesses
# Downloading: http://webscraping.com/data/default/database/68/uk-businesses
# Downloading: http://webscraping.com/data/default/database/69/new-zealand-real-estate-agents
# Downloading: http://webscraping.com/data/default/database/7/apple-ios-apps
# Downloading: http://webscraping.com/data/default/database/70/usa-businesses
# Downloading: http://webscraping.com/data/default/database/71/usa-real-estate-agents
# Downloading: http://webscraping.com/data/default/database/8/amazon-standard-identification-numbers-asin
# Downloading: http://webscraping.com/data/default/database/9/world-restaurants
# Downloading: http://webscraping.com/data/default/index?page=0
# Downloading: http://webscraping.com/data/default/index?page=1
# Downloading: http://webscraping.com/data/default/index?page=2
# Downloading: http://webscraping.com/data/default/index?page=3
# Downloading: http://webscraping.com/data/default/index?page=4
# Downloading: http://webscraping.com/data/default/index?page=5
# Downloading: http://webscraping.com/data/default/index?page=6
# Downloading: http://webscraping.com/feedback
# Downloading: http://webscraping.com/quote
# Downloading: http://webscraping.com/shame

# %%
import itertools
import re
import urllib.request
import urllib.error


def download(url, user_agent='wswp', num_retries=2):
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    try:
        html = urllib.request.urlopen(request).read()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                return download(url, user_agent, num_retries - 1)
    return html


def crawl_sitemap(url):
    # download the sitemap file
    sitemap = download(url)
    # extract the sitemap links
    links = re.findall('<loc>(.*?)</loc>', sitemap.decode())
    # download each link
    for link in links:
        html = download(link)
        # scrape html here
        # ...


for page in itertools.count(1):
    url = 'http://example.webscraping.com/places/default/view/-{}'.format(page)
    html = download(url)
    if html is None:
        break
    else:
        # success - can scrape the result
        pass
# Out:
# Downloading: http://example.webscraping.com/places/default/view/-1
# Downloading: http://example.webscraping.com/places/default/view/-2
# Downloading: http://example.webscraping.com/places/default/view/-3
# Downloading: http://example.webscraping.com/places/default/view/-4
# Downloading: http://example.webscraping.com/places/default/view/-5
# Downloading: http://example.webscraping.com/places/default/view/-6
# Downloading: http://example.webscraping.com/places/default/view/-7
# Downloading: http://example.webscraping.com/places/default/view/-8
# Downloading: http://example.webscraping.com/places/default/view/-9
# Downloading: http://example.webscraping.com/places/default/view/-10
# Downloading: http://example.webscraping.com/places/default/view/-11
# Downloading: http://example.webscraping.com/places/default/view/-12
# Downloading: http://example.webscraping.com/places/default/view/-13
# Downloading: http://example.webscraping.com/places/default/view/-14
# Downloading: http://example.webscraping.com/places/default/view/-15
# Downloading: http://example.webscraping.com/places/default/view/-16
# Downloading: http://example.webscraping.com/places/default/view/-17
# Downloading: http://example.webscraping.com/places/default/view/-18
# Downloading: http://example.webscraping.com/places/default/view/-19
# Downloading: http://example.webscraping.com/places/default/view/-20
# Downloading: http://example.webscraping.com/places/default/view/-21
# Downloading: http://example.webscraping.com/places/default/view/-22
# Downloading: http://example.webscraping.com/places/default/view/-23
# Downloading: http://example.webscraping.com/places/default/view/-24
# Downloading: http://example.webscraping.com/places/default/view/-25
# Downloading: http://example.webscraping.com/places/default/view/-26
# Downloading: http://example.webscraping.com/places/default/view/-27
# Downloading: http://example.webscraping.com/places/default/view/-28
# Downloading: http://example.webscraping.com/places/default/view/-29
# Downloading: http://example.webscraping.com/places/default/view/-30
# Downloading: http://example.webscraping.com/places/default/view/-31
# Downloading: http://example.webscraping.com/places/default/view/-32
# Downloading: http://example.webscraping.com/places/default/view/-33
# Downloading: http://example.webscraping.com/places/default/view/-34
# Downloading: http://example.webscraping.com/places/default/view/-35
# Downloading: http://example.webscraping.com/places/default/view/-36
# Downloading: http://example.webscraping.com/places/default/view/-37
# Downloading: http://example.webscraping.com/places/default/view/-38
# Downloading: http://example.webscraping.com/places/default/view/-39
# Downloading: http://example.webscraping.com/places/default/view/-40
# Downloading: http://example.webscraping.com/places/default/view/-41
# Downloading: http://example.webscraping.com/places/default/view/-42
# Downloading: http://example.webscraping.com/places/default/view/-43
# Downloading: http://example.webscraping.com/places/default/view/-44
# Downloading: http://example.webscraping.com/places/default/view/-45
# Downloading: http://example.webscraping.com/places/default/view/-46
# Downloading: http://example.webscraping.com/places/default/view/-47
# Downloading: http://example.webscraping.com/places/default/view/-48
# Downloading: http://example.webscraping.com/places/default/view/-49
# Downloading: http://example.webscraping.com/places/default/view/-50
# Downloading: http://example.webscraping.com/places/default/view/-51
# Downloading: http://example.webscraping.com/places/default/view/-52
# Downloading: http://example.webscraping.com/places/default/view/-53
# Downloading: http://example.webscraping.com/places/default/view/-54
# Downloading: http://example.webscraping.com/places/default/view/-55
# Downloading: http://example.webscraping.com/places/default/view/-56
# Downloading: http://example.webscraping.com/places/default/view/-57
# Downloading: http://example.webscraping.com/places/default/view/-58
# Downloading: http://example.webscraping.com/places/default/view/-59
# Downloading: http://example.webscraping.com/places/default/view/-60
# Downloading: http://example.webscraping.com/places/default/view/-61
# Downloading: http://example.webscraping.com/places/default/view/-62
# Downloading: http://example.webscraping.com/places/default/view/-63
# Downloading: http://example.webscraping.com/places/default/view/-64
# Downloading: http://example.webscraping.com/places/default/view/-65
# Downloading: http://example.webscraping.com/places/default/view/-66
# Downloading: http://example.webscraping.com/places/default/view/-67
# Downloading: http://example.webscraping.com/places/default/view/-68
# Downloading: http://example.webscraping.com/places/default/view/-69
# Downloading: http://example.webscraping.com/places/default/view/-70
# Downloading: http://example.webscraping.com/places/default/view/-71
# Downloading: http://example.webscraping.com/places/default/view/-72
# Downloading: http://example.webscraping.com/places/default/view/-73
# Downloading: http://example.webscraping.com/places/default/view/-74
# Downloading: http://example.webscraping.com/places/default/view/-75
# Downloading: http://example.webscraping.com/places/default/view/-76
# Downloading: http://example.webscraping.com/places/default/view/-77
# Downloading: http://example.webscraping.com/places/default/view/-78
# Downloading: http://example.webscraping.com/places/default/view/-79
# Downloading: http://example.webscraping.com/places/default/view/-80
# Downloading: http://example.webscraping.com/places/default/view/-81
# Downloading: http://example.webscraping.com/places/default/view/-82
# Downloading: http://example.webscraping.com/places/default/view/-83
# Downloading: http://example.webscraping.com/places/default/view/-84
# Downloading: http://example.webscraping.com/places/default/view/-85
# Downloading: http://example.webscraping.com/places/default/view/-86
# Downloading: http://example.webscraping.com/places/default/view/-87
# Downloading: http://example.webscraping.com/places/default/view/-88
# Downloading: http://example.webscraping.com/places/default/view/-89
# Downloading: http://example.webscraping.com/places/default/view/-90
# Downloading: http://example.webscraping.com/places/default/view/-91
# Downloading: http://example.webscraping.com/places/default/view/-92
# Downloading: http://example.webscraping.com/places/default/view/-93
# Downloading: http://example.webscraping.com/places/default/view/-94
# Downloading: http://example.webscraping.com/places/default/view/-95
# Downloading: http://example.webscraping.com/places/default/view/-96
# Downloading: http://example.webscraping.com/places/default/view/-97
# Downloading: http://example.webscraping.com/places/default/view/-98
# Downloading: http://example.webscraping.com/places/default/view/-99
# Downloading: http://example.webscraping.com/places/default/view/-100
# Downloading: http://example.webscraping.com/places/default/view/-101
# Downloading: http://example.webscraping.com/places/default/view/-102
# Downloading: http://example.webscraping.com/places/default/view/-103
# Downloading: http://example.webscraping.com/places/default/view/-104
# Downloading: http://example.webscraping.com/places/default/view/-105
# Downloading: http://example.webscraping.com/places/default/view/-106
# Downloading: http://example.webscraping.com/places/default/view/-107
# Downloading: http://example.webscraping.com/places/default/view/-108
# Downloading: http://example.webscraping.com/places/default/view/-109
# Downloading: http://example.webscraping.com/places/default/view/-110
# Downloading: http://example.webscraping.com/places/default/view/-111
# Downloading: http://example.webscraping.com/places/default/view/-112
# Downloading: http://example.webscraping.com/places/default/view/-113
# Downloading: http://example.webscraping.com/places/default/view/-114
# Downloading: http://example.webscraping.com/places/default/view/-115
# Downloading: http://example.webscraping.com/places/default/view/-116
# Downloading: http://example.webscraping.com/places/default/view/-117
# Downloading: http://example.webscraping.com/places/default/view/-118
# Downloading: http://example.webscraping.com/places/default/view/-119
# Downloading: http://example.webscraping.com/places/default/view/-120
# Downloading: http://example.webscraping.com/places/default/view/-121
# Downloading: http://example.webscraping.com/places/default/view/-122
# Downloading: http://example.webscraping.com/places/default/view/-123
# Downloading: http://example.webscraping.com/places/default/view/-124
# Downloading: http://example.webscraping.com/places/default/view/-125
# Downloading: http://example.webscraping.com/places/default/view/-126
# Downloading: http://example.webscraping.com/places/default/view/-127
# Downloading: http://example.webscraping.com/places/default/view/-128
# Downloading: http://example.webscraping.com/places/default/view/-129
# Downloading: http://example.webscraping.com/places/default/view/-130
# Downloading: http://example.webscraping.com/places/default/view/-131
# Downloading: http://example.webscraping.com/places/default/view/-132
# Downloading: http://example.webscraping.com/places/default/view/-133
# Downloading: http://example.webscraping.com/places/default/view/-134
# Downloading: http://example.webscraping.com/places/default/view/-135
# Downloading: http://example.webscraping.com/places/default/view/-136
# Downloading: http://example.webscraping.com/places/default/view/-137
# Downloading: http://example.webscraping.com/places/default/view/-138
# Downloading: http://example.webscraping.com/places/default/view/-139
# Downloading: http://example.webscraping.com/places/default/view/-140
# Downloading: http://example.webscraping.com/places/default/view/-141
# Downloading: http://example.webscraping.com/places/default/view/-142
# Downloading: http://example.webscraping.com/places/default/view/-143
# Downloading: http://example.webscraping.com/places/default/view/-144
# Downloading: http://example.webscraping.com/places/default/view/-145
# Downloading: http://example.webscraping.com/places/default/view/-146
# Downloading: http://example.webscraping.com/places/default/view/-147
# Downloading: http://example.webscraping.com/places/default/view/-148
# Downloading: http://example.webscraping.com/places/default/view/-149
# Downloading: http://example.webscraping.com/places/default/view/-150
# Downloading: http://example.webscraping.com/places/default/view/-151
# Downloading: http://example.webscraping.com/places/default/view/-152
# Downloading: http://example.webscraping.com/places/default/view/-153
# Downloading: http://example.webscraping.com/places/default/view/-154
# Downloading: http://example.webscraping.com/places/default/view/-155
# Downloading: http://example.webscraping.com/places/default/view/-156
# Downloading: http://example.webscraping.com/places/default/view/-157
# Downloading: http://example.webscraping.com/places/default/view/-158
# Downloading: http://example.webscraping.com/places/default/view/-159
# Downloading: http://example.webscraping.com/places/default/view/-160
# Downloading: http://example.webscraping.com/places/default/view/-161
# Downloading: http://example.webscraping.com/places/default/view/-162
# Downloading: http://example.webscraping.com/places/default/view/-163
# Downloading: http://example.webscraping.com/places/default/view/-164
# Downloading: http://example.webscraping.com/places/default/view/-165
# Downloading: http://example.webscraping.com/places/default/view/-166
# Downloading: http://example.webscraping.com/places/default/view/-167
# Downloading: http://example.webscraping.com/places/default/view/-168
# Downloading: http://example.webscraping.com/places/default/view/-169
# Downloading: http://example.webscraping.com/places/default/view/-170
# Downloading: http://example.webscraping.com/places/default/view/-171
# Downloading: http://example.webscraping.com/places/default/view/-172
# Downloading: http://example.webscraping.com/places/default/view/-173
# Downloading: http://example.webscraping.com/places/default/view/-174
# Downloading: http://example.webscraping.com/places/default/view/-175
# Downloading: http://example.webscraping.com/places/default/view/-176
# Downloading: http://example.webscraping.com/places/default/view/-177
# Downloading: http://example.webscraping.com/places/default/view/-178
# Downloading: http://example.webscraping.com/places/default/view/-179
# Downloading: http://example.webscraping.com/places/default/view/-180
# Downloading: http://example.webscraping.com/places/default/view/-181
# Downloading: http://example.webscraping.com/places/default/view/-182
# Downloading: http://example.webscraping.com/places/default/view/-183
# Downloading: http://example.webscraping.com/places/default/view/-184
# Downloading: http://example.webscraping.com/places/default/view/-185
# Downloading: http://example.webscraping.com/places/default/view/-186
# Downloading: http://example.webscraping.com/places/default/view/-187
# Downloading: http://example.webscraping.com/places/default/view/-188
# Downloading: http://example.webscraping.com/places/default/view/-189
# Downloading: http://example.webscraping.com/places/default/view/-190
# Downloading: http://example.webscraping.com/places/default/view/-191
# Downloading: http://example.webscraping.com/places/default/view/-192
# Downloading: http://example.webscraping.com/places/default/view/-193
# Downloading: http://example.webscraping.com/places/default/view/-194
# Downloading: http://example.webscraping.com/places/default/view/-195
# Downloading: http://example.webscraping.com/places/default/view/-196
# Downloading: http://example.webscraping.com/places/default/view/-197
# Downloading: http://example.webscraping.com/places/default/view/-198
# Downloading: http://example.webscraping.com/places/default/view/-199
# Downloading: http://example.webscraping.com/places/default/view/-200
# Downloading: http://example.webscraping.com/places/default/view/-201
# Downloading: http://example.webscraping.com/places/default/view/-202
# Downloading: http://example.webscraping.com/places/default/view/-203
# Downloading: http://example.webscraping.com/places/default/view/-204
# Downloading: http://example.webscraping.com/places/default/view/-205
# Downloading: http://example.webscraping.com/places/default/view/-206
# Downloading: http://example.webscraping.com/places/default/view/-207
# Downloading: http://example.webscraping.com/places/default/view/-208
# Downloading: http://example.webscraping.com/places/default/view/-209
# Downloading: http://example.webscraping.com/places/default/view/-210
# Downloading: http://example.webscraping.com/places/default/view/-211
# Downloading: http://example.webscraping.com/places/default/view/-212
# Downloading: http://example.webscraping.com/places/default/view/-213
# Downloading: http://example.webscraping.com/places/default/view/-214
# Downloading: http://example.webscraping.com/places/default/view/-215
# Downloading: http://example.webscraping.com/places/default/view/-216
# Downloading: http://example.webscraping.com/places/default/view/-217
# Downloading: http://example.webscraping.com/places/default/view/-218
# Downloading: http://example.webscraping.com/places/default/view/-219
# Downloading: http://example.webscraping.com/places/default/view/-220
# Downloading: http://example.webscraping.com/places/default/view/-221
# Downloading: http://example.webscraping.com/places/default/view/-222
# Downloading: http://example.webscraping.com/places/default/view/-223
# Downloading: http://example.webscraping.com/places/default/view/-224
# Downloading: http://example.webscraping.com/places/default/view/-225
# Downloading: http://example.webscraping.com/places/default/view/-226
# Downloading: http://example.webscraping.com/places/default/view/-227
# Downloading: http://example.webscraping.com/places/default/view/-228
# Downloading: http://example.webscraping.com/places/default/view/-229
# Downloading: http://example.webscraping.com/places/default/view/-230
# Downloading: http://example.webscraping.com/places/default/view/-231
# Downloading: http://example.webscraping.com/places/default/view/-232
# Downloading: http://example.webscraping.com/places/default/view/-233
# Downloading: http://example.webscraping.com/places/default/view/-234
# Downloading: http://example.webscraping.com/places/default/view/-235
# Downloading: http://example.webscraping.com/places/default/view/-236
# Downloading: http://example.webscraping.com/places/default/view/-237
# Downloading: http://example.webscraping.com/places/default/view/-238
# Downloading: http://example.webscraping.com/places/default/view/-239
# Downloading: http://example.webscraping.com/places/default/view/-240
# Downloading: http://example.webscraping.com/places/default/view/-241
# Downloading: http://example.webscraping.com/places/default/view/-242
# Downloading: http://example.webscraping.com/places/default/view/-243
# Downloading: http://example.webscraping.com/places/default/view/-244
# Downloading: http://example.webscraping.com/places/default/view/-245
# Downloading: http://example.webscraping.com/places/default/view/-246
# Downloading: http://example.webscraping.com/places/default/view/-247
# Downloading: http://example.webscraping.com/places/default/view/-248
# Downloading: http://example.webscraping.com/places/default/view/-249
# Downloading: http://example.webscraping.com/places/default/view/-250
# Downloading: http://example.webscraping.com/places/default/view/-251
# Downloading: http://example.webscraping.com/places/default/view/-252
# Downloading: http://example.webscraping.com/places/default/view/-253
# Download error: NOT FOUND

# %%
import itertools
import urllib.request
import urllib.error


def download(url, user_agent='wswp', num_retries=2):
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    try:
        html = urllib.request.urlopen(request).read()
    except urllib.error.URLError as e:
        print('Download error:', e.code, e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                return download(url, user_agent, num_retries - 1)
    return html


# maximum number of consecutive download errors allowed
max_errors = 5
# current number of consecutive download errors
num_errors = 0
for page in itertools.count(1):
    url = 'http://example.webscraping.com/places/default/view/-{}'.format(page)
    html = download(url)
    if html is None:
        # received an error trying to download this webpage
        num_errors += 1
        if num_errors == max_errors:
            # reached maximum number of
            # consecutive errors so exit
            break
# Out:
# Downloading: http://example.webscraping.com/places/default/view/-1
# Downloading: http://example.webscraping.com/places/default/view/-2
# Downloading: http://example.webscraping.com/places/default/view/-3
# Downloading: http://example.webscraping.com/places/default/view/-4
# Downloading: http://example.webscraping.com/places/default/view/-5
# Downloading: http://example.webscraping.com/places/default/view/-6
# Downloading: http://example.webscraping.com/places/default/view/-7
# Downloading: http://example.webscraping.com/places/default/view/-8
# Downloading: http://example.webscraping.com/places/default/view/-9
# Downloading: http://example.webscraping.com/places/default/view/-10
# Downloading: http://example.webscraping.com/places/default/view/-11
# Downloading: http://example.webscraping.com/places/default/view/-12
# Downloading: http://example.webscraping.com/places/default/view/-13
# Downloading: http://example.webscraping.com/places/default/view/-14
# Downloading: http://example.webscraping.com/places/default/view/-15
# Downloading: http://example.webscraping.com/places/default/view/-16
# Downloading: http://example.webscraping.com/places/default/view/-17
# Downloading: http://example.webscraping.com/places/default/view/-18
# Downloading: http://example.webscraping.com/places/default/view/-19
# Downloading: http://example.webscraping.com/places/default/view/-20
# Downloading: http://example.webscraping.com/places/default/view/-21
# Downloading: http://example.webscraping.com/places/default/view/-22
# Downloading: http://example.webscraping.com/places/default/view/-23
# Downloading: http://example.webscraping.com/places/default/view/-24
# Downloading: http://example.webscraping.com/places/default/view/-25
# Downloading: http://example.webscraping.com/places/default/view/-26
# Downloading: http://example.webscraping.com/places/default/view/-27
# Downloading: http://example.webscraping.com/places/default/view/-28
# Downloading: http://example.webscraping.com/places/default/view/-29
# Downloading: http://example.webscraping.com/places/default/view/-30
# Downloading: http://example.webscraping.com/places/default/view/-31
# Downloading: http://example.webscraping.com/places/default/view/-32
# Downloading: http://example.webscraping.com/places/default/view/-33
# Downloading: http://example.webscraping.com/places/default/view/-34
# Downloading: http://example.webscraping.com/places/default/view/-35
# Downloading: http://example.webscraping.com/places/default/view/-36
# Downloading: http://example.webscraping.com/places/default/view/-37
# Downloading: http://example.webscraping.com/places/default/view/-38
# Downloading: http://example.webscraping.com/places/default/view/-39
# Downloading: http://example.webscraping.com/places/default/view/-40
# Downloading: http://example.webscraping.com/places/default/view/-41
# Downloading: http://example.webscraping.com/places/default/view/-42
# Downloading: http://example.webscraping.com/places/default/view/-43
# Downloading: http://example.webscraping.com/places/default/view/-44
# Downloading: http://example.webscraping.com/places/default/view/-45
# Downloading: http://example.webscraping.com/places/default/view/-46
# Downloading: http://example.webscraping.com/places/default/view/-47
# Downloading: http://example.webscraping.com/places/default/view/-48
# Downloading: http://example.webscraping.com/places/default/view/-49
# Downloading: http://example.webscraping.com/places/default/view/-50
# Downloading: http://example.webscraping.com/places/default/view/-51
# Downloading: http://example.webscraping.com/places/default/view/-52
# Downloading: http://example.webscraping.com/places/default/view/-53
# Downloading: http://example.webscraping.com/places/default/view/-54
# Downloading: http://example.webscraping.com/places/default/view/-55
# Downloading: http://example.webscraping.com/places/default/view/-56
# Downloading: http://example.webscraping.com/places/default/view/-57
# Downloading: http://example.webscraping.com/places/default/view/-58
# Downloading: http://example.webscraping.com/places/default/view/-59
# Downloading: http://example.webscraping.com/places/default/view/-60
# Downloading: http://example.webscraping.com/places/default/view/-61
# Downloading: http://example.webscraping.com/places/default/view/-62
# Downloading: http://example.webscraping.com/places/default/view/-63
# Downloading: http://example.webscraping.com/places/default/view/-64
# Downloading: http://example.webscraping.com/places/default/view/-65
# Downloading: http://example.webscraping.com/places/default/view/-66
# Downloading: http://example.webscraping.com/places/default/view/-67
# Downloading: http://example.webscraping.com/places/default/view/-68
# Downloading: http://example.webscraping.com/places/default/view/-69
# Downloading: http://example.webscraping.com/places/default/view/-70
# Downloading: http://example.webscraping.com/places/default/view/-71
# Downloading: http://example.webscraping.com/places/default/view/-72
# Downloading: http://example.webscraping.com/places/default/view/-73
# Downloading: http://example.webscraping.com/places/default/view/-74
# Downloading: http://example.webscraping.com/places/default/view/-75
# Downloading: http://example.webscraping.com/places/default/view/-76
# Downloading: http://example.webscraping.com/places/default/view/-77
# Downloading: http://example.webscraping.com/places/default/view/-78
# Downloading: http://example.webscraping.com/places/default/view/-79
# Downloading: http://example.webscraping.com/places/default/view/-80
# Downloading: http://example.webscraping.com/places/default/view/-81
# Downloading: http://example.webscraping.com/places/default/view/-82
# Downloading: http://example.webscraping.com/places/default/view/-83
# Downloading: http://example.webscraping.com/places/default/view/-84
# Downloading: http://example.webscraping.com/places/default/view/-85
# Downloading: http://example.webscraping.com/places/default/view/-86
# Downloading: http://example.webscraping.com/places/default/view/-87
# Downloading: http://example.webscraping.com/places/default/view/-88
# Downloading: http://example.webscraping.com/places/default/view/-89
# Downloading: http://example.webscraping.com/places/default/view/-90
# Downloading: http://example.webscraping.com/places/default/view/-91
# Downloading: http://example.webscraping.com/places/default/view/-92
# Downloading: http://example.webscraping.com/places/default/view/-93
# Downloading: http://example.webscraping.com/places/default/view/-94
# Downloading: http://example.webscraping.com/places/default/view/-95
# Downloading: http://example.webscraping.com/places/default/view/-96
# Downloading: http://example.webscraping.com/places/default/view/-97
# Downloading: http://example.webscraping.com/places/default/view/-98
# Downloading: http://example.webscraping.com/places/default/view/-99
# Downloading: http://example.webscraping.com/places/default/view/-100
# Downloading: http://example.webscraping.com/places/default/view/-101
# Downloading: http://example.webscraping.com/places/default/view/-102
# Downloading: http://example.webscraping.com/places/default/view/-103
# Downloading: http://example.webscraping.com/places/default/view/-104
# Downloading: http://example.webscraping.com/places/default/view/-105
# Downloading: http://example.webscraping.com/places/default/view/-106
# Downloading: http://example.webscraping.com/places/default/view/-107
# Downloading: http://example.webscraping.com/places/default/view/-108
# Downloading: http://example.webscraping.com/places/default/view/-109
# Downloading: http://example.webscraping.com/places/default/view/-110
# Downloading: http://example.webscraping.com/places/default/view/-111
# Downloading: http://example.webscraping.com/places/default/view/-112
# Downloading: http://example.webscraping.com/places/default/view/-113
# Downloading: http://example.webscraping.com/places/default/view/-114
# Downloading: http://example.webscraping.com/places/default/view/-115
# Downloading: http://example.webscraping.com/places/default/view/-116
# Downloading: http://example.webscraping.com/places/default/view/-117
# Downloading: http://example.webscraping.com/places/default/view/-118
# Downloading: http://example.webscraping.com/places/default/view/-119
# Downloading: http://example.webscraping.com/places/default/view/-120
# Downloading: http://example.webscraping.com/places/default/view/-121
# Downloading: http://example.webscraping.com/places/default/view/-122
# Downloading: http://example.webscraping.com/places/default/view/-123
# Downloading: http://example.webscraping.com/places/default/view/-124
# Downloading: http://example.webscraping.com/places/default/view/-125
# Downloading: http://example.webscraping.com/places/default/view/-126
# Downloading: http://example.webscraping.com/places/default/view/-127
# Downloading: http://example.webscraping.com/places/default/view/-128
# Downloading: http://example.webscraping.com/places/default/view/-129
# Downloading: http://example.webscraping.com/places/default/view/-130
# Downloading: http://example.webscraping.com/places/default/view/-131
# Downloading: http://example.webscraping.com/places/default/view/-132
# Downloading: http://example.webscraping.com/places/default/view/-133
# Downloading: http://example.webscraping.com/places/default/view/-134
# Downloading: http://example.webscraping.com/places/default/view/-135
# Downloading: http://example.webscraping.com/places/default/view/-136
# Downloading: http://example.webscraping.com/places/default/view/-137
# Downloading: http://example.webscraping.com/places/default/view/-138
# Downloading: http://example.webscraping.com/places/default/view/-139
# Downloading: http://example.webscraping.com/places/default/view/-140
# Downloading: http://example.webscraping.com/places/default/view/-141
# Downloading: http://example.webscraping.com/places/default/view/-142
# Downloading: http://example.webscraping.com/places/default/view/-143
# Downloading: http://example.webscraping.com/places/default/view/-144
# Downloading: http://example.webscraping.com/places/default/view/-145
# Downloading: http://example.webscraping.com/places/default/view/-146
# Downloading: http://example.webscraping.com/places/default/view/-147
# Downloading: http://example.webscraping.com/places/default/view/-148
# Downloading: http://example.webscraping.com/places/default/view/-149
# Downloading: http://example.webscraping.com/places/default/view/-150
# Downloading: http://example.webscraping.com/places/default/view/-151
# Downloading: http://example.webscraping.com/places/default/view/-152
# Downloading: http://example.webscraping.com/places/default/view/-153
# Downloading: http://example.webscraping.com/places/default/view/-154
# Downloading: http://example.webscraping.com/places/default/view/-155
# Downloading: http://example.webscraping.com/places/default/view/-156
# Downloading: http://example.webscraping.com/places/default/view/-157
# Downloading: http://example.webscraping.com/places/default/view/-158
# Downloading: http://example.webscraping.com/places/default/view/-159
# Downloading: http://example.webscraping.com/places/default/view/-160
# Downloading: http://example.webscraping.com/places/default/view/-161
# Downloading: http://example.webscraping.com/places/default/view/-162
# Downloading: http://example.webscraping.com/places/default/view/-163
# Downloading: http://example.webscraping.com/places/default/view/-164
# Downloading: http://example.webscraping.com/places/default/view/-165
# Downloading: http://example.webscraping.com/places/default/view/-166
# Downloading: http://example.webscraping.com/places/default/view/-167
# Downloading: http://example.webscraping.com/places/default/view/-168
# Downloading: http://example.webscraping.com/places/default/view/-169
# Downloading: http://example.webscraping.com/places/default/view/-170
# Downloading: http://example.webscraping.com/places/default/view/-171
# Downloading: http://example.webscraping.com/places/default/view/-172
# Downloading: http://example.webscraping.com/places/default/view/-173
# Downloading: http://example.webscraping.com/places/default/view/-174
# Downloading: http://example.webscraping.com/places/default/view/-175
# Downloading: http://example.webscraping.com/places/default/view/-176
# Downloading: http://example.webscraping.com/places/default/view/-177
# Downloading: http://example.webscraping.com/places/default/view/-178
# Downloading: http://example.webscraping.com/places/default/view/-179
# Downloading: http://example.webscraping.com/places/default/view/-180
# Downloading: http://example.webscraping.com/places/default/view/-181
# Downloading: http://example.webscraping.com/places/default/view/-182
# Downloading: http://example.webscraping.com/places/default/view/-183
# Downloading: http://example.webscraping.com/places/default/view/-184
# Downloading: http://example.webscraping.com/places/default/view/-185
# Downloading: http://example.webscraping.com/places/default/view/-186
# Downloading: http://example.webscraping.com/places/default/view/-187
# Downloading: http://example.webscraping.com/places/default/view/-188
# Downloading: http://example.webscraping.com/places/default/view/-189
# Downloading: http://example.webscraping.com/places/default/view/-190
# Downloading: http://example.webscraping.com/places/default/view/-191
# Downloading: http://example.webscraping.com/places/default/view/-192
# Downloading: http://example.webscraping.com/places/default/view/-193
# Downloading: http://example.webscraping.com/places/default/view/-194
# Downloading: http://example.webscraping.com/places/default/view/-195
# Downloading: http://example.webscraping.com/places/default/view/-196
# Downloading: http://example.webscraping.com/places/default/view/-197
# Downloading: http://example.webscraping.com/places/default/view/-198
# Downloading: http://example.webscraping.com/places/default/view/-199
# Downloading: http://example.webscraping.com/places/default/view/-200
# Downloading: http://example.webscraping.com/places/default/view/-201
# Downloading: http://example.webscraping.com/places/default/view/-202
# Downloading: http://example.webscraping.com/places/default/view/-203
# Downloading: http://example.webscraping.com/places/default/view/-204
# Downloading: http://example.webscraping.com/places/default/view/-205
# Downloading: http://example.webscraping.com/places/default/view/-206
# Downloading: http://example.webscraping.com/places/default/view/-207
# Downloading: http://example.webscraping.com/places/default/view/-208
# Downloading: http://example.webscraping.com/places/default/view/-209
# Downloading: http://example.webscraping.com/places/default/view/-210
# Downloading: http://example.webscraping.com/places/default/view/-211
# Downloading: http://example.webscraping.com/places/default/view/-212
# Downloading: http://example.webscraping.com/places/default/view/-213
# Downloading: http://example.webscraping.com/places/default/view/-214
# Downloading: http://example.webscraping.com/places/default/view/-215
# Downloading: http://example.webscraping.com/places/default/view/-216
# Downloading: http://example.webscraping.com/places/default/view/-217
# Downloading: http://example.webscraping.com/places/default/view/-218
# Downloading: http://example.webscraping.com/places/default/view/-219
# Downloading: http://example.webscraping.com/places/default/view/-220
# Downloading: http://example.webscraping.com/places/default/view/-221
# Downloading: http://example.webscraping.com/places/default/view/-222
# Downloading: http://example.webscraping.com/places/default/view/-223
# Downloading: http://example.webscraping.com/places/default/view/-224
# Downloading: http://example.webscraping.com/places/default/view/-225
# Downloading: http://example.webscraping.com/places/default/view/-226
# Downloading: http://example.webscraping.com/places/default/view/-227
# Downloading: http://example.webscraping.com/places/default/view/-228
# Downloading: http://example.webscraping.com/places/default/view/-229
# Downloading: http://example.webscraping.com/places/default/view/-230
# Downloading: http://example.webscraping.com/places/default/view/-231
# Downloading: http://example.webscraping.com/places/default/view/-232
# Downloading: http://example.webscraping.com/places/default/view/-233
# Downloading: http://example.webscraping.com/places/default/view/-234
# Downloading: http://example.webscraping.com/places/default/view/-235
# Downloading: http://example.webscraping.com/places/default/view/-236
# Downloading: http://example.webscraping.com/places/default/view/-237
# Downloading: http://example.webscraping.com/places/default/view/-238
# Downloading: http://example.webscraping.com/places/default/view/-239
# Downloading: http://example.webscraping.com/places/default/view/-240
# Downloading: http://example.webscraping.com/places/default/view/-241
# Downloading: http://example.webscraping.com/places/default/view/-242
# Downloading: http://example.webscraping.com/places/default/view/-243
# Downloading: http://example.webscraping.com/places/default/view/-244
# Downloading: http://example.webscraping.com/places/default/view/-245
# Downloading: http://example.webscraping.com/places/default/view/-246
# Downloading: http://example.webscraping.com/places/default/view/-247
# Downloading: http://example.webscraping.com/places/default/view/-248
# Downloading: http://example.webscraping.com/places/default/view/-249
# Downloading: http://example.webscraping.com/places/default/view/-250
# Downloading: http://example.webscraping.com/places/default/view/-251
# Downloading: http://example.webscraping.com/places/default/view/-252
# Downloading: http://example.webscraping.com/places/default/view/-253
# Download error: 404 NOT FOUND
# Downloading: http://example.webscraping.com/places/default/view/-254
# Download error: 404 NOT FOUND
# Downloading: http://example.webscraping.com/places/default/view/-255
# Download error: 404 NOT FOUND
# Downloading: http://example.webscraping.com/places/default/view/-256
# Download error: 404 NOT FOUND
# Downloading: http://example.webscraping.com/places/default/view/-257
# Download error: 404 NOT FOUND

# %%
import itertools
import urllib.request
import urllib.error


def download(url, user_agent='wswp', num_retries=2):
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    try:
        html = urllib.request.urlopen(request).read()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                return download(url, user_agent, num_retries - 1)
    return html


# maximum number of consecutive download errors allowed
max_errors = 5
# current number of consecutive download errors
num_errors = 0
for page in itertools.count(1):
    url = 'http://example.webscraping.com/places/default/view/-{}'.format(page)
    html = download(url)
    if html is None:
        # received an error trying to download this webpage
        num_errors += 1
        if num_errors == max_errors:
            # reached maximum number of
            # consecutive errors so exit
            break
# Out:
# Downloading: http://example.webscraping.com/places/default/view/-1
# Downloading: http://example.webscraping.com/places/default/view/-2
# Downloading: http://example.webscraping.com/places/default/view/-3
# Downloading: http://example.webscraping.com/places/default/view/-4
# Downloading: http://example.webscraping.com/places/default/view/-5
# Downloading: http://example.webscraping.com/places/default/view/-6
# Downloading: http://example.webscraping.com/places/default/view/-7
# Downloading: http://example.webscraping.com/places/default/view/-8
# Downloading: http://example.webscraping.com/places/default/view/-9
# Downloading: http://example.webscraping.com/places/default/view/-10
# Downloading: http://example.webscraping.com/places/default/view/-11
# Downloading: http://example.webscraping.com/places/default/view/-12
# Downloading: http://example.webscraping.com/places/default/view/-13
# Downloading: http://example.webscraping.com/places/default/view/-14
# Downloading: http://example.webscraping.com/places/default/view/-15
# Downloading: http://example.webscraping.com/places/default/view/-16
# Downloading: http://example.webscraping.com/places/default/view/-17
# Downloading: http://example.webscraping.com/places/default/view/-18
# Downloading: http://example.webscraping.com/places/default/view/-19
# Downloading: http://example.webscraping.com/places/default/view/-20
# Downloading: http://example.webscraping.com/places/default/view/-21
# Downloading: http://example.webscraping.com/places/default/view/-22
# Downloading: http://example.webscraping.com/places/default/view/-23
# Downloading: http://example.webscraping.com/places/default/view/-24
# Downloading: http://example.webscraping.com/places/default/view/-25
# Downloading: http://example.webscraping.com/places/default/view/-26
# Downloading: http://example.webscraping.com/places/default/view/-27
# Downloading: http://example.webscraping.com/places/default/view/-28
# Downloading: http://example.webscraping.com/places/default/view/-29
# Downloading: http://example.webscraping.com/places/default/view/-30
# Downloading: http://example.webscraping.com/places/default/view/-31
# Downloading: http://example.webscraping.com/places/default/view/-32
# Downloading: http://example.webscraping.com/places/default/view/-33
# Downloading: http://example.webscraping.com/places/default/view/-34
# Downloading: http://example.webscraping.com/places/default/view/-35
# Downloading: http://example.webscraping.com/places/default/view/-36
# Downloading: http://example.webscraping.com/places/default/view/-37
# Downloading: http://example.webscraping.com/places/default/view/-38
# Downloading: http://example.webscraping.com/places/default/view/-39
# Downloading: http://example.webscraping.com/places/default/view/-40
# Downloading: http://example.webscraping.com/places/default/view/-41
# Downloading: http://example.webscraping.com/places/default/view/-42
# Downloading: http://example.webscraping.com/places/default/view/-43
# Downloading: http://example.webscraping.com/places/default/view/-44
# Downloading: http://example.webscraping.com/places/default/view/-45
# Downloading: http://example.webscraping.com/places/default/view/-46
# Downloading: http://example.webscraping.com/places/default/view/-47
# Downloading: http://example.webscraping.com/places/default/view/-48
# Downloading: http://example.webscraping.com/places/default/view/-49
# Downloading: http://example.webscraping.com/places/default/view/-50
# Downloading: http://example.webscraping.com/places/default/view/-51
# Downloading: http://example.webscraping.com/places/default/view/-52
# Downloading: http://example.webscraping.com/places/default/view/-53
# Downloading: http://example.webscraping.com/places/default/view/-54
# Downloading: http://example.webscraping.com/places/default/view/-55
# Downloading: http://example.webscraping.com/places/default/view/-56
# Downloading: http://example.webscraping.com/places/default/view/-57
# Downloading: http://example.webscraping.com/places/default/view/-58
# Downloading: http://example.webscraping.com/places/default/view/-59
# Downloading: http://example.webscraping.com/places/default/view/-60
# Downloading: http://example.webscraping.com/places/default/view/-61
# Downloading: http://example.webscraping.com/places/default/view/-62
# Downloading: http://example.webscraping.com/places/default/view/-63
# Downloading: http://example.webscraping.com/places/default/view/-64
# Downloading: http://example.webscraping.com/places/default/view/-65
# Downloading: http://example.webscraping.com/places/default/view/-66
# Downloading: http://example.webscraping.com/places/default/view/-67
# Downloading: http://example.webscraping.com/places/default/view/-68
# Downloading: http://example.webscraping.com/places/default/view/-69
# Downloading: http://example.webscraping.com/places/default/view/-70
# Downloading: http://example.webscraping.com/places/default/view/-71
# Downloading: http://example.webscraping.com/places/default/view/-72
# Downloading: http://example.webscraping.com/places/default/view/-73
# Downloading: http://example.webscraping.com/places/default/view/-74
# Downloading: http://example.webscraping.com/places/default/view/-75
# Downloading: http://example.webscraping.com/places/default/view/-76
# Downloading: http://example.webscraping.com/places/default/view/-77
# Downloading: http://example.webscraping.com/places/default/view/-78
# Downloading: http://example.webscraping.com/places/default/view/-79
# Downloading: http://example.webscraping.com/places/default/view/-80
# Downloading: http://example.webscraping.com/places/default/view/-81
# Downloading: http://example.webscraping.com/places/default/view/-82
# Downloading: http://example.webscraping.com/places/default/view/-83
# Downloading: http://example.webscraping.com/places/default/view/-84
# Downloading: http://example.webscraping.com/places/default/view/-85
# Downloading: http://example.webscraping.com/places/default/view/-86
# Downloading: http://example.webscraping.com/places/default/view/-87
# Downloading: http://example.webscraping.com/places/default/view/-88
# Downloading: http://example.webscraping.com/places/default/view/-89
# Downloading: http://example.webscraping.com/places/default/view/-90
# Downloading: http://example.webscraping.com/places/default/view/-91
# Downloading: http://example.webscraping.com/places/default/view/-92
# Downloading: http://example.webscraping.com/places/default/view/-93
# Downloading: http://example.webscraping.com/places/default/view/-94
# Downloading: http://example.webscraping.com/places/default/view/-95
# Downloading: http://example.webscraping.com/places/default/view/-96
# Downloading: http://example.webscraping.com/places/default/view/-97
# Downloading: http://example.webscraping.com/places/default/view/-98
# Downloading: http://example.webscraping.com/places/default/view/-99
# Downloading: http://example.webscraping.com/places/default/view/-100
# Downloading: http://example.webscraping.com/places/default/view/-101
# Downloading: http://example.webscraping.com/places/default/view/-102
# Downloading: http://example.webscraping.com/places/default/view/-103
# Downloading: http://example.webscraping.com/places/default/view/-104
# Downloading: http://example.webscraping.com/places/default/view/-105
# Downloading: http://example.webscraping.com/places/default/view/-106
# Downloading: http://example.webscraping.com/places/default/view/-107
# Downloading: http://example.webscraping.com/places/default/view/-108
# Downloading: http://example.webscraping.com/places/default/view/-109
# Downloading: http://example.webscraping.com/places/default/view/-110
# Downloading: http://example.webscraping.com/places/default/view/-111
# Downloading: http://example.webscraping.com/places/default/view/-112
# Downloading: http://example.webscraping.com/places/default/view/-113
# Downloading: http://example.webscraping.com/places/default/view/-114
# Downloading: http://example.webscraping.com/places/default/view/-115
# Downloading: http://example.webscraping.com/places/default/view/-116
# Downloading: http://example.webscraping.com/places/default/view/-117
# Downloading: http://example.webscraping.com/places/default/view/-118
# Downloading: http://example.webscraping.com/places/default/view/-119
# Downloading: http://example.webscraping.com/places/default/view/-120
# Downloading: http://example.webscraping.com/places/default/view/-121
# Downloading: http://example.webscraping.com/places/default/view/-122
# Downloading: http://example.webscraping.com/places/default/view/-123
# Downloading: http://example.webscraping.com/places/default/view/-124
# Downloading: http://example.webscraping.com/places/default/view/-125
# Downloading: http://example.webscraping.com/places/default/view/-126
# Downloading: http://example.webscraping.com/places/default/view/-127
# Downloading: http://example.webscraping.com/places/default/view/-128
# Downloading: http://example.webscraping.com/places/default/view/-129
# Downloading: http://example.webscraping.com/places/default/view/-130
# Downloading: http://example.webscraping.com/places/default/view/-131
# Downloading: http://example.webscraping.com/places/default/view/-132
# Downloading: http://example.webscraping.com/places/default/view/-133
# Downloading: http://example.webscraping.com/places/default/view/-134
# Downloading: http://example.webscraping.com/places/default/view/-135
# Downloading: http://example.webscraping.com/places/default/view/-136
# Downloading: http://example.webscraping.com/places/default/view/-137
# Downloading: http://example.webscraping.com/places/default/view/-138
# Downloading: http://example.webscraping.com/places/default/view/-139
# Downloading: http://example.webscraping.com/places/default/view/-140
# Downloading: http://example.webscraping.com/places/default/view/-141
# Downloading: http://example.webscraping.com/places/default/view/-142
# Downloading: http://example.webscraping.com/places/default/view/-143
# Downloading: http://example.webscraping.com/places/default/view/-144
# Downloading: http://example.webscraping.com/places/default/view/-145
# Downloading: http://example.webscraping.com/places/default/view/-146
# Downloading: http://example.webscraping.com/places/default/view/-147
# Downloading: http://example.webscraping.com/places/default/view/-148
# Downloading: http://example.webscraping.com/places/default/view/-149
# Downloading: http://example.webscraping.com/places/default/view/-150
# Downloading: http://example.webscraping.com/places/default/view/-151
# Downloading: http://example.webscraping.com/places/default/view/-152
# Downloading: http://example.webscraping.com/places/default/view/-153
# Downloading: http://example.webscraping.com/places/default/view/-154
# Downloading: http://example.webscraping.com/places/default/view/-155
# Downloading: http://example.webscraping.com/places/default/view/-156
# Downloading: http://example.webscraping.com/places/default/view/-157
# Downloading: http://example.webscraping.com/places/default/view/-158
# Downloading: http://example.webscraping.com/places/default/view/-159
# Downloading: http://example.webscraping.com/places/default/view/-160
# Downloading: http://example.webscraping.com/places/default/view/-161
# Downloading: http://example.webscraping.com/places/default/view/-162
# Downloading: http://example.webscraping.com/places/default/view/-163
# Downloading: http://example.webscraping.com/places/default/view/-164
# Downloading: http://example.webscraping.com/places/default/view/-165
# Downloading: http://example.webscraping.com/places/default/view/-166
# Downloading: http://example.webscraping.com/places/default/view/-167
# Downloading: http://example.webscraping.com/places/default/view/-168
# Downloading: http://example.webscraping.com/places/default/view/-169
# Downloading: http://example.webscraping.com/places/default/view/-170
# Downloading: http://example.webscraping.com/places/default/view/-171
# Downloading: http://example.webscraping.com/places/default/view/-172
# Downloading: http://example.webscraping.com/places/default/view/-173
# Downloading: http://example.webscraping.com/places/default/view/-174
# Downloading: http://example.webscraping.com/places/default/view/-175
# Downloading: http://example.webscraping.com/places/default/view/-176
# Downloading: http://example.webscraping.com/places/default/view/-177
# Downloading: http://example.webscraping.com/places/default/view/-178
# Downloading: http://example.webscraping.com/places/default/view/-179
# Downloading: http://example.webscraping.com/places/default/view/-180
# Downloading: http://example.webscraping.com/places/default/view/-181
# Downloading: http://example.webscraping.com/places/default/view/-182
# Downloading: http://example.webscraping.com/places/default/view/-183
# Downloading: http://example.webscraping.com/places/default/view/-184
# Downloading: http://example.webscraping.com/places/default/view/-185
# Downloading: http://example.webscraping.com/places/default/view/-186
# Downloading: http://example.webscraping.com/places/default/view/-187
# Downloading: http://example.webscraping.com/places/default/view/-188
# Downloading: http://example.webscraping.com/places/default/view/-189
# Downloading: http://example.webscraping.com/places/default/view/-190
# Downloading: http://example.webscraping.com/places/default/view/-191
# Downloading: http://example.webscraping.com/places/default/view/-192
# Downloading: http://example.webscraping.com/places/default/view/-193
# Downloading: http://example.webscraping.com/places/default/view/-194
# Downloading: http://example.webscraping.com/places/default/view/-195
# Downloading: http://example.webscraping.com/places/default/view/-196
# Downloading: http://example.webscraping.com/places/default/view/-197
# Downloading: http://example.webscraping.com/places/default/view/-198
# Downloading: http://example.webscraping.com/places/default/view/-199
# Downloading: http://example.webscraping.com/places/default/view/-200
# Downloading: http://example.webscraping.com/places/default/view/-201
# Downloading: http://example.webscraping.com/places/default/view/-202
# Downloading: http://example.webscraping.com/places/default/view/-203
# Downloading: http://example.webscraping.com/places/default/view/-204
# Downloading: http://example.webscraping.com/places/default/view/-205
# Downloading: http://example.webscraping.com/places/default/view/-206
# Downloading: http://example.webscraping.com/places/default/view/-207
# Downloading: http://example.webscraping.com/places/default/view/-208
# Downloading: http://example.webscraping.com/places/default/view/-209
# Downloading: http://example.webscraping.com/places/default/view/-210
# Downloading: http://example.webscraping.com/places/default/view/-211
# Downloading: http://example.webscraping.com/places/default/view/-212
# Downloading: http://example.webscraping.com/places/default/view/-213
# Downloading: http://example.webscraping.com/places/default/view/-214
# Downloading: http://example.webscraping.com/places/default/view/-215
# Downloading: http://example.webscraping.com/places/default/view/-216
# Downloading: http://example.webscraping.com/places/default/view/-217
# Downloading: http://example.webscraping.com/places/default/view/-218
# Downloading: http://example.webscraping.com/places/default/view/-219
# Downloading: http://example.webscraping.com/places/default/view/-220
# Downloading: http://example.webscraping.com/places/default/view/-221
# Downloading: http://example.webscraping.com/places/default/view/-222
# Downloading: http://example.webscraping.com/places/default/view/-223
# Downloading: http://example.webscraping.com/places/default/view/-224
# Downloading: http://example.webscraping.com/places/default/view/-225
# Downloading: http://example.webscraping.com/places/default/view/-226
# Downloading: http://example.webscraping.com/places/default/view/-227
# Downloading: http://example.webscraping.com/places/default/view/-228
# Downloading: http://example.webscraping.com/places/default/view/-229
# Downloading: http://example.webscraping.com/places/default/view/-230
# Downloading: http://example.webscraping.com/places/default/view/-231
# Downloading: http://example.webscraping.com/places/default/view/-232
# Downloading: http://example.webscraping.com/places/default/view/-233
# Downloading: http://example.webscraping.com/places/default/view/-234
# Downloading: http://example.webscraping.com/places/default/view/-235
# Downloading: http://example.webscraping.com/places/default/view/-236
# Downloading: http://example.webscraping.com/places/default/view/-237
# Downloading: http://example.webscraping.com/places/default/view/-238
# Downloading: http://example.webscraping.com/places/default/view/-239
# Downloading: http://example.webscraping.com/places/default/view/-240
# Downloading: http://example.webscraping.com/places/default/view/-241
# Downloading: http://example.webscraping.com/places/default/view/-242
# Downloading: http://example.webscraping.com/places/default/view/-243
# Downloading: http://example.webscraping.com/places/default/view/-244
# Downloading: http://example.webscraping.com/places/default/view/-245
# Downloading: http://example.webscraping.com/places/default/view/-246
# Downloading: http://example.webscraping.com/places/default/view/-247
# Downloading: http://example.webscraping.com/places/default/view/-248
# Downloading: http://example.webscraping.com/places/default/view/-249
# Downloading: http://example.webscraping.com/places/default/view/-250
# Downloading: http://example.webscraping.com/places/default/view/-251
# Downloading: http://example.webscraping.com/places/default/view/-252
# Downloading: http://example.webscraping.com/places/default/view/-253
# Download error: NOT FOUND
# Downloading: http://example.webscraping.com/places/default/view/-254
# Download error: NOT FOUND
# Downloading: http://example.webscraping.com/places/default/view/-255
# Download error: NOT FOUND
# Downloading: http://example.webscraping.com/places/default/view/-256
# Download error: NOT FOUND
# Downloading: http://example.webscraping.com/places/default/view/-257
# Download error: NOT FOUND

# %%
import itertools
import urllib.request
import urllib.error


def download(url, user_agent='wswp', num_retries=2):
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    try:
        html = urllib.request.urlopen(request).read()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                return download(url, user_agent, num_retries - 1)
    return html


# maximum number of consecutive download errors allowed
max_errors = 5
# current number of consecutive download errors
num_errors = 0
for page in itertools.count(1):
    url = 'http://example.webscraping.com/places/default/view/-{}'.format(page)
    html = download(url)
    if html is None:
        # received an error trying to download this webpage
        num_errors += 1
        if num_errors == max_errors:
            # reached maximum number of
            # consecutive errors so exit
            break
    else:
        # success - can scrape the resule
        # ...
        num_errors = 0
# Out:
# Downloading: http://example.webscraping.com/places/default/view/-1
# Downloading: http://example.webscraping.com/places/default/view/-2
# Downloading: http://example.webscraping.com/places/default/view/-3
# Downloading: http://example.webscraping.com/places/default/view/-4
# Downloading: http://example.webscraping.com/places/default/view/-5
# Downloading: http://example.webscraping.com/places/default/view/-6
# Downloading: http://example.webscraping.com/places/default/view/-7
# Downloading: http://example.webscraping.com/places/default/view/-8
# Downloading: http://example.webscraping.com/places/default/view/-9
# Downloading: http://example.webscraping.com/places/default/view/-10
# Downloading: http://example.webscraping.com/places/default/view/-11
# Downloading: http://example.webscraping.com/places/default/view/-12
# Downloading: http://example.webscraping.com/places/default/view/-13
# Downloading: http://example.webscraping.com/places/default/view/-14
# Downloading: http://example.webscraping.com/places/default/view/-15
# Downloading: http://example.webscraping.com/places/default/view/-16
# Downloading: http://example.webscraping.com/places/default/view/-17
# Downloading: http://example.webscraping.com/places/default/view/-18
# Downloading: http://example.webscraping.com/places/default/view/-19
# Downloading: http://example.webscraping.com/places/default/view/-20
# Downloading: http://example.webscraping.com/places/default/view/-21
# Downloading: http://example.webscraping.com/places/default/view/-22
# Downloading: http://example.webscraping.com/places/default/view/-23
# Downloading: http://example.webscraping.com/places/default/view/-24
# Downloading: http://example.webscraping.com/places/default/view/-25
# Downloading: http://example.webscraping.com/places/default/view/-26
# Downloading: http://example.webscraping.com/places/default/view/-27
# Downloading: http://example.webscraping.com/places/default/view/-28
# Downloading: http://example.webscraping.com/places/default/view/-29
# Downloading: http://example.webscraping.com/places/default/view/-30
# Downloading: http://example.webscraping.com/places/default/view/-31
# Downloading: http://example.webscraping.com/places/default/view/-32
# Downloading: http://example.webscraping.com/places/default/view/-33
# Downloading: http://example.webscraping.com/places/default/view/-34
# Downloading: http://example.webscraping.com/places/default/view/-35
# Downloading: http://example.webscraping.com/places/default/view/-36
# Downloading: http://example.webscraping.com/places/default/view/-37
# Downloading: http://example.webscraping.com/places/default/view/-38
# Downloading: http://example.webscraping.com/places/default/view/-39
# Downloading: http://example.webscraping.com/places/default/view/-40
# Downloading: http://example.webscraping.com/places/default/view/-41
# Downloading: http://example.webscraping.com/places/default/view/-42
# Downloading: http://example.webscraping.com/places/default/view/-43
# Downloading: http://example.webscraping.com/places/default/view/-44
# Downloading: http://example.webscraping.com/places/default/view/-45
# Downloading: http://example.webscraping.com/places/default/view/-46
# Downloading: http://example.webscraping.com/places/default/view/-47
# Downloading: http://example.webscraping.com/places/default/view/-48
# Downloading: http://example.webscraping.com/places/default/view/-49
# Downloading: http://example.webscraping.com/places/default/view/-50
# Downloading: http://example.webscraping.com/places/default/view/-51
# Downloading: http://example.webscraping.com/places/default/view/-52
# Downloading: http://example.webscraping.com/places/default/view/-53
# Downloading: http://example.webscraping.com/places/default/view/-54
# Downloading: http://example.webscraping.com/places/default/view/-55
# Downloading: http://example.webscraping.com/places/default/view/-56
# Downloading: http://example.webscraping.com/places/default/view/-57
# Downloading: http://example.webscraping.com/places/default/view/-58
# Downloading: http://example.webscraping.com/places/default/view/-59
# Downloading: http://example.webscraping.com/places/default/view/-60
# Downloading: http://example.webscraping.com/places/default/view/-61
# Downloading: http://example.webscraping.com/places/default/view/-62
# Downloading: http://example.webscraping.com/places/default/view/-63
# Downloading: http://example.webscraping.com/places/default/view/-64
# Downloading: http://example.webscraping.com/places/default/view/-65
# Downloading: http://example.webscraping.com/places/default/view/-66
# Downloading: http://example.webscraping.com/places/default/view/-67
# Downloading: http://example.webscraping.com/places/default/view/-68
# Downloading: http://example.webscraping.com/places/default/view/-69
# Downloading: http://example.webscraping.com/places/default/view/-70
# Downloading: http://example.webscraping.com/places/default/view/-71
# Downloading: http://example.webscraping.com/places/default/view/-72
# Downloading: http://example.webscraping.com/places/default/view/-73
# Downloading: http://example.webscraping.com/places/default/view/-74
# Downloading: http://example.webscraping.com/places/default/view/-75
# Downloading: http://example.webscraping.com/places/default/view/-76
# Downloading: http://example.webscraping.com/places/default/view/-77
# Downloading: http://example.webscraping.com/places/default/view/-78
# Downloading: http://example.webscraping.com/places/default/view/-79
# Downloading: http://example.webscraping.com/places/default/view/-80
# Downloading: http://example.webscraping.com/places/default/view/-81
# Downloading: http://example.webscraping.com/places/default/view/-82
# Downloading: http://example.webscraping.com/places/default/view/-83
# Downloading: http://example.webscraping.com/places/default/view/-84
# Downloading: http://example.webscraping.com/places/default/view/-85
# Downloading: http://example.webscraping.com/places/default/view/-86
# Downloading: http://example.webscraping.com/places/default/view/-87
# Downloading: http://example.webscraping.com/places/default/view/-88
# Downloading: http://example.webscraping.com/places/default/view/-89
# Downloading: http://example.webscraping.com/places/default/view/-90
# Downloading: http://example.webscraping.com/places/default/view/-91
# Downloading: http://example.webscraping.com/places/default/view/-92
# Downloading: http://example.webscraping.com/places/default/view/-93
# Downloading: http://example.webscraping.com/places/default/view/-94
# Downloading: http://example.webscraping.com/places/default/view/-95
# Downloading: http://example.webscraping.com/places/default/view/-96
# Downloading: http://example.webscraping.com/places/default/view/-97
# Downloading: http://example.webscraping.com/places/default/view/-98
# Downloading: http://example.webscraping.com/places/default/view/-99
# Downloading: http://example.webscraping.com/places/default/view/-100
# Downloading: http://example.webscraping.com/places/default/view/-101
# Downloading: http://example.webscraping.com/places/default/view/-102
# Downloading: http://example.webscraping.com/places/default/view/-103
# Downloading: http://example.webscraping.com/places/default/view/-104
# Downloading: http://example.webscraping.com/places/default/view/-105
# Downloading: http://example.webscraping.com/places/default/view/-106
# Downloading: http://example.webscraping.com/places/default/view/-107
# Downloading: http://example.webscraping.com/places/default/view/-108
# Downloading: http://example.webscraping.com/places/default/view/-109
# Downloading: http://example.webscraping.com/places/default/view/-110
# Downloading: http://example.webscraping.com/places/default/view/-111
# Downloading: http://example.webscraping.com/places/default/view/-112
# Downloading: http://example.webscraping.com/places/default/view/-113
# Downloading: http://example.webscraping.com/places/default/view/-114
# Downloading: http://example.webscraping.com/places/default/view/-115
# Downloading: http://example.webscraping.com/places/default/view/-116
# Downloading: http://example.webscraping.com/places/default/view/-117
# Downloading: http://example.webscraping.com/places/default/view/-118
# Downloading: http://example.webscraping.com/places/default/view/-119
# Downloading: http://example.webscraping.com/places/default/view/-120
# Downloading: http://example.webscraping.com/places/default/view/-121
# Downloading: http://example.webscraping.com/places/default/view/-122
# Downloading: http://example.webscraping.com/places/default/view/-123
# Downloading: http://example.webscraping.com/places/default/view/-124
# Downloading: http://example.webscraping.com/places/default/view/-125
# Downloading: http://example.webscraping.com/places/default/view/-126
# Downloading: http://example.webscraping.com/places/default/view/-127
# Downloading: http://example.webscraping.com/places/default/view/-128
# Downloading: http://example.webscraping.com/places/default/view/-129
# Downloading: http://example.webscraping.com/places/default/view/-130
# Downloading: http://example.webscraping.com/places/default/view/-131
# Downloading: http://example.webscraping.com/places/default/view/-132
# Downloading: http://example.webscraping.com/places/default/view/-133
# Downloading: http://example.webscraping.com/places/default/view/-134
# Downloading: http://example.webscraping.com/places/default/view/-135
# Downloading: http://example.webscraping.com/places/default/view/-136
# Downloading: http://example.webscraping.com/places/default/view/-137
# Downloading: http://example.webscraping.com/places/default/view/-138
# Downloading: http://example.webscraping.com/places/default/view/-139
# Downloading: http://example.webscraping.com/places/default/view/-140
# Downloading: http://example.webscraping.com/places/default/view/-141
# Downloading: http://example.webscraping.com/places/default/view/-142
# Downloading: http://example.webscraping.com/places/default/view/-143
# Downloading: http://example.webscraping.com/places/default/view/-144
# Downloading: http://example.webscraping.com/places/default/view/-145
# Downloading: http://example.webscraping.com/places/default/view/-146
# Downloading: http://example.webscraping.com/places/default/view/-147
# Downloading: http://example.webscraping.com/places/default/view/-148
# Downloading: http://example.webscraping.com/places/default/view/-149
# Downloading: http://example.webscraping.com/places/default/view/-150
# Downloading: http://example.webscraping.com/places/default/view/-151
# Downloading: http://example.webscraping.com/places/default/view/-152
# Downloading: http://example.webscraping.com/places/default/view/-153
# Downloading: http://example.webscraping.com/places/default/view/-154
# Downloading: http://example.webscraping.com/places/default/view/-155
# Downloading: http://example.webscraping.com/places/default/view/-156
# Downloading: http://example.webscraping.com/places/default/view/-157
# Downloading: http://example.webscraping.com/places/default/view/-158
# Downloading: http://example.webscraping.com/places/default/view/-159
# Downloading: http://example.webscraping.com/places/default/view/-160
# Downloading: http://example.webscraping.com/places/default/view/-161
# Downloading: http://example.webscraping.com/places/default/view/-162
# Downloading: http://example.webscraping.com/places/default/view/-163
# Downloading: http://example.webscraping.com/places/default/view/-164
# Downloading: http://example.webscraping.com/places/default/view/-165
# Downloading: http://example.webscraping.com/places/default/view/-166
# Downloading: http://example.webscraping.com/places/default/view/-167
# Downloading: http://example.webscraping.com/places/default/view/-168
# Downloading: http://example.webscraping.com/places/default/view/-169
# Downloading: http://example.webscraping.com/places/default/view/-170
# Downloading: http://example.webscraping.com/places/default/view/-171
# Downloading: http://example.webscraping.com/places/default/view/-172
# Downloading: http://example.webscraping.com/places/default/view/-173
# Downloading: http://example.webscraping.com/places/default/view/-174
# Downloading: http://example.webscraping.com/places/default/view/-175
# Downloading: http://example.webscraping.com/places/default/view/-176
# Downloading: http://example.webscraping.com/places/default/view/-177
# Downloading: http://example.webscraping.com/places/default/view/-178
# Downloading: http://example.webscraping.com/places/default/view/-179
# Downloading: http://example.webscraping.com/places/default/view/-180
# Downloading: http://example.webscraping.com/places/default/view/-181
# Downloading: http://example.webscraping.com/places/default/view/-182
# Downloading: http://example.webscraping.com/places/default/view/-183
# Downloading: http://example.webscraping.com/places/default/view/-184
# Downloading: http://example.webscraping.com/places/default/view/-185
# Downloading: http://example.webscraping.com/places/default/view/-186
# Downloading: http://example.webscraping.com/places/default/view/-187
# Downloading: http://example.webscraping.com/places/default/view/-188
# Downloading: http://example.webscraping.com/places/default/view/-189
# Downloading: http://example.webscraping.com/places/default/view/-190
# Downloading: http://example.webscraping.com/places/default/view/-191
# Downloading: http://example.webscraping.com/places/default/view/-192
# Downloading: http://example.webscraping.com/places/default/view/-193
# Downloading: http://example.webscraping.com/places/default/view/-194
# Downloading: http://example.webscraping.com/places/default/view/-195
# Downloading: http://example.webscraping.com/places/default/view/-196
# Downloading: http://example.webscraping.com/places/default/view/-197
# Downloading: http://example.webscraping.com/places/default/view/-198
# Downloading: http://example.webscraping.com/places/default/view/-199
# Downloading: http://example.webscraping.com/places/default/view/-200
# Downloading: http://example.webscraping.com/places/default/view/-201
# Downloading: http://example.webscraping.com/places/default/view/-202
# Downloading: http://example.webscraping.com/places/default/view/-203
# Downloading: http://example.webscraping.com/places/default/view/-204
# Downloading: http://example.webscraping.com/places/default/view/-205
# Downloading: http://example.webscraping.com/places/default/view/-206
# Downloading: http://example.webscraping.com/places/default/view/-207
# Downloading: http://example.webscraping.com/places/default/view/-208
# Downloading: http://example.webscraping.com/places/default/view/-209
# Downloading: http://example.webscraping.com/places/default/view/-210
# Downloading: http://example.webscraping.com/places/default/view/-211
# Downloading: http://example.webscraping.com/places/default/view/-212
# Downloading: http://example.webscraping.com/places/default/view/-213
# Downloading: http://example.webscraping.com/places/default/view/-214
# Downloading: http://example.webscraping.com/places/default/view/-215
# Downloading: http://example.webscraping.com/places/default/view/-216
# Downloading: http://example.webscraping.com/places/default/view/-217
# Downloading: http://example.webscraping.com/places/default/view/-218
# Downloading: http://example.webscraping.com/places/default/view/-219
# Downloading: http://example.webscraping.com/places/default/view/-220
# Downloading: http://example.webscraping.com/places/default/view/-221
# Downloading: http://example.webscraping.com/places/default/view/-222
# Downloading: http://example.webscraping.com/places/default/view/-223
# Downloading: http://example.webscraping.com/places/default/view/-224
# Downloading: http://example.webscraping.com/places/default/view/-225
# Downloading: http://example.webscraping.com/places/default/view/-226
# Downloading: http://example.webscraping.com/places/default/view/-227
# Downloading: http://example.webscraping.com/places/default/view/-228
# Downloading: http://example.webscraping.com/places/default/view/-229
# Downloading: http://example.webscraping.com/places/default/view/-230
# Downloading: http://example.webscraping.com/places/default/view/-231
# Downloading: http://example.webscraping.com/places/default/view/-232
# Downloading: http://example.webscraping.com/places/default/view/-233
# Downloading: http://example.webscraping.com/places/default/view/-234
# Downloading: http://example.webscraping.com/places/default/view/-235
# Downloading: http://example.webscraping.com/places/default/view/-236
# Downloading: http://example.webscraping.com/places/default/view/-237
# Downloading: http://example.webscraping.com/places/default/view/-238
# Downloading: http://example.webscraping.com/places/default/view/-239
# Downloading: http://example.webscraping.com/places/default/view/-240
# Downloading: http://example.webscraping.com/places/default/view/-241
# Downloading: http://example.webscraping.com/places/default/view/-242
# Downloading: http://example.webscraping.com/places/default/view/-243
# Downloading: http://example.webscraping.com/places/default/view/-244
# Downloading: http://example.webscraping.com/places/default/view/-245
# Downloading: http://example.webscraping.com/places/default/view/-246
# Downloading: http://example.webscraping.com/places/default/view/-247
# Downloading: http://example.webscraping.com/places/default/view/-248
# Downloading: http://example.webscraping.com/places/default/view/-249
# Downloading: http://example.webscraping.com/places/default/view/-250
# Downloading: http://example.webscraping.com/places/default/view/-251
# Downloading: http://example.webscraping.com/places/default/view/-252
# Downloading: http://example.webscraping.com/places/default/view/-253
# Download error: NOT FOUND
# Downloading: http://example.webscraping.com/places/default/view/-254
# Download error: NOT FOUND
# Downloading: http://example.webscraping.com/places/default/view/-255
# Download error: NOT FOUND
# Downloading: http://example.webscraping.com/places/default/view/-256
# Download error: NOT FOUND
# Downloading: http://example.webscraping.com/places/default/view/-257
# Download error: NOT FOUND

# %%
# -*- coding: utf-8 -*-
import re
import urllib.request
import urllib.error


def download(url, user_agent='wswp', num_retries=2):
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    try:
        html = urllib.request.urlopen(request).read()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                return download(url, user_agent, num_retries - 1)
    return html


def link_crawler(seed_url, link_regex):
    """Crawl from the given seed URL following links matched by link_regex
    """
    crawl_quene = [seed_url]
    while crawl_quene:
        url = crawl_quene.pop()
        html = download(url)
        # filter for links matching our regular expression
        for link in get_links(html):
            if re.match(link_regex, link):
                crawl_quene.append(link)


def get_links(html):
    """Return a list of links from html
    """
    # a regular expression to extract all links from the webpage
    webpage_regex = re.compile('<a[^>]+href=["\'](.*?)["\']', re.IGNORECASE)
    # list of all links from the webpage
    return webpage_regex.findall(html)


html = download('http://example.webscraping.com/places/default').decode()
get_links(html)
# Out:
# Downloading: http://example.webscraping.com/places/default
# ['/places/default/index',
#  '#',
#  '/places/default/user/register?_next=/places/default/index',
#  '/places/default/user/login?_next=/places/default/index',
#  '/places/default/index',
#  '/places/default/search',
#  '/places/default/view/Afghanistan-1',
#  '/places/default/view/Aland-Islands-2',
#  '/places/default/view/Albania-3',
#  '/places/default/view/Algeria-4',
#  '/places/default/view/American-Samoa-5',
#  '/places/default/view/Andorra-6',
#  '/places/default/view/Angola-7',
#  '/places/default/view/Anguilla-8',
#  '/places/default/view/Antarctica-9',
#  '/places/default/view/Antigua-and-Barbuda-10',
#  '/places/default/index/1']

# %%
# -*- coding: utf-8 -*-
import re
import urllib.request
import urllib.error


def download(url, user_agent='wswp', num_retries=2):
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    try:
        html = urllib.request.urlopen(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                return download(url, user_agent, num_retries - 1)
    return html


def link_crawler(seed_url, link_regex):
    """Crawl from the given seed URL following links matched by link_regex
    """
    crawl_quene = [seed_url]
    while crawl_quene:
        url = crawl_quene.pop()
        html = download(url)
        # filter for links matching our regular expression
        for link in get_links(html):
            if re.match(link_regex, link):
                crawl_quene.append(link)


def get_links(html):
    """Return a list of links from html
    """
    # a regular expression to extract all links from the webpage
    webpage_regex = re.compile('<a[^>]+href=["\'](.*?)["\']', re.IGNORECASE)
    # list of all links from the webpage
    return webpage_regex.findall(html)


link_crawler('http://example.webscraping.com/places/default', '/places/default/(index|view)')
# Out:
# Downloading: http://example.webscraping.com/places/default
# Downloading: /places/default/index/1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-cd8f48957bdc> in <module>()
#      43
#      44
# ---> 45 link_crawler('http://example.webscraping.com/places/default', '/places/default/(index|view)')
#
# <ipython-input-5-cd8f48957bdc> in link_crawler(seed_url, link_regex)
#      27     while crawl_quene:
#      28         url = crawl_quene.pop()
# ---> 29         html = download(url)
#      30         # filter for links matching our regular expression
#      31         for link in get_links(html):
#
# <ipython-input-5-cd8f48957bdc> in download(url, user_agent, num_retries)
#       8     print('Downloading:', url)
#       9     headers = {'User-agent': user_agent}
# ---> 10     request = urllib.request.Request(url, headers=headers)
#      11     try:
#      12         html = urllib.request.urlopen(request).read().decode()
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     327                  origin_req_host=None, unverifiable=False,
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#     331         self.unredirected_hdrs = {}
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in full_url(self, url)
#     353         self._full_url = unwrap(url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#     357     @full_url.deleter
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _parse(self)
#     382         self.type, rest = splittype(self._full_url)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#     386         if self.host:
#
# ValueError: unknown url type: '/places/default/index/1'

# %%
# -*- coding: utf-8 -*-
import re
import urllib.request
import urllib.error
import urllib.parse


def download(url, user_agent='wswp', num_retries=2):
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    try:
        html = urllib.request.urlopen(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                return download(url, user_agent, num_retries - 1)
    return html


def link_crawler(seed_url, link_regex):
    """Crawl from the given seed URL following links matched by link_regex
    """
    crawl_quene = [seed_url]
    while crawl_quene:
        url = crawl_quene.pop()
        html = download(url)
        # filter for links matching our regular expression
        for link in get_links(html):
            if re.match(link_regex, link):
                link = urllib.parse.urljoin(seed_url, link)
                crawl_quene.append(link)


def get_links(html):
    """Return a list of links from html
    """
    # a regular expression to extract all links from the webpage
    webpage_regex = re.compile('<a[^>]+href=["\'](.*?)["\']', re.IGNORECASE)
    # list of all links from the webpage
    return webpage_regex.findall(html)


link_crawler('http://example.webscraping.com', '/places/default/(index|view)')
# Out:
# Downloading: http://example.webscraping.com
# Downloading: http://example.webscraping.com/places/default/index/1
# Downloading: http://example.webscraping.com/places/default/index/2
# Downloading: http://example.webscraping.com/places/default/index/3
# Downloading: http://example.webscraping.com/places/default/index/4
# Downloading: http://example.webscraping.com/places/default/index/5
# Downloading: http://example.webscraping.com/places/default/index/6
# Downloading: http://example.webscraping.com/places/default/index/7
# Downloading: http://example.webscraping.com/places/default/index/8
# Downloading: http://example.webscraping.com/places/default/index/9
# Downloading: http://example.webscraping.com/places/default/index/10
# Downloading: http://example.webscraping.com/places/default/index/11
# Downloading: http://example.webscraping.com/places/default/index/12
# Downloading: http://example.webscraping.com/places/default/index/13
# Downloading: http://example.webscraping.com/places/default/index/14
# Downloading: http://example.webscraping.com/places/default/index/15
# Downloading: http://example.webscraping.com/places/default/index/16
# Downloading: http://example.webscraping.com/places/default/index/17
# Downloading: http://example.webscraping.com/places/default/index/18
# Downloading: http://example.webscraping.com/places/default/index/19
# Downloading: http://example.webscraping.com/places/default/index/20
# Downloading: http://example.webscraping.com/places/default/index/21
# Downloading: http://example.webscraping.com/places/default/index/22
# Downloading: http://example.webscraping.com/places/default/index/23
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/index/24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-33cb16e65852> in <module>()
#      45
#      46
# ---> 47 link_crawler('http://example.webscraping.com', '/places/default/(index|view)')
#
# <ipython-input-1-33cb16e65852> in link_crawler(seed_url, link_regex)
#      28     while crawl_quene:
#      29         url = crawl_quene.pop()
# ---> 30         html = download(url)
#      31         # filter for links matching our regular expression
#      32         for link in get_links(html):
#
# <ipython-input-1-33cb16e65852> in download(url, user_agent, num_retries)
#      11     request = urllib.request.Request(url, headers=headers)
#      12     try:
# ---> 13         html = urllib.request.urlopen(request).read().decode()
#      14     except urllib.error.URLError as e:
#      15         print('Download error:', e.reason)
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# 爬取任何网站，User-Agent必须伪装成正常浏览器的UA，爬虫类的UA极易被屏蔽或是限制。

# %%
# -*- coding: utf-8 -*-
import re
import urllib.request
import urllib.error
import urllib.parse


def download(url, user_agent='Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36', num_retries=2):
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    try:
        html = urllib.request.urlopen(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                return download(url, user_agent, num_retries - 1)
    return html


def link_crawler(seed_url, link_regex):
    """Crawl from the given seed URL following links matched by link_regex
    """
    crawl_queue = [seed_url]
    # keep track which URL's have seen before
    seen = set(crawl_queue)
    while crawl_queue:
        url = crawl_queue.pop()
        html = download(url)
        # filter for links matching our regular expression
        for link in get_links(html):
            # check if link matches expected regex
            if re.match(link_regex, link):
                # form absolute link
                link = urllib.parse.urljoin(seed_url, link)
                # check if have already seen this link
                if link not in seen:
                    seen.add(link)
                    crawl_queue.append(link)


def get_links(html):
    """Return a list of links from html
    """
    # a regular expression to extract all links from the webpage
    webpage_regex = re.compile('<a[^>]+href=["\'](.*?)["\']', re.IGNORECASE)
    # list of all links from the webpage
    return webpage_regex.findall(html)


link_crawler('http://example.webscraping.com', '/places/default/(index|view)')
# Out:
# Downloading: http://example.webscraping.com
# Downloading: http://example.webscraping.com/places/default/index/1
# Downloading: http://example.webscraping.com/places/default/index/2
# Downloading: http://example.webscraping.com/places/default/index/3
# Downloading: http://example.webscraping.com/places/default/index/4
# Downloading: http://example.webscraping.com/places/default/index/5
# Downloading: http://example.webscraping.com/places/default/index/6
# Downloading: http://example.webscraping.com/places/default/index/7
# Downloading: http://example.webscraping.com/places/default/index/8
# Downloading: http://example.webscraping.com/places/default/index/9
# Downloading: http://example.webscraping.com/places/default/index/10
# Downloading: http://example.webscraping.com/places/default/index/11
# Downloading: http://example.webscraping.com/places/default/index/12
# Downloading: http://example.webscraping.com/places/default/index/13
# Downloading: http://example.webscraping.com/places/default/index/14
# Downloading: http://example.webscraping.com/places/default/index/15
# Downloading: http://example.webscraping.com/places/default/index/16
# Downloading: http://example.webscraping.com/places/default/index/17
# Downloading: http://example.webscraping.com/places/default/index/18
# Downloading: http://example.webscraping.com/places/default/index/19
# Downloading: http://example.webscraping.com/places/default/index/20
# Downloading: http://example.webscraping.com/places/default/index/21
# Downloading: http://example.webscraping.com/places/default/index/22
# Downloading: http://example.webscraping.com/places/default/index/23
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/view/Zimbabwe-252
# Downloading: http://example.webscraping.com/places/default/view/Zambia-251
# Downloading: http://example.webscraping.com/places/default/view/Yemen-250
# Downloading: http://example.webscraping.com/places/default/view/Western-Sahara-249
# Downloading: http://example.webscraping.com/places/default/view/Wallis-and-Futuna-248
# Downloading: http://example.webscraping.com/places/default/view/Vietnam-247
# Downloading: http://example.webscraping.com/places/default/view/Venezuela-246
# Downloading: http://example.webscraping.com/places/default/view/Vatican-245
# Downloading: http://example.webscraping.com/places/default/view/Vanuatu-244
# Downloading: http://example.webscraping.com/places/default/view/Uzbekistan-243
# Downloading: http://example.webscraping.com/places/default/view/Uruguay-242
# Downloading: http://example.webscraping.com/places/default/view/United-States-Minor-Outlying-Islands-241
# Downloading: http://example.webscraping.com/places/default/view/United-States-240
# Downloading: http://example.webscraping.com/places/default/view/United-Kingdom-239
# Downloading: http://example.webscraping.com/places/default/view/United-Arab-Emirates-238
# Downloading: http://example.webscraping.com/places/default/view/Ukraine-237
# Downloading: http://example.webscraping.com/places/default/view/Uganda-236
# Downloading: http://example.webscraping.com/places/default/view/US-Virgin-Islands-235
# Downloading: http://example.webscraping.com/places/default/view/Tuvalu-234
# Downloading: http://example.webscraping.com/places/default/view/Turks-and-Caicos-Islands-233
# Downloading: http://example.webscraping.com/places/default/view/Turkmenistan-232
# Downloading: http://example.webscraping.com/places/default/view/Turkey-231
# Downloading: http://example.webscraping.com/places/default/view/Tunisia-230
# Downloading: http://example.webscraping.com/places/default/view/Trinidad-and-Tobago-229
# Downloading: http://example.webscraping.com/places/default/view/Tonga-228
# Downloading: http://example.webscraping.com/places/default/view/Tokelau-227
# Downloading: http://example.webscraping.com/places/default/view/Togo-226
# Downloading: http://example.webscraping.com/places/default/view/Thailand-225
# Downloading: http://example.webscraping.com/places/default/view/Tanzania-224
# Downloading: http://example.webscraping.com/places/default/view/Tajikistan-223
# Downloading: http://example.webscraping.com/places/default/view/Taiwan-222
# Downloading: http://example.webscraping.com/places/default/view/Syria-221
# Downloading: http://example.webscraping.com/places/default/view/Switzerland-220
# Downloading: http://example.webscraping.com/places/default/view/Sweden-219
# Downloading: http://example.webscraping.com/places/default/view/Swaziland-218
# Downloading: http://example.webscraping.com/places/default/view/Svalbard-and-Jan-Mayen-217
# Downloading: http://example.webscraping.com/places/default/view/Suriname-216
# Downloading: http://example.webscraping.com/places/default/view/Sudan-215
# Downloading: http://example.webscraping.com/places/default/view/Sri-Lanka-214
# Downloading: http://example.webscraping.com/places/default/view/Spain-213
# Downloading: http://example.webscraping.com/places/default/view/South-Sudan-212
# Downloading: http://example.webscraping.com/places/default/view/South-Korea-211
# Downloading: http://example.webscraping.com/places/default/view/South-Georgia-and-the-South-Sandwich-Islands-210
# Downloading: http://example.webscraping.com/places/default/view/South-Africa-209
# Downloading: http://example.webscraping.com/places/default/view/Somalia-208
# Downloading: http://example.webscraping.com/places/default/view/Solomon-Islands-207
# Downloading: http://example.webscraping.com/places/default/view/Slovenia-206
# Downloading: http://example.webscraping.com/places/default/view/Slovakia-205
# Downloading: http://example.webscraping.com/places/default/view/Sint-Maarten-204
# Downloading: http://example.webscraping.com/places/default/view/Singapore-203
# Downloading: http://example.webscraping.com/places/default/view/Sierra-Leone-202
# Downloading: http://example.webscraping.com/places/default/view/Seychelles-201
# Downloading: http://example.webscraping.com/places/default/view/Serbia-and-Montenegro-200
# Downloading: http://example.webscraping.com/places/default/view/Serbia-199
# Downloading: http://example.webscraping.com/places/default/view/Senegal-198
# Downloading: http://example.webscraping.com/places/default/view/Saudi-Arabia-197
# Downloading: http://example.webscraping.com/places/default/view/Sao-Tome-and-Principe-196
# Downloading: http://example.webscraping.com/places/default/view/San-Marino-195
# Downloading: http://example.webscraping.com/places/default/view/Samoa-194
# Downloading: http://example.webscraping.com/places/default/view/Saint-Vincent-and-the-Grenadines-193
# Downloading: http://example.webscraping.com/places/default/view/Saint-Pierre-and-Miquelon-192
# Downloading: http://example.webscraping.com/places/default/view/Saint-Martin-191
# Downloading: http://example.webscraping.com/places/default/view/Saint-Lucia-190
# Downloading: http://example.webscraping.com/places/default/view/Saint-Kitts-and-Nevis-189
# Downloading: http://example.webscraping.com/places/default/view/Saint-Helena-188
# Downloading: http://example.webscraping.com/places/default/view/Saint-Barthelemy-187
# Downloading: http://example.webscraping.com/places/default/view/Rwanda-186
# Downloading: http://example.webscraping.com/places/default/view/Russia-185
# Downloading: http://example.webscraping.com/places/default/view/Romania-184
# Downloading: http://example.webscraping.com/places/default/view/Reunion-183
# Downloading: http://example.webscraping.com/places/default/view/Republic-of-the-Congo-182
# Downloading: http://example.webscraping.com/places/default/view/Qatar-181
# Downloading: http://example.webscraping.com/places/default/view/Puerto-Rico-180
# Downloading: http://example.webscraping.com/places/default/view/Portugal-179
# Downloading: http://example.webscraping.com/places/default/view/Poland-178
# Downloading: http://example.webscraping.com/places/default/view/Pitcairn-177
# Downloading: http://example.webscraping.com/places/default/view/Philippines-176
# Downloading: http://example.webscraping.com/places/default/view/Peru-175
# Downloading: http://example.webscraping.com/places/default/view/Paraguay-174
# Downloading: http://example.webscraping.com/places/default/view/Papua-New-Guinea-173
# Downloading: http://example.webscraping.com/places/default/view/Panama-172
# Downloading: http://example.webscraping.com/places/default/view/Palestinian-Territory-171
# Downloading: http://example.webscraping.com/places/default/view/Palau-170
# Downloading: http://example.webscraping.com/places/default/view/Pakistan-169
# Downloading: http://example.webscraping.com/places/default/view/Oman-168
# Downloading: http://example.webscraping.com/places/default/view/Norway-167
# Downloading: http://example.webscraping.com/places/default/view/Northern-Mariana-Islands-166
# Downloading: http://example.webscraping.com/places/default/view/North-Korea-165
# Downloading: http://example.webscraping.com/places/default/view/Norfolk-Island-164
# Downloading: http://example.webscraping.com/places/default/view/Niue-163
# Downloading: http://example.webscraping.com/places/default/view/Nigeria-162
# Downloading: http://example.webscraping.com/places/default/view/Niger-161
# Downloading: http://example.webscraping.com/places/default/view/Nicaragua-160
# Downloading: http://example.webscraping.com/places/default/view/New-Zealand-159
# Downloading: http://example.webscraping.com/places/default/view/New-Caledonia-158
# Downloading: http://example.webscraping.com/places/default/view/Netherlands-Antilles-157
# Downloading: http://example.webscraping.com/places/default/view/Netherlands-156
# Downloading: http://example.webscraping.com/places/default/view/Nepal-155
# Downloading: http://example.webscraping.com/places/default/view/Nauru-154
# Downloading: http://example.webscraping.com/places/default/view/Namibia-153
# Downloading: http://example.webscraping.com/places/default/view/Myanmar-152
# Downloading: http://example.webscraping.com/places/default/view/Mozambique-151
# Downloading: http://example.webscraping.com/places/default/view/Morocco-150
# Downloading: http://example.webscraping.com/places/default/view/Montserrat-149
# Downloading: http://example.webscraping.com/places/default/view/Montenegro-148
# Downloading: http://example.webscraping.com/places/default/view/Mongolia-147
# Downloading: http://example.webscraping.com/places/default/view/Monaco-146
# Downloading: http://example.webscraping.com/places/default/view/Moldova-145
# Downloading: http://example.webscraping.com/places/default/view/Micronesia-144
# Downloading: http://example.webscraping.com/places/default/view/Mexico-143
# Downloading: http://example.webscraping.com/places/default/view/Mayotte-142
# Downloading: http://example.webscraping.com/places/default/view/Mauritius-141
# Downloading: http://example.webscraping.com/places/default/view/Mauritania-140
# Downloading: http://example.webscraping.com/places/default/view/Martinique-139
# Downloading: http://example.webscraping.com/places/default/view/Marshall-Islands-138
# Downloading: http://example.webscraping.com/places/default/view/Malta-137
# Downloading: http://example.webscraping.com/places/default/view/Mali-136
# Downloading: http://example.webscraping.com/places/default/view/Maldives-135
# Downloading: http://example.webscraping.com/places/default/view/Malaysia-134
# Downloading: http://example.webscraping.com/places/default/view/Malawi-133
# Downloading: http://example.webscraping.com/places/default/view/Madagascar-132
# Downloading: http://example.webscraping.com/places/default/view/Macedonia-131
# Downloading: http://example.webscraping.com/places/default/view/Macao-130
# Downloading: http://example.webscraping.com/places/default/view/Luxembourg-129
# Downloading: http://example.webscraping.com/places/default/view/Lithuania-128
# Downloading: http://example.webscraping.com/places/default/view/Liechtenstein-127
# Downloading: http://example.webscraping.com/places/default/view/Libya-126
# Downloading: http://example.webscraping.com/places/default/view/Liberia-125
# Downloading: http://example.webscraping.com/places/default/view/Lesotho-124
# Downloading: http://example.webscraping.com/places/default/view/Lebanon-123
# Downloading: http://example.webscraping.com/places/default/view/Latvia-122
# Downloading: http://example.webscraping.com/places/default/view/Laos-121
# Downloading: http://example.webscraping.com/places/default/view/Kyrgyzstan-120
# Downloading: http://example.webscraping.com/places/default/view/Kuwait-119
# Downloading: http://example.webscraping.com/places/default/view/Kosovo-118
# Downloading: http://example.webscraping.com/places/default/view/Kiribati-117
# Downloading: http://example.webscraping.com/places/default/view/Kenya-116
# Downloading: http://example.webscraping.com/places/default/view/Kazakhstan-115
# Downloading: http://example.webscraping.com/places/default/view/Jordan-114
# Downloading: http://example.webscraping.com/places/default/view/Jersey-113
# Downloading: http://example.webscraping.com/places/default/view/Japan-112
# Downloading: http://example.webscraping.com/places/default/view/Jamaica-111
# Downloading: http://example.webscraping.com/places/default/view/Ivory-Coast-110
# Downloading: http://example.webscraping.com/places/default/view/Italy-109
# Downloading: http://example.webscraping.com/places/default/view/Israel-108
# Downloading: http://example.webscraping.com/places/default/view/Isle-of-Man-107
# Downloading: http://example.webscraping.com/places/default/view/Ireland-106
# Downloading: http://example.webscraping.com/places/default/view/Iraq-105
# Downloading: http://example.webscraping.com/places/default/view/Iran-104
# Downloading: http://example.webscraping.com/places/default/view/Indonesia-103
# Downloading: http://example.webscraping.com/places/default/view/India-102
# Downloading: http://example.webscraping.com/places/default/view/Iceland-101
# Downloading: http://example.webscraping.com/places/default/view/Hungary-100
# Downloading: http://example.webscraping.com/places/default/view/Hong-Kong-99
# Downloading: http://example.webscraping.com/places/default/view/Honduras-98
# Downloading: http://example.webscraping.com/places/default/view/Heard-Island-and-McDonald-Islands-97
# Downloading: http://example.webscraping.com/places/default/view/Haiti-96
# Downloading: http://example.webscraping.com/places/default/view/Guyana-95
# Downloading: http://example.webscraping.com/places/default/view/Guinea-Bissau-94
# Downloading: http://example.webscraping.com/places/default/view/Guinea-93
# Downloading: http://example.webscraping.com/places/default/view/Guernsey-92
# Downloading: http://example.webscraping.com/places/default/view/Guatemala-91
# Downloading: http://example.webscraping.com/places/default/view/Guam-90
# Downloading: http://example.webscraping.com/places/default/view/Guadeloupe-89
# Downloading: http://example.webscraping.com/places/default/view/Grenada-88
# Downloading: http://example.webscraping.com/places/default/view/Greenland-87
# Downloading: http://example.webscraping.com/places/default/view/Greece-86
# Downloading: http://example.webscraping.com/places/default/view/Gibraltar-85
# Downloading: http://example.webscraping.com/places/default/view/Ghana-84
# Downloading: http://example.webscraping.com/places/default/view/Germany-83
# Downloading: http://example.webscraping.com/places/default/view/Georgia-82
# Downloading: http://example.webscraping.com/places/default/view/Gambia-81
# Downloading: http://example.webscraping.com/places/default/view/Gabon-80
# Downloading: http://example.webscraping.com/places/default/view/French-Southern-Territories-79
# Downloading: http://example.webscraping.com/places/default/view/French-Polynesia-78
# Downloading: http://example.webscraping.com/places/default/view/French-Guiana-77
# Downloading: http://example.webscraping.com/places/default/view/France-76
# Downloading: http://example.webscraping.com/places/default/view/Finland-75
# Downloading: http://example.webscraping.com/places/default/view/Fiji-74
# Downloading: http://example.webscraping.com/places/default/view/Faroe-Islands-73
# Downloading: http://example.webscraping.com/places/default/view/Falkland-Islands-72
# Downloading: http://example.webscraping.com/places/default/view/Ethiopia-71
# Downloading: http://example.webscraping.com/places/default/view/Estonia-70
# Downloading: http://example.webscraping.com/places/default/view/Eritrea-69
# Downloading: http://example.webscraping.com/places/default/view/Equatorial-Guinea-68
# Downloading: http://example.webscraping.com/places/default/view/El-Salvador-67
# Downloading: http://example.webscraping.com/places/default/view/Egypt-66
# Downloading: http://example.webscraping.com/places/default/view/Ecuador-65
# Downloading: http://example.webscraping.com/places/default/view/East-Timor-64
# Downloading: http://example.webscraping.com/places/default/view/Dominican-Republic-63
# Downloading: http://example.webscraping.com/places/default/view/Dominica-62
# Downloading: http://example.webscraping.com/places/default/view/Djibouti-61
# Downloading: http://example.webscraping.com/places/default/view/Denmark-60
# Downloading: http://example.webscraping.com/places/default/view/Democratic-Republic-of-the-Congo-59
# Downloading: http://example.webscraping.com/places/default/view/Czech-Republic-58
# Downloading: http://example.webscraping.com/places/default/view/Cyprus-57
# Downloading: http://example.webscraping.com/places/default/view/Curacao-56
# Downloading: http://example.webscraping.com/places/default/view/Cuba-55
# Downloading: http://example.webscraping.com/places/default/view/Croatia-54
# Downloading: http://example.webscraping.com/places/default/view/Costa-Rica-53
# Downloading: http://example.webscraping.com/places/default/view/Cook-Islands-52
# Downloading: http://example.webscraping.com/places/default/view/Comoros-51
# Downloading: http://example.webscraping.com/places/default/view/Colombia-50
# Downloading: http://example.webscraping.com/places/default/view/Cocos-Islands-49
# Downloading: http://example.webscraping.com/places/default/view/Christmas-Island-48
# Downloading: http://example.webscraping.com/places/default/view/China-47
# Downloading: http://example.webscraping.com/places/default/view/Chile-46
# Downloading: http://example.webscraping.com/places/default/view/Chad-45
# Downloading: http://example.webscraping.com/places/default/view/Central-African-Republic-44
# Downloading: http://example.webscraping.com/places/default/view/Cayman-Islands-43
# Downloading: http://example.webscraping.com/places/default/view/Cape-Verde-42
# Downloading: http://example.webscraping.com/places/default/view/Canada-41
# Downloading: http://example.webscraping.com/places/default/view/Cameroon-40
# Downloading: http://example.webscraping.com/places/default/view/Cambodia-39
# Downloading: http://example.webscraping.com/places/default/view/Burundi-38
# Downloading: http://example.webscraping.com/places/default/view/Burkina-Faso-37
# Downloading: http://example.webscraping.com/places/default/view/Bulgaria-36
# Downloading: http://example.webscraping.com/places/default/view/Brunei-35
# Downloading: http://example.webscraping.com/places/default/view/British-Virgin-Islands-34
# Downloading: http://example.webscraping.com/places/default/view/British-Indian-Ocean-Territory-33
# Downloading: http://example.webscraping.com/places/default/view/Brazil-32
# Downloading: http://example.webscraping.com/places/default/view/Bouvet-Island-31
# Downloading: http://example.webscraping.com/places/default/view/Botswana-30
# Downloading: http://example.webscraping.com/places/default/view/Bosnia-and-Herzegovina-29
# Downloading: http://example.webscraping.com/places/default/view/Bonaire-Saint-Eustatius-and-Saba-28
# Downloading: http://example.webscraping.com/places/default/view/Bolivia-27
# Downloading: http://example.webscraping.com/places/default/view/Bhutan-26
# Downloading: http://example.webscraping.com/places/default/view/Bermuda-25
# Downloading: http://example.webscraping.com/places/default/view/Benin-24
# Downloading: http://example.webscraping.com/places/default/view/Belize-23
# Downloading: http://example.webscraping.com/places/default/view/Belgium-22
# Downloading: http://example.webscraping.com/places/default/view/Belarus-21
# Downloading: http://example.webscraping.com/places/default/index/0
# Downloading: http://example.webscraping.com/places/default/view/Barbados-20
# Downloading: http://example.webscraping.com/places/default/view/Bangladesh-19
# Downloading: http://example.webscraping.com/places/default/view/Bahrain-18
# Downloading: http://example.webscraping.com/places/default/view/Bahamas-17
# Downloading: http://example.webscraping.com/places/default/view/Azerbaijan-16
# Downloading: http://example.webscraping.com/places/default/view/Austria-15
# Downloading: http://example.webscraping.com/places/default/view/Australia-14
# Downloading: http://example.webscraping.com/places/default/view/Aruba-13
# Downloading: http://example.webscraping.com/places/default/view/Armenia-12
# Downloading: http://example.webscraping.com/places/default/view/Argentina-11
# Downloading: http://example.webscraping.com/places/default/view/Antigua-and-Barbuda-10
# Downloading: http://example.webscraping.com/places/default/view/Antarctica-9
# Downloading: http://example.webscraping.com/places/default/view/Anguilla-8
# Downloading: http://example.webscraping.com/places/default/view/Angola-7
# Downloading: http://example.webscraping.com/places/default/view/Andorra-6
# Downloading: http://example.webscraping.com/places/default/view/American-Samoa-5
# Downloading: http://example.webscraping.com/places/default/view/Algeria-4
# Downloading: http://example.webscraping.com/places/default/view/Albania-3
# Downloading: http://example.webscraping.com/places/default/view/Aland-Islands-2
# Downloading: http://example.webscraping.com/places/default/view/Afghanistan-1
# Downloading: http://example.webscraping.com/places/default/index

# %%
import urllib.robotparser


rp = urllib.robotparser.RobotFileParser()
rp.set_url('http://example.webscraping.com/robots.txt')
rp.read()
url = 'http://example.webscraping.com'
user_agent = 'BadCrawler'
print(rp.can_fetch(user_agent, url))
user_agent = 'GoodCrawler'
print(rp.can_fetch(user_agent, url))
# Out:
# False
# True

# %%
# -*- coding: utf-8 -*-
import re
import urllib.request
import urllib.error
import urllib.parse
import urllib.robotparser
import time


user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36'
rp = urllib.robotparser.RobotFileParser()
rp.set_url('http://example.webscraping.com/robots.txt')
rp.read()


def download(url, user_agent=user_agent, num_retries=2):
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    try:
        html = urllib.request.urlopen(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                return download(url, user_agent, num_retries - 1)
    return html


def link_crawler(seed_url, link_regex):
    """Crawl from the given seed URL following links matched by link_regex
    """
    crawl_queue = [seed_url]
    # keep track which URL's have seen before
    seen = set(crawl_queue)
    while crawl_queue:
        url = crawl_queue.pop()
        # check url passes robots.txt restrictions
        if rp.can_fetch(user_agent, url):
            time.sleep(1)
            html = download(url)
        else:
            print('Blocked by robots.txt:', url)
            html = None
        # filter for links matching our regular expression
        for link in get_links(html):
            # check if link matches expected regex
            if re.match(link_regex, link):
                # form absolute link
                link = urllib.parse.urljoin(seed_url, link)
                # check if have already seen this link
                if link not in seen:
                    seen.add(link)
                    crawl_queue.append(link)


def get_links(html):
    """Return a list of links from html
    """
    # a regular expression to extract all links from the webpage
    webpage_regex = re.compile('<a[^>]+href=["\'](.*?)["\']', re.IGNORECASE)
    # list of all links from the webpage
    return webpage_regex.findall(html)


link_crawler('http://example.webscraping.com', '/places/default/(index|view)')
# Out:
# Downloading: http://example.webscraping.com
# Downloading: http://example.webscraping.com/places/default/index/1
# Downloading: http://example.webscraping.com/places/default/index/2
# Downloading: http://example.webscraping.com/places/default/index/3
# Downloading: http://example.webscraping.com/places/default/index/4
# Downloading: http://example.webscraping.com/places/default/index/5
# Downloading: http://example.webscraping.com/places/default/index/6
# Downloading: http://example.webscraping.com/places/default/index/7
# Downloading: http://example.webscraping.com/places/default/index/8
# Downloading: http://example.webscraping.com/places/default/index/9
# Downloading: http://example.webscraping.com/places/default/index/10
# Downloading: http://example.webscraping.com/places/default/index/11
# Downloading: http://example.webscraping.com/places/default/index/12
# Downloading: http://example.webscraping.com/places/default/index/13
# Downloading: http://example.webscraping.com/places/default/index/14
# Downloading: http://example.webscraping.com/places/default/index/15
# Downloading: http://example.webscraping.com/places/default/index/16
# Downloading: http://example.webscraping.com/places/default/index/17
# Downloading: http://example.webscraping.com/places/default/index/18
# Downloading: http://example.webscraping.com/places/default/index/19
# Downloading: http://example.webscraping.com/places/default/index/20
# Downloading: http://example.webscraping.com/places/default/index/21
# Downloading: http://example.webscraping.com/places/default/index/22
# Downloading: http://example.webscraping.com/places/default/index/23
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/view/Zimbabwe-252
# Downloading: http://example.webscraping.com/places/default/view/Zambia-251
# Downloading: http://example.webscraping.com/places/default/view/Yemen-250
# Downloading: http://example.webscraping.com/places/default/view/Western-Sahara-249
# Downloading: http://example.webscraping.com/places/default/view/Wallis-and-Futuna-248
# Downloading: http://example.webscraping.com/places/default/view/Vietnam-247
# Downloading: http://example.webscraping.com/places/default/view/Venezuela-246
# Downloading: http://example.webscraping.com/places/default/view/Vatican-245
# Downloading: http://example.webscraping.com/places/default/view/Vanuatu-244
# Downloading: http://example.webscraping.com/places/default/view/Uzbekistan-243
# Downloading: http://example.webscraping.com/places/default/view/Uruguay-242
# Downloading: http://example.webscraping.com/places/default/view/United-States-Minor-Outlying-Islands-241
# Downloading: http://example.webscraping.com/places/default/view/United-States-240
# Downloading: http://example.webscraping.com/places/default/view/United-Kingdom-239
# Downloading: http://example.webscraping.com/places/default/view/United-Arab-Emirates-238
# Downloading: http://example.webscraping.com/places/default/view/Ukraine-237
# Downloading: http://example.webscraping.com/places/default/view/Uganda-236
# Downloading: http://example.webscraping.com/places/default/view/US-Virgin-Islands-235
# Downloading: http://example.webscraping.com/places/default/view/Tuvalu-234
# Downloading: http://example.webscraping.com/places/default/view/Turks-and-Caicos-Islands-233
# Downloading: http://example.webscraping.com/places/default/view/Turkmenistan-232
# Downloading: http://example.webscraping.com/places/default/view/Turkey-231
# Downloading: http://example.webscraping.com/places/default/view/Tunisia-230
# Downloading: http://example.webscraping.com/places/default/view/Trinidad-and-Tobago-229
# Downloading: http://example.webscraping.com/places/default/view/Tonga-228
# Downloading: http://example.webscraping.com/places/default/view/Tokelau-227
# Downloading: http://example.webscraping.com/places/default/view/Togo-226
# Downloading: http://example.webscraping.com/places/default/view/Thailand-225
# Downloading: http://example.webscraping.com/places/default/view/Tanzania-224
# Downloading: http://example.webscraping.com/places/default/view/Tajikistan-223
# Downloading: http://example.webscraping.com/places/default/view/Taiwan-222
# Downloading: http://example.webscraping.com/places/default/view/Syria-221
# Downloading: http://example.webscraping.com/places/default/view/Switzerland-220
# Downloading: http://example.webscraping.com/places/default/view/Sweden-219
# Downloading: http://example.webscraping.com/places/default/view/Swaziland-218
# Downloading: http://example.webscraping.com/places/default/view/Svalbard-and-Jan-Mayen-217
# Downloading: http://example.webscraping.com/places/default/view/Suriname-216
# Downloading: http://example.webscraping.com/places/default/view/Sudan-215
# Downloading: http://example.webscraping.com/places/default/view/Sri-Lanka-214
# Downloading: http://example.webscraping.com/places/default/view/Spain-213
# Downloading: http://example.webscraping.com/places/default/view/South-Sudan-212
# Downloading: http://example.webscraping.com/places/default/view/South-Korea-211
# Downloading: http://example.webscraping.com/places/default/view/South-Georgia-and-the-South-Sandwich-Islands-210
# Downloading: http://example.webscraping.com/places/default/view/South-Africa-209
# Downloading: http://example.webscraping.com/places/default/view/Somalia-208
# Downloading: http://example.webscraping.com/places/default/view/Solomon-Islands-207
# Downloading: http://example.webscraping.com/places/default/view/Slovenia-206
# Downloading: http://example.webscraping.com/places/default/view/Slovakia-205
# Downloading: http://example.webscraping.com/places/default/view/Sint-Maarten-204
# Downloading: http://example.webscraping.com/places/default/view/Singapore-203
# Downloading: http://example.webscraping.com/places/default/view/Sierra-Leone-202
# Downloading: http://example.webscraping.com/places/default/view/Seychelles-201
# Downloading: http://example.webscraping.com/places/default/view/Serbia-and-Montenegro-200
# Downloading: http://example.webscraping.com/places/default/view/Serbia-199
# Downloading: http://example.webscraping.com/places/default/view/Senegal-198
# Downloading: http://example.webscraping.com/places/default/view/Saudi-Arabia-197
# Downloading: http://example.webscraping.com/places/default/view/Sao-Tome-and-Principe-196
# Downloading: http://example.webscraping.com/places/default/view/San-Marino-195
# Downloading: http://example.webscraping.com/places/default/view/Samoa-194
# Downloading: http://example.webscraping.com/places/default/view/Saint-Vincent-and-the-Grenadines-193
# Downloading: http://example.webscraping.com/places/default/view/Saint-Pierre-and-Miquelon-192
# Downloading: http://example.webscraping.com/places/default/view/Saint-Martin-191
# Downloading: http://example.webscraping.com/places/default/view/Saint-Lucia-190
# Downloading: http://example.webscraping.com/places/default/view/Saint-Kitts-and-Nevis-189
# Downloading: http://example.webscraping.com/places/default/view/Saint-Helena-188
# Downloading: http://example.webscraping.com/places/default/view/Saint-Barthelemy-187
# Downloading: http://example.webscraping.com/places/default/view/Rwanda-186
# Downloading: http://example.webscraping.com/places/default/view/Russia-185
# Downloading: http://example.webscraping.com/places/default/view/Romania-184
# Downloading: http://example.webscraping.com/places/default/view/Reunion-183
# Downloading: http://example.webscraping.com/places/default/view/Republic-of-the-Congo-182
# Downloading: http://example.webscraping.com/places/default/view/Qatar-181
# Downloading: http://example.webscraping.com/places/default/view/Puerto-Rico-180
# Downloading: http://example.webscraping.com/places/default/view/Portugal-179
# Downloading: http://example.webscraping.com/places/default/view/Poland-178
# Downloading: http://example.webscraping.com/places/default/view/Pitcairn-177
# Downloading: http://example.webscraping.com/places/default/view/Philippines-176
# Downloading: http://example.webscraping.com/places/default/view/Peru-175
# Downloading: http://example.webscraping.com/places/default/view/Paraguay-174
# Downloading: http://example.webscraping.com/places/default/view/Papua-New-Guinea-173
# Downloading: http://example.webscraping.com/places/default/view/Panama-172
# Downloading: http://example.webscraping.com/places/default/view/Palestinian-Territory-171
# Downloading: http://example.webscraping.com/places/default/view/Palau-170
# Downloading: http://example.webscraping.com/places/default/view/Pakistan-169
# Downloading: http://example.webscraping.com/places/default/view/Oman-168
# Downloading: http://example.webscraping.com/places/default/view/Norway-167
# Downloading: http://example.webscraping.com/places/default/view/Northern-Mariana-Islands-166
# Downloading: http://example.webscraping.com/places/default/view/North-Korea-165
# Downloading: http://example.webscraping.com/places/default/view/Norfolk-Island-164
# Downloading: http://example.webscraping.com/places/default/view/Niue-163
# Downloading: http://example.webscraping.com/places/default/view/Nigeria-162
# Downloading: http://example.webscraping.com/places/default/view/Niger-161
# Downloading: http://example.webscraping.com/places/default/view/Nicaragua-160
# Downloading: http://example.webscraping.com/places/default/view/New-Zealand-159
# Downloading: http://example.webscraping.com/places/default/view/New-Caledonia-158
# Downloading: http://example.webscraping.com/places/default/view/Netherlands-Antilles-157
# Downloading: http://example.webscraping.com/places/default/view/Netherlands-156
# Downloading: http://example.webscraping.com/places/default/view/Nepal-155
# Downloading: http://example.webscraping.com/places/default/view/Nauru-154
# Downloading: http://example.webscraping.com/places/default/view/Namibia-153
# Downloading: http://example.webscraping.com/places/default/view/Myanmar-152
# Downloading: http://example.webscraping.com/places/default/view/Mozambique-151
# Downloading: http://example.webscraping.com/places/default/view/Morocco-150
# Downloading: http://example.webscraping.com/places/default/view/Montserrat-149
# Downloading: http://example.webscraping.com/places/default/view/Montenegro-148
# Downloading: http://example.webscraping.com/places/default/view/Mongolia-147
# Downloading: http://example.webscraping.com/places/default/view/Monaco-146
# Downloading: http://example.webscraping.com/places/default/view/Moldova-145
# Downloading: http://example.webscraping.com/places/default/view/Micronesia-144
# Downloading: http://example.webscraping.com/places/default/view/Mexico-143
# Downloading: http://example.webscraping.com/places/default/view/Mayotte-142
# Downloading: http://example.webscraping.com/places/default/view/Mauritius-141
# Downloading: http://example.webscraping.com/places/default/view/Mauritania-140
# Downloading: http://example.webscraping.com/places/default/view/Martinique-139
# Downloading: http://example.webscraping.com/places/default/view/Marshall-Islands-138
# Downloading: http://example.webscraping.com/places/default/view/Malta-137
# Downloading: http://example.webscraping.com/places/default/view/Mali-136
# Downloading: http://example.webscraping.com/places/default/view/Maldives-135
# Downloading: http://example.webscraping.com/places/default/view/Malaysia-134
# Downloading: http://example.webscraping.com/places/default/view/Malawi-133
# Downloading: http://example.webscraping.com/places/default/view/Madagascar-132
# Downloading: http://example.webscraping.com/places/default/view/Macedonia-131
# Downloading: http://example.webscraping.com/places/default/view/Macao-130
# Downloading: http://example.webscraping.com/places/default/view/Luxembourg-129
# Downloading: http://example.webscraping.com/places/default/view/Lithuania-128
# Downloading: http://example.webscraping.com/places/default/view/Liechtenstein-127
# Downloading: http://example.webscraping.com/places/default/view/Libya-126
# Downloading: http://example.webscraping.com/places/default/view/Liberia-125
# Downloading: http://example.webscraping.com/places/default/view/Lesotho-124
# Downloading: http://example.webscraping.com/places/default/view/Lebanon-123
# Downloading: http://example.webscraping.com/places/default/view/Latvia-122
# Downloading: http://example.webscraping.com/places/default/view/Laos-121
# Downloading: http://example.webscraping.com/places/default/view/Kyrgyzstan-120
# Downloading: http://example.webscraping.com/places/default/view/Kuwait-119
# Downloading: http://example.webscraping.com/places/default/view/Kosovo-118
# Downloading: http://example.webscraping.com/places/default/view/Kiribati-117
# Downloading: http://example.webscraping.com/places/default/view/Kenya-116
# Downloading: http://example.webscraping.com/places/default/view/Kazakhstan-115
# Downloading: http://example.webscraping.com/places/default/view/Jordan-114
# Downloading: http://example.webscraping.com/places/default/view/Jersey-113
# Downloading: http://example.webscraping.com/places/default/view/Japan-112
# Downloading: http://example.webscraping.com/places/default/view/Jamaica-111
# Downloading: http://example.webscraping.com/places/default/view/Ivory-Coast-110
# Downloading: http://example.webscraping.com/places/default/view/Italy-109
# Downloading: http://example.webscraping.com/places/default/view/Israel-108
# Downloading: http://example.webscraping.com/places/default/view/Isle-of-Man-107
# Downloading: http://example.webscraping.com/places/default/view/Ireland-106
# Downloading: http://example.webscraping.com/places/default/view/Iraq-105
# Downloading: http://example.webscraping.com/places/default/view/Iran-104
# Downloading: http://example.webscraping.com/places/default/view/Indonesia-103
# Downloading: http://example.webscraping.com/places/default/view/India-102
# Downloading: http://example.webscraping.com/places/default/view/Iceland-101
# Downloading: http://example.webscraping.com/places/default/view/Hungary-100
# Downloading: http://example.webscraping.com/places/default/view/Hong-Kong-99
# Downloading: http://example.webscraping.com/places/default/view/Honduras-98
# Downloading: http://example.webscraping.com/places/default/view/Heard-Island-and-McDonald-Islands-97
# Downloading: http://example.webscraping.com/places/default/view/Haiti-96
# Downloading: http://example.webscraping.com/places/default/view/Guyana-95
# Downloading: http://example.webscraping.com/places/default/view/Guinea-Bissau-94
# Downloading: http://example.webscraping.com/places/default/view/Guinea-93
# Downloading: http://example.webscraping.com/places/default/view/Guernsey-92
# Downloading: http://example.webscraping.com/places/default/view/Guatemala-91
# Downloading: http://example.webscraping.com/places/default/view/Guam-90
# Downloading: http://example.webscraping.com/places/default/view/Guadeloupe-89
# Downloading: http://example.webscraping.com/places/default/view/Grenada-88
# Downloading: http://example.webscraping.com/places/default/view/Greenland-87
# Downloading: http://example.webscraping.com/places/default/view/Greece-86
# Downloading: http://example.webscraping.com/places/default/view/Gibraltar-85
# Downloading: http://example.webscraping.com/places/default/view/Ghana-84
# Downloading: http://example.webscraping.com/places/default/view/Germany-83
# Downloading: http://example.webscraping.com/places/default/view/Georgia-82
# Downloading: http://example.webscraping.com/places/default/view/Gambia-81
# Downloading: http://example.webscraping.com/places/default/view/Gabon-80
# Downloading: http://example.webscraping.com/places/default/view/French-Southern-Territories-79
# Downloading: http://example.webscraping.com/places/default/view/French-Polynesia-78
# Downloading: http://example.webscraping.com/places/default/view/French-Guiana-77
# Downloading: http://example.webscraping.com/places/default/view/France-76
# Downloading: http://example.webscraping.com/places/default/view/Finland-75
# Downloading: http://example.webscraping.com/places/default/view/Fiji-74
# Downloading: http://example.webscraping.com/places/default/view/Faroe-Islands-73
# Downloading: http://example.webscraping.com/places/default/view/Falkland-Islands-72
# Downloading: http://example.webscraping.com/places/default/view/Ethiopia-71
# Downloading: http://example.webscraping.com/places/default/view/Estonia-70
# Downloading: http://example.webscraping.com/places/default/view/Eritrea-69
# Downloading: http://example.webscraping.com/places/default/view/Equatorial-Guinea-68
# Downloading: http://example.webscraping.com/places/default/view/El-Salvador-67
# Downloading: http://example.webscraping.com/places/default/view/Egypt-66
# Downloading: http://example.webscraping.com/places/default/view/Ecuador-65
# Downloading: http://example.webscraping.com/places/default/view/East-Timor-64
# Downloading: http://example.webscraping.com/places/default/view/Dominican-Republic-63
# Downloading: http://example.webscraping.com/places/default/view/Dominica-62
# Downloading: http://example.webscraping.com/places/default/view/Djibouti-61
# Downloading: http://example.webscraping.com/places/default/view/Denmark-60
# Downloading: http://example.webscraping.com/places/default/view/Democratic-Republic-of-the-Congo-59
# Downloading: http://example.webscraping.com/places/default/view/Czech-Republic-58
# Downloading: http://example.webscraping.com/places/default/view/Cyprus-57
# Downloading: http://example.webscraping.com/places/default/view/Curacao-56
# Downloading: http://example.webscraping.com/places/default/view/Cuba-55
# Downloading: http://example.webscraping.com/places/default/view/Croatia-54
# Downloading: http://example.webscraping.com/places/default/view/Costa-Rica-53
# Downloading: http://example.webscraping.com/places/default/view/Cook-Islands-52
# Downloading: http://example.webscraping.com/places/default/view/Comoros-51
# Downloading: http://example.webscraping.com/places/default/view/Colombia-50
# Downloading: http://example.webscraping.com/places/default/view/Cocos-Islands-49
# Downloading: http://example.webscraping.com/places/default/view/Christmas-Island-48
# Downloading: http://example.webscraping.com/places/default/view/China-47
# Downloading: http://example.webscraping.com/places/default/view/Chile-46
# Downloading: http://example.webscraping.com/places/default/view/Chad-45
# Downloading: http://example.webscraping.com/places/default/view/Central-African-Republic-44
# Downloading: http://example.webscraping.com/places/default/view/Cayman-Islands-43
# Downloading: http://example.webscraping.com/places/default/view/Cape-Verde-42
# Downloading: http://example.webscraping.com/places/default/view/Canada-41
# Downloading: http://example.webscraping.com/places/default/view/Cameroon-40
# Downloading: http://example.webscraping.com/places/default/view/Cambodia-39
# Downloading: http://example.webscraping.com/places/default/view/Burundi-38
# Downloading: http://example.webscraping.com/places/default/view/Burkina-Faso-37
# Downloading: http://example.webscraping.com/places/default/view/Bulgaria-36
# Downloading: http://example.webscraping.com/places/default/view/Brunei-35
# Downloading: http://example.webscraping.com/places/default/view/British-Virgin-Islands-34
# Downloading: http://example.webscraping.com/places/default/view/British-Indian-Ocean-Territory-33
# Downloading: http://example.webscraping.com/places/default/view/Brazil-32
# Downloading: http://example.webscraping.com/places/default/view/Bouvet-Island-31
# Downloading: http://example.webscraping.com/places/default/view/Botswana-30
# Downloading: http://example.webscraping.com/places/default/view/Bosnia-and-Herzegovina-29
# Downloading: http://example.webscraping.com/places/default/view/Bonaire-Saint-Eustatius-and-Saba-28
# Downloading: http://example.webscraping.com/places/default/view/Bolivia-27
# Downloading: http://example.webscraping.com/places/default/view/Bhutan-26
# Downloading: http://example.webscraping.com/places/default/view/Bermuda-25
# Downloading: http://example.webscraping.com/places/default/view/Benin-24
# Downloading: http://example.webscraping.com/places/default/view/Belize-23
# Downloading: http://example.webscraping.com/places/default/view/Belgium-22
# Downloading: http://example.webscraping.com/places/default/view/Belarus-21
# Downloading: http://example.webscraping.com/places/default/index/0
# Downloading: http://example.webscraping.com/places/default/view/Barbados-20
# Downloading: http://example.webscraping.com/places/default/view/Bangladesh-19
# Downloading: http://example.webscraping.com/places/default/view/Bahrain-18
# Downloading: http://example.webscraping.com/places/default/view/Bahamas-17
# Downloading: http://example.webscraping.com/places/default/view/Azerbaijan-16
# Downloading: http://example.webscraping.com/places/default/view/Austria-15
# Downloading: http://example.webscraping.com/places/default/view/Australia-14
# Downloading: http://example.webscraping.com/places/default/view/Aruba-13
# Downloading: http://example.webscraping.com/places/default/view/Armenia-12
# Downloading: http://example.webscraping.com/places/default/view/Argentina-11
# Downloading: http://example.webscraping.com/places/default/view/Antigua-and-Barbuda-10
# Downloading: http://example.webscraping.com/places/default/view/Antarctica-9
# Downloading: http://example.webscraping.com/places/default/view/Anguilla-8
# Downloading: http://example.webscraping.com/places/default/view/Angola-7
# Downloading: http://example.webscraping.com/places/default/view/Andorra-6
# Downloading: http://example.webscraping.com/places/default/view/American-Samoa-5
# Downloading: http://example.webscraping.com/places/default/view/Algeria-4
# Downloading: http://example.webscraping.com/places/default/view/Albania-3
# Downloading: http://example.webscraping.com/places/default/view/Aland-Islands-2
# Downloading: http://example.webscraping.com/places/default/view/Afghanistan-1
# Downloading: http://example.webscraping.com/places/default/index

# %% [markdown]
# ##### 支持代理的Python 3代码

# %%
# coding=utf-8

from urllib.parse import urlparse
from urllib.request import Request, build_opener, ProxyHandler
from bs4 import BeautifulSoup

url = 'http://ip138.com'
_headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:58.0) Gecko/20100101 Firefox/58.0'}

proxy = '127.0.0.1:1080'
opener = build_opener()
proxy_params = {urlparse(url).scheme: proxy}
opener.add_handler(ProxyHandler(proxy_params))
req = Request(url, headers=_headers)
page = opener.open(req).read()
soup = BeautifulSoup(page, 'lxml')
target = soup.find_all('iframe')
for iframe in target:
    src_page = opener.open(Request(iframe.attrs['src'], headers=_headers))
    iframe_soup = BeautifulSoup(src_page, 'lxml')
    print(iframe_soup.center.get_text())
# Out:
# 您的IP是：[45.77.166.94] 来自：美国

# %%
# coding=utf-8

from urllib.request import Request, build_opener, ProxyHandler
from urllib.parse import urlparse
from bs4 import BeautifulSoup

url = 'https://www.whatismybrowser.com/'
_headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:58.0) Gecko/20100101 Firefox/58.0'}

# Proxy setting start
proxy = '127.0.0.1:1080'
opener = build_opener()
proxy_params = {urlparse(url).scheme: proxy}
opener.add_handler(ProxyHandler(proxy_params))
# Proxy setting end

req = Request(url, headers=_headers)
page = opener.open(req).read()
soup = BeautifulSoup(page, 'lxml')
target_div = soup.find_all('div', class_="user-agent")[0].a.get_text()
print(target_div)
# Out:
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:58.0) Gecko/20100101 Firefox/58.0

# %%
from urllib.request import Request, build_opener, ProxyHandler
from urllib.parse import urlparse

from bs4 import BeautifulSoup

url = 'https://www.youtube.com'
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}

# Proxy setting start
proxy = '127.0.0.1:1080'
proxy_params = {urlparse(url).scheme: proxy}
opener = build_opener()
opener.add_handler(ProxyHandler(proxy_params))
# Proxy setting end

req = Request(url, headers=headers)
page = opener.open(req).read()
soup = BeautifulSoup(page, 'lxml')
print(soup.title.contents[0])
# Out:
# YouTube

# %%
from urllib.request import Request, build_opener, ProxyHandler
from urllib.parse import urlparse

from bs4 import BeautifulSoup

url = 'https://twitter.com'
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}

# Proxy setting start
proxy = '127.0.0.1:1080'
proxy_params = {urlparse(url).scheme: proxy}
opener = build_opener()
opener.add_handler(ProxyHandler(proxy_params))
# Proxy setting end

req = Request(url, headers=headers)
page = opener.open(req).read()
soup = BeautifulSoup(page, 'lxml')
print(soup.title.contents[0])
# Out:
# Twitter. It's what's happening.

# %% [markdown]
# #### 支持代理、自定义User-Agent、异常检测及自动下载重试的download函数

# %%
# -*- coding: utf-8 -*-

import urllib.request
import urllib.parse
import urllib.error


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


ua = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
url= 'https://www.facebook.com'

# Proxy setting start
proxy = '127.0.0.1:1087'  # macOS上的shadowsocksX-NG
proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
opener = urllib.request.build_opener()
opener.add_handler(urllib.request.ProxyHandler(proxy_params))
# Proxy setting end

download(url, ua, proxy)
# Out:
# Downloading: https://www.facebook.com
# b'<!DOCTYPE html>\n<html lang="en" id="facebook" class="no_js">\n<head><meta charset="utf-8" /><meta name="referrer" content="origin-when-crossorigin" id="meta_referrer" /><script>window._cstart=+new Date();</script><script>function envFlush(a){function b(b){for(var c in a)b[c]=a[c]}window.requireLazy?window.requireLazy(["Env"],b):(window.Env=window.Env||{},b(window.Env))}envFlush({"ajaxpipe_token":"AXgTZmO57XER_mQn","timeslice_heartbeat_config":{"pollIntervalMs":33,"idleGapThresholdMs":60,"ignoredTimesliceNames":{"requestAnimationFrame":true,"Event listenHandler mousemove":true,"Event listenHandler mouseover":true,"Event listenHandler mouseout":true,"Event listenHandler scroll":true},"isHeartbeatEnabled":true,"isArtilleryOn":false},"shouldLogCounters":true,"timeslice_categories":{"react_render":true,"reflow":true},"sample_continuation_stacktraces":true,"dom_mutation_flag":true,"khsh":"0`sj`e`rm`s-0fdu^gshdoer-0gc^eurf-3gc^eurf;1;enbtldou;fduDmdldourCxO`ld-2YLMIuuqSdptdru;qsnunuxqd;rdoe-0unjdojnx-0unjdojnx0-0gdubi^rdbsduOdv-0`sj`e`r-0q`xm`r-0StoRbs`qhof-0mhoj^q`xm`r","stack_trace_limit":30,"timesliceBufferSize":5000});</script><style></style><script>__DEV__=0;CavalryLogger=window.CavalryLogger||function(a){this.lid=a,this.transition=!1,this.metric_collected=!1,this.is_detailed_profiler=!1,this.instrumentation_started=!1,this.pagelet_metrics={},this.events={},this.ongoing_watch={},this.values={t_cstart:window._cstart},this.piggy_values={},this.bootloader_metrics={},this.resource_to_pagelet_mapping={},this.e2eLogged=!1,this.initializeInstrumentation&&this.initializeInstrumentation()},CavalryLogger.prototype.setIsDetailedProfiler=function(a){this.is_detailed_profiler=a;return this},CavalryLogger.prototype.setTTIEvent=function(a){this.tti_event=a;return this},CavalryLogger.prototype.setValue=function(a,b,c,d){d=d?this.piggy_values:this.values;(typeof d[a]=="undefined"||c)&&(d[a]=b);return this},CavalryLogger.prototype.getLastTtiValue=function(){return this.lastTtiValue},CavalryLogger.prototype.setTimeStamp=CavalryLogger.prototype.setTimeStamp||function(a,b,c,d){this.mark(a);var e=this.values.t_cstart||this.values.t_start;e=d?e+d:CavalryLogger.now();this.setValue(a,e,b,c);this.tti_event&&a==this.tti_event&&(this.lastTtiValue=e,this.setTimeStamp("t_tti",b));return this},CavalryLogger.prototype.mark=typeof console==="object"&&console.timeStamp?function(a){console.timeStamp(a)}:function(){},CavalryLogger.prototype.addPiggyback=function(a,b){this.piggy_values[a]=b;return this},CavalryLogger.instances={},CavalryLogger.id=0,CavalryLogger.perfNubMarkup="",CavalryLogger.disableArtilleryOnUntilOffLogging=!1,CavalryLogger.getInstance=function(a){typeof a=="undefined"&&(a=CavalryLogger.id);CavalryLogger.instances[a]||(CavalryLogger.instances[a]=new CavalryLogger(a));return CavalryLogger.instances[a]},CavalryLogger.setPageID=function(a){if(CavalryLogger.id===0){var b=CavalryLogger.getInstance();CavalryLogger.instances[a]=b;CavalryLogger.instances[a].lid=a;delete CavalryLogger.instances[0]}CavalryLogger.id=a},CavalryLogger.setPerfNubMarkup=function(a){CavalryLogger.perfNubMarkup=a},CavalryLogger.now=function(){return window.performance&&performance.timing&&performance.timing.navigationStart&&performance.now?performance.now()+performance.timing.navigationStart:new Date().getTime()},CavalryLogger.prototype.measureResources=function(){},CavalryLogger.prototype.profileEarlyResources=function(){},CavalryLogger.getBootloaderMetricsFromAllLoggers=function(){},CavalryLogger.start_js=function(){},CavalryLogger.done_js=function(){};CavalryLogger.getInstance().setTTIEvent("t_domcontent");CavalryLogger.prototype.measureResources=function(a,b){if(!this.log_resources)return;var c="bootload/"+a.name;if(this.bootloader_metrics[c]!==undefined||this.ongoing_watch[c]!==undefined)return;var d=CavalryLogger.now();this.ongoing_watch[c]=d;"start_"+c in this.bootloader_metrics||(this.bootloader_metrics["start_"+c]=d);b&&!("tag_"+c in this.bootloader_metrics)&&(this.bo ...

# %%
# -*- coding: utf-8 -*-

import urllib.request
import urllib.parse
import urllib.error


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    '''Support custom User-Agent, proxy and auto retry
    '''
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


url= 'https://twitter.com'
ua = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
proxy = '127.0.0.1:1080'  # Windows上的shadowsocks

download(url, ua, proxy, 2)
# Out:
# Downloading: https://twitter.com
# '<!DOCTYPE html>\n<html lang="en" data-scribe-reduced-action-queue="true">\n  <head>\n    \n    \n    \n    \n    \n    \n    \n    <meta charset="utf-8">\n      <script  nonce="Bm1LfJ9aIvgEEcCwOidQ5Q==">\n        !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();\n      </script>\n    \n    \n  \n  <script id="bouncer_terminate_iframe" nonce="Bm1LfJ9aIvgEEcCwOidQ5Q==">\n    if (window.top != window) {\n  window.top.postMessage({\'bouncer\': true, \'event\': \'complete\'}, \'*\');\n}\n  </script>\n  <script id="resolve_inline_redirects" nonce="Bm1LfJ9aIvgEEcCwOidQ5Q==">\n    !function(){function n(){var n=window.location.href.match(/#(.)(.*)$/);return n&&"!"==n[1]&&n[2].replace(/^\\//,"")}function t(){var t=n();t&&window.location.replace("//"+window.location.host+"/"+t)}t(),window.addEventListener?window.addEventListener("hashchange",t,!1):window.attachEvent&&window.attachEvent("onhashchange",t)}();\n  </script>\n  <script id="ttft_boot_data" nonce="Bm1LfJ9aIvgEEcCwOidQ5Q==">\n    window.ttftData={"transaction_id":"00edb553005c44fc.5e14d986d4543135\\u003c:0094b4dd0002949d","server_request_start_time":1530176978785,"user_id":null,"is_ssl":true,"rendered_on_server":true,"is_tfe":true,"client":"macaw-swift","tfe_version":"tsa_c\\/1.0.1\\/20180606.1803.b14e74d","ttft_browser":"chrome"};!function(){function t(t,n){window.ttftData&&!window.ttftData[t]&&(window.ttftData[t]=n)}function n(){return o?Math.round(w.now()+w.timing.navigationStart):(new Date).getTime()}var w=window.performance,o=w&&w.now;window.ttft||(window.ttft={}),window.ttft.recordMilestone||(window.ttft.recordMilestone=t),window.ttft.now||(window.ttft.now=n)}();\n  </script>\n  <script id="swift_action_queue" nonce="Bm1LfJ9aIvgEEcCwOidQ5Q==">\n    !function(){function e(e){if(e||(e=window.event),!e)return!1;if(e.timestamp=(new Date).getTime(),!e.target&&e.srcElement&&(e.target=e.srcElement),document.documentElement.getAttribute("data-scribe-reduced-action-queue"))for(var t=e.target;t&&t!=document.body;){if("A"==t.tagName)return;t=t.parentNode}return i("all",o(e)),a(e)?(document.addEventListener||(e=o(e)),e.preventDefault=e.stopPropagation=e.stopImmediatePropagation=function(){},y?(v.push(e),i("captured",e)):i("ignored",e),!1):(i("direct",e),!0)}function t(e){n();for(var t,r=0;t=v[r];r++){var a=e(t.target),i=a.closest("a")[0];if("click"==t.type&&i){var o=e.data(i,"events"),u=o&&o.click,c=!i.hostname.match(g)||!i.href.match(/#$/);if(!u&&c){window.location=i.href;continue}}a.trigger(e.event.fix(t))}window.swiftActionQueue.wasFlushed=!0}function r(){for(var e in b)if("all"!=e)for(var t=b[e],r=0;r<t.length;r++)console.log("actionQueue",c(t[r]))}function n(){clearTimeout(w);for(var e,t=0;e=h[t];t++)document["on"+e]=null}function a(e){if(!e.target)return!1;var t=e.target,r=(t.tagName||"").toLowerCase();if(e.metaKey)return!1;if(e.shiftKey&&"a"==r)return!1;if(t.hostname&&!t.hostname.match(g))return!1;if(e.type.match(p)&&s(t))return!1;if("label"==r){var n=t.getAttribute("for");if(n){var a=document.getElementById(n);if(a&&f(a))return!1}else for(var i,o=0;i=t.childNodes[o];o++)if(f(i))return!1}return!0}function i(e,t){t.bucket=e,b[e].push(t)}function o(e){var t={};for(var r in e)t[r]=e[r];return t}function u(e){for(;e&&e!=document.body;){if("A"==e.tagName)return e;e=e.parentNode}}function c(e){var t=[];e.bucket&&t.push("["+e.bucket+"]"),t.push(e.type);var r,n,a=e.target,i=u(a),o="",c=e.timestamp&&e.timestamp-d;return"click"===e.type&&i?(r=i.className.trim().replace(/\\s+/g,"."),n=i.id.trim(),o=/[^#]$/.test(i.href)?" ("+i.href+")":"",a=\'"\'+i.innerText.replace(/\\n+/g," ").trim()+\'"\'):(r=a.className.trim().replace(/\\s+/g,"."),n=a.id.trim(),a=a.tagName.toLowerCase(),e.keyCode&&(a=String.fromCharCode(e.keyCode)+" : "+a)),t.push(a+o+(n&&"#"+n)+(!n&&r?"."+r:"")),c&&t.push(c),t.join(" ")}function f(e){var t=(e.tagName||""). ...

# %%
# -*- coding: utf-8 -*-

import urllib.request
import urllib.parse
import urllib.error


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    '''Support custom User-Agent, proxy and auto retry
    '''
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


url= 'https://www.baidu.com'
ua = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
proxy = '127.0.0.1:1080'  # Windows上的shadowsocks

download(url, ua, proxy, 2)
# Out:
# Downloading: https://www.baidu.com
# '<!DOCTYPE html>\n<!--STATUS OK-->\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\t\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\t\r\n        \r\n\t\t\t        \r\n\t\r\n\t\t\t        \r\n\t\r\n\t\t\t        \r\n\t\r\n\t\t\t        \r\n\t\t\t    \r\n\r\n\t\r\n        \r\n\t\t\t        \r\n\t\r\n\t\t\t        \r\n\t\r\n\t\t\t        \r\n\t\r\n\t\t\t        \r\n\t\t\t    \r\n\r\n\r\n\r\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html;charset=utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge">\n\t<meta content="always" name="referrer">\n    <meta name="theme-color" content="#2932e1">\n    <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />\n    <link rel="search" type="application/opensearchdescription+xml" href="/content-search.xml" title="百度搜索" />\n    <link rel="icon" sizes="any" mask href="//www.baidu.com/img/baidu_85beaf5496f291521eb75ba38eacbd87.svg">\n\t\n\t\n\t<link rel="dns-prefetch" href="//s1.bdstatic.com"/>\n\t<link rel="dns-prefetch" href="//t1.baidu.com"/>\n\t<link rel="dns-prefetch" href="//t2.baidu.com"/>\n\t<link rel="dns-prefetch" href="//t3.baidu.com"/>\n\t<link rel="dns-prefetch" href="//t10.baidu.com"/>\n\t<link rel="dns-prefetch" href="//t11.baidu.com"/>\n\t<link rel="dns-prefetch" href="//t12.baidu.com"/>\n\t<link rel="dns-prefetch" href="//b1.bdstatic.com"/>\n    \n    <title>百度一下，你就知道</title>\n    \r\n\r\n<style id="css_index" index="index" type="text/css">html,body{height:100%}\nhtml{overflow-y:auto}\nbody{font:12px arial;text-align:;background:#fff}\nbody,p,form,ul,li{margin:0;padding:0;list-style:none}\nbody,form,#fm{position:relative}\ntd{text-align:left}\nimg{border:0}\na{color:#00c}\na:active{color:#f60}\ninput{border:0;padding:0}\n#wrapper{position:relative;_position:;min-height:100%}\n#head{padding-bottom:100px;text-align:center;*z-index:1}\n#ftCon{height:50px;position:absolute;bottom:47px;text-align:left;width:100%;margin:0 auto;z-index:0;overflow:hidden}\n.ftCon-Wrapper{overflow:hidden;margin:0 auto;text-align:center;*width:640px}\n.qrcodeCon{text-align:center;position:absolute;bottom:140px;height:60px;width:100%}\n#qrcode{display:inline-block;*float:left;*margin-top:4px}\n#qrcode .qrcode-item{float:left}\n#qrcode .qrcode-item-2{margin-left:33px}\n#qrcode .qrcode-img{width:60px;height:60px}\n#qrcode .qrcode-item-1 .qrcode-img{background:url(https://ss1.bdstatic.com/5eN1bjq8AAUYm2zgoY3K/r/www/cache/static/protocol/https/home/img/qrcode/zbios_efde696.png) 0 0 no-repeat}\n#qrcode .qrcode-item-2 .qrcode-img{background:url(https://ss1.bdstatic.com/5eN1bjq8AAUYm2zgoY3K/r/www/cache/static/protocol/https/home/img/qrcode/nuomi_365eabd.png) 0 0 no-repeat}\n@media only screen and (-webkit-min-device-pixel-ratio:2){#qrcode .qrcode-item-1 .qrcode-img{background-image:url(https://ss1.bdstatic.com/5eN1bjq8AAUYm2zgoY3K/r/www/cache/static/protocol/https/home/img/qrcode/zbios_x2_9d645d9.png);background-size:60px 60px}\n#qrcode .qrcode-item-2 .qrcode-img{background-image:url(https://ss1.bdstatic.com/5eN1bjq8AAUYm2zgoY3K/r/www/cache/static/protocol/https/home/img/qrcode/nuomi_x2_55dc5b7.png);background-size:60px 60px}}\n#qrcode .qrcode-text{color:#999;line-height:23px;margin:3px 0 0}\n#qrcode .qrcode-text a{color:#999;text-decoration:none}\n#qrcode .qrcode-text p{text-align:center}\n#qrcode .qrcode-text b{color:#666;font-weight:700}\n#qrcode .qrcode-text span{letter-spacing:1px}\n#ftConw{display:inline-block;text-align:left;margin-left:33px;line-height:22px;position:relative;top:-2px;*float:right;*margin-left:0;*position:static}\n#ftConw,#ftConw a{color:#999}\n#ftConw{text-align:center;margin-left:0}\n.bg{background-image:url(https://ss1.bdstatic.com/ ...

# %%
# -*- coding: utf-8 -*-
import re
import urllib.request
import urllib.error
import urllib.parse
import urllib.robotparser
import time
import datetime


user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36'
rp = urllib.robotparser.RobotFileParser()
rp.set_url('http://example.webscraping.com/robots.txt')
rp.read()


class Throttle:
    """Add a delay between downloads to the same domain
    """

    def __init__(self, delay):
        # amount of delay between downloads for each domain
        self.delay = delay
        # timestamp of when a domain was last accessed
        self.domains = {}

    def wait(self, url):
        domain = urllib.parse.urlparse(url).netloc
        last_accessed = self.domains.get(domain)
        if self.delay > 0 and last_accessed is not None:
            sleep_secs = self.delay - \
                (datetime.datetime.now() - last_accessed).seconds
            if sleep_secs > 0:
                # domain has been accessed recently
                # so need to sleep
                time.sleep(sleep_secs)
        # update the last accessed time
        self.domains[domain] = datetime.datetime.now()

        
throttle=Throttle(2)


def download(url, user_agent=user_agent, num_retries=2):
    print('Downloading:', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    try:
        html = urllib.request.urlopen(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                return download(url, user_agent, num_retries - 1)
    return html


def link_crawler(seed_url, link_regex):
    """Crawl from the given seed URL following links matched by link_regex
    """
    crawl_queue = [seed_url]
    # keep track which URL's have seen before
    seen = set(crawl_queue)
    while crawl_queue:
        url = crawl_queue.pop()
        # check url passes robots.txt restrictions
        if rp.can_fetch(user_agent, url):
            throttle.wait(url)
            html = download(url)
        else:
            print('Blocked by robots.txt:', url)
            html = None
        # filter for links matching our regular expression
        for link in get_links(html):
            # check if link matches expected regex
            if re.match(link_regex, link):
                # form absolute link
                link = urllib.parse.urljoin(seed_url, link)
                # check if have already seen this link
                if link not in seen:
                    seen.add(link)
                    crawl_queue.append(link)


def get_links(html):
    """Return a list of links from html
    """
    # a regular expression to extract all links from the webpage
    webpage_regex = re.compile('<a[^>]+href=["\'](.*?)["\']', re.IGNORECASE)
    # list of all links from the webpage
    return webpage_regex.findall(html)


link_crawler('http://example.webscraping.com', '/places/default/(index|view)')
# Out:
# Downloading: http://example.webscraping.com
# Downloading: http://example.webscraping.com/places/default/index/1
# Downloading: http://example.webscraping.com/places/default/index/2
# Downloading: http://example.webscraping.com/places/default/index/3
# Downloading: http://example.webscraping.com/places/default/index/4
# Downloading: http://example.webscraping.com/places/default/index/5
# Downloading: http://example.webscraping.com/places/default/index/6
# Downloading: http://example.webscraping.com/places/default/index/7
# Downloading: http://example.webscraping.com/places/default/index/8
# Downloading: http://example.webscraping.com/places/default/index/9
# Downloading: http://example.webscraping.com/places/default/index/10
# Downloading: http://example.webscraping.com/places/default/index/11
# Downloading: http://example.webscraping.com/places/default/index/12
# Downloading: http://example.webscraping.com/places/default/index/13
# Downloading: http://example.webscraping.com/places/default/index/14
# Downloading: http://example.webscraping.com/places/default/index/15
# Downloading: http://example.webscraping.com/places/default/index/16
# Downloading: http://example.webscraping.com/places/default/index/17
# Downloading: http://example.webscraping.com/places/default/index/18
# Downloading: http://example.webscraping.com/places/default/index/19
# Downloading: http://example.webscraping.com/places/default/index/20
# Downloading: http://example.webscraping.com/places/default/index/21
# Downloading: http://example.webscraping.com/places/default/index/22
# Downloading: http://example.webscraping.com/places/default/index/23
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/view/Zimbabwe-252
# Downloading: http://example.webscraping.com/places/default/view/Zambia-251
# Downloading: http://example.webscraping.com/places/default/view/Yemen-250
# Downloading: http://example.webscraping.com/places/default/view/Western-Sahara-249
# Downloading: http://example.webscraping.com/places/default/view/Wallis-and-Futuna-248
# Downloading: http://example.webscraping.com/places/default/view/Vietnam-247
# Downloading: http://example.webscraping.com/places/default/view/Venezuela-246
# Downloading: http://example.webscraping.com/places/default/view/Vatican-245
# Downloading: http://example.webscraping.com/places/default/view/Vanuatu-244
# Downloading: http://example.webscraping.com/places/default/view/Uzbekistan-243
# Downloading: http://example.webscraping.com/places/default/view/Uruguay-242
# Downloading: http://example.webscraping.com/places/default/view/United-States-Minor-Outlying-Islands-241
# Downloading: http://example.webscraping.com/places/default/view/United-States-240
# Downloading: http://example.webscraping.com/places/default/view/United-Kingdom-239
# Downloading: http://example.webscraping.com/places/default/view/United-Arab-Emirates-238
# Downloading: http://example.webscraping.com/places/default/view/Ukraine-237
# Downloading: http://example.webscraping.com/places/default/view/Uganda-236
# Downloading: http://example.webscraping.com/places/default/view/US-Virgin-Islands-235
# Downloading: http://example.webscraping.com/places/default/view/Tuvalu-234
# Downloading: http://example.webscraping.com/places/default/view/Turks-and-Caicos-Islands-233
# Downloading: http://example.webscraping.com/places/default/view/Turkmenistan-232
# Downloading: http://example.webscraping.com/places/default/view/Turkey-231
# Downloading: http://example.webscraping.com/places/default/view/Tunisia-230
# Downloading: http://example.webscraping.com/places/default/view/Trinidad-and-Tobago-229
# Downloading: http://example.webscraping.com/places/default/view/Tonga-228
# Downloading: http://example.webscraping.com/places/default/view/Tokelau-227
# Downloading: http://example.webscraping.com/places/default/view/Togo-226
# Downloading: http://example.webscraping.com/places/default/view/Thailand-225
# Downloading: http://example.webscraping.com/places/default/view/Tanzania-224
# Downloading: http://example.webscraping.com/places/default/view/Tajikistan-223
# Downloading: http://example.webscraping.com/places/default/view/Taiwan-222
# Downloading: http://example.webscraping.com/places/default/view/Syria-221
# Downloading: http://example.webscraping.com/places/default/view/Switzerland-220
# Downloading: http://example.webscraping.com/places/default/view/Sweden-219
# Downloading: http://example.webscraping.com/places/default/view/Swaziland-218
# Downloading: http://example.webscraping.com/places/default/view/Svalbard-and-Jan-Mayen-217
# Downloading: http://example.webscraping.com/places/default/view/Suriname-216
# Downloading: http://example.webscraping.com/places/default/view/Sudan-215
# Downloading: http://example.webscraping.com/places/default/view/Sri-Lanka-214
# Downloading: http://example.webscraping.com/places/default/view/Spain-213
# Downloading: http://example.webscraping.com/places/default/view/South-Sudan-212
# Downloading: http://example.webscraping.com/places/default/view/South-Korea-211
# Downloading: http://example.webscraping.com/places/default/view/South-Georgia-and-the-South-Sandwich-Islands-210
# Downloading: http://example.webscraping.com/places/default/view/South-Africa-209
# Downloading: http://example.webscraping.com/places/default/view/Somalia-208
# Downloading: http://example.webscraping.com/places/default/view/Solomon-Islands-207
# Downloading: http://example.webscraping.com/places/default/view/Slovenia-206
# Downloading: http://example.webscraping.com/places/default/view/Slovakia-205
# Downloading: http://example.webscraping.com/places/default/view/Sint-Maarten-204
# Downloading: http://example.webscraping.com/places/default/view/Singapore-203
# Downloading: http://example.webscraping.com/places/default/view/Sierra-Leone-202
# Downloading: http://example.webscraping.com/places/default/view/Seychelles-201
# Downloading: http://example.webscraping.com/places/default/view/Serbia-and-Montenegro-200
# Downloading: http://example.webscraping.com/places/default/view/Serbia-199
# Downloading: http://example.webscraping.com/places/default/view/Senegal-198
# Downloading: http://example.webscraping.com/places/default/view/Saudi-Arabia-197
# Downloading: http://example.webscraping.com/places/default/view/Sao-Tome-and-Principe-196
# Downloading: http://example.webscraping.com/places/default/view/San-Marino-195
# Downloading: http://example.webscraping.com/places/default/view/Samoa-194
# Downloading: http://example.webscraping.com/places/default/view/Saint-Vincent-and-the-Grenadines-193
# Downloading: http://example.webscraping.com/places/default/view/Saint-Pierre-and-Miquelon-192
# Downloading: http://example.webscraping.com/places/default/view/Saint-Martin-191
# Downloading: http://example.webscraping.com/places/default/view/Saint-Lucia-190
# Downloading: http://example.webscraping.com/places/default/view/Saint-Kitts-and-Nevis-189
# Downloading: http://example.webscraping.com/places/default/view/Saint-Helena-188
# Downloading: http://example.webscraping.com/places/default/view/Saint-Barthelemy-187
# Downloading: http://example.webscraping.com/places/default/view/Rwanda-186
# Downloading: http://example.webscraping.com/places/default/view/Russia-185
# Downloading: http://example.webscraping.com/places/default/view/Romania-184
# Downloading: http://example.webscraping.com/places/default/view/Reunion-183
# Downloading: http://example.webscraping.com/places/default/view/Republic-of-the-Congo-182
# Downloading: http://example.webscraping.com/places/default/view/Qatar-181
# Downloading: http://example.webscraping.com/places/default/view/Puerto-Rico-180
# Downloading: http://example.webscraping.com/places/default/view/Portugal-179
# Downloading: http://example.webscraping.com/places/default/view/Poland-178
# Downloading: http://example.webscraping.com/places/default/view/Pitcairn-177
# Downloading: http://example.webscraping.com/places/default/view/Philippines-176
# Downloading: http://example.webscraping.com/places/default/view/Peru-175
# Downloading: http://example.webscraping.com/places/default/view/Paraguay-174
# Downloading: http://example.webscraping.com/places/default/view/Papua-New-Guinea-173
# Downloading: http://example.webscraping.com/places/default/view/Panama-172
# Downloading: http://example.webscraping.com/places/default/view/Palestinian-Territory-171
# Downloading: http://example.webscraping.com/places/default/view/Palau-170
# Downloading: http://example.webscraping.com/places/default/view/Pakistan-169
# Downloading: http://example.webscraping.com/places/default/view/Oman-168
# Downloading: http://example.webscraping.com/places/default/view/Norway-167
# Downloading: http://example.webscraping.com/places/default/view/Northern-Mariana-Islands-166
# Downloading: http://example.webscraping.com/places/default/view/North-Korea-165
# Downloading: http://example.webscraping.com/places/default/view/Norfolk-Island-164
# Downloading: http://example.webscraping.com/places/default/view/Niue-163
# Downloading: http://example.webscraping.com/places/default/view/Nigeria-162
# Downloading: http://example.webscraping.com/places/default/view/Niger-161
# Downloading: http://example.webscraping.com/places/default/view/Nicaragua-160
# Downloading: http://example.webscraping.com/places/default/view/New-Zealand-159
# Downloading: http://example.webscraping.com/places/default/view/New-Caledonia-158
# Downloading: http://example.webscraping.com/places/default/view/Netherlands-Antilles-157
# Downloading: http://example.webscraping.com/places/default/view/Netherlands-156
# Downloading: http://example.webscraping.com/places/default/view/Nepal-155
# Downloading: http://example.webscraping.com/places/default/view/Nauru-154
# Downloading: http://example.webscraping.com/places/default/view/Namibia-153
# Downloading: http://example.webscraping.com/places/default/view/Myanmar-152
# Downloading: http://example.webscraping.com/places/default/view/Mozambique-151
# Downloading: http://example.webscraping.com/places/default/view/Morocco-150
# Downloading: http://example.webscraping.com/places/default/view/Montserrat-149
# Downloading: http://example.webscraping.com/places/default/view/Montenegro-148
# Downloading: http://example.webscraping.com/places/default/view/Mongolia-147
# Downloading: http://example.webscraping.com/places/default/view/Monaco-146
# Downloading: http://example.webscraping.com/places/default/view/Moldova-145
# Downloading: http://example.webscraping.com/places/default/view/Micronesia-144
# Downloading: http://example.webscraping.com/places/default/view/Mexico-143
# Downloading: http://example.webscraping.com/places/default/view/Mayotte-142
# Downloading: http://example.webscraping.com/places/default/view/Mauritius-141
# Downloading: http://example.webscraping.com/places/default/view/Mauritania-140
# Downloading: http://example.webscraping.com/places/default/view/Martinique-139
# Downloading: http://example.webscraping.com/places/default/view/Marshall-Islands-138
# Downloading: http://example.webscraping.com/places/default/view/Malta-137
# Downloading: http://example.webscraping.com/places/default/view/Mali-136
# Downloading: http://example.webscraping.com/places/default/view/Maldives-135
# Downloading: http://example.webscraping.com/places/default/view/Malaysia-134
# Downloading: http://example.webscraping.com/places/default/view/Malawi-133
# Downloading: http://example.webscraping.com/places/default/view/Madagascar-132
# Downloading: http://example.webscraping.com/places/default/view/Macedonia-131
# Downloading: http://example.webscraping.com/places/default/view/Macao-130
# Downloading: http://example.webscraping.com/places/default/view/Luxembourg-129
# Downloading: http://example.webscraping.com/places/default/view/Lithuania-128
# Downloading: http://example.webscraping.com/places/default/view/Liechtenstein-127
# Downloading: http://example.webscraping.com/places/default/view/Libya-126
# Downloading: http://example.webscraping.com/places/default/view/Liberia-125
# Downloading: http://example.webscraping.com/places/default/view/Lesotho-124
# Downloading: http://example.webscraping.com/places/default/view/Lebanon-123
# Downloading: http://example.webscraping.com/places/default/view/Latvia-122
# Downloading: http://example.webscraping.com/places/default/view/Laos-121
# Downloading: http://example.webscraping.com/places/default/view/Kyrgyzstan-120
# Downloading: http://example.webscraping.com/places/default/view/Kuwait-119
# Downloading: http://example.webscraping.com/places/default/view/Kosovo-118
# Downloading: http://example.webscraping.com/places/default/view/Kiribati-117
# Downloading: http://example.webscraping.com/places/default/view/Kenya-116
# Downloading: http://example.webscraping.com/places/default/view/Kazakhstan-115
# Downloading: http://example.webscraping.com/places/default/view/Jordan-114
# Downloading: http://example.webscraping.com/places/default/view/Jersey-113
# Downloading: http://example.webscraping.com/places/default/view/Japan-112
# Downloading: http://example.webscraping.com/places/default/view/Jamaica-111
# Downloading: http://example.webscraping.com/places/default/view/Ivory-Coast-110
# Downloading: http://example.webscraping.com/places/default/view/Italy-109
# Downloading: http://example.webscraping.com/places/default/view/Israel-108
# Downloading: http://example.webscraping.com/places/default/view/Isle-of-Man-107
# Downloading: http://example.webscraping.com/places/default/view/Ireland-106
# Downloading: http://example.webscraping.com/places/default/view/Iraq-105
# Downloading: http://example.webscraping.com/places/default/view/Iran-104
# Downloading: http://example.webscraping.com/places/default/view/Indonesia-103
# Downloading: http://example.webscraping.com/places/default/view/India-102
# Downloading: http://example.webscraping.com/places/default/view/Iceland-101
# Downloading: http://example.webscraping.com/places/default/view/Hungary-100
# Downloading: http://example.webscraping.com/places/default/view/Hong-Kong-99
# Downloading: http://example.webscraping.com/places/default/view/Honduras-98
# Downloading: http://example.webscraping.com/places/default/view/Heard-Island-and-McDonald-Islands-97
# Downloading: http://example.webscraping.com/places/default/view/Haiti-96
# Downloading: http://example.webscraping.com/places/default/view/Guyana-95
# Downloading: http://example.webscraping.com/places/default/view/Guinea-Bissau-94
# Downloading: http://example.webscraping.com/places/default/view/Guinea-93
# Downloading: http://example.webscraping.com/places/default/view/Guernsey-92
# Downloading: http://example.webscraping.com/places/default/view/Guatemala-91
# Downloading: http://example.webscraping.com/places/default/view/Guam-90
# Downloading: http://example.webscraping.com/places/default/view/Guadeloupe-89
# Downloading: http://example.webscraping.com/places/default/view/Grenada-88
# Downloading: http://example.webscraping.com/places/default/view/Greenland-87
# Downloading: http://example.webscraping.com/places/default/view/Greece-86
# Downloading: http://example.webscraping.com/places/default/view/Gibraltar-85
# Downloading: http://example.webscraping.com/places/default/view/Ghana-84
# Downloading: http://example.webscraping.com/places/default/view/Germany-83
# Downloading: http://example.webscraping.com/places/default/view/Georgia-82
# Downloading: http://example.webscraping.com/places/default/view/Gambia-81
# Downloading: http://example.webscraping.com/places/default/view/Gabon-80
# Downloading: http://example.webscraping.com/places/default/view/French-Southern-Territories-79
# Downloading: http://example.webscraping.com/places/default/view/French-Polynesia-78
# Downloading: http://example.webscraping.com/places/default/view/French-Guiana-77
# Downloading: http://example.webscraping.com/places/default/view/France-76
# Downloading: http://example.webscraping.com/places/default/view/Finland-75
# Downloading: http://example.webscraping.com/places/default/view/Fiji-74
# Downloading: http://example.webscraping.com/places/default/view/Faroe-Islands-73
# Downloading: http://example.webscraping.com/places/default/view/Falkland-Islands-72
# Downloading: http://example.webscraping.com/places/default/view/Ethiopia-71
# Downloading: http://example.webscraping.com/places/default/view/Estonia-70
# Downloading: http://example.webscraping.com/places/default/view/Eritrea-69
# Downloading: http://example.webscraping.com/places/default/view/Equatorial-Guinea-68
# Downloading: http://example.webscraping.com/places/default/view/El-Salvador-67
# Downloading: http://example.webscraping.com/places/default/view/Egypt-66
# Downloading: http://example.webscraping.com/places/default/view/Ecuador-65
# Downloading: http://example.webscraping.com/places/default/view/East-Timor-64
# Downloading: http://example.webscraping.com/places/default/view/Dominican-Republic-63
# Downloading: http://example.webscraping.com/places/default/view/Dominica-62
# Downloading: http://example.webscraping.com/places/default/view/Djibouti-61
# Downloading: http://example.webscraping.com/places/default/view/Denmark-60
# Downloading: http://example.webscraping.com/places/default/view/Democratic-Republic-of-the-Congo-59
# Downloading: http://example.webscraping.com/places/default/view/Czech-Republic-58
# Downloading: http://example.webscraping.com/places/default/view/Cyprus-57
# Downloading: http://example.webscraping.com/places/default/view/Curacao-56
# Downloading: http://example.webscraping.com/places/default/view/Cuba-55
# Downloading: http://example.webscraping.com/places/default/view/Croatia-54
# Downloading: http://example.webscraping.com/places/default/view/Costa-Rica-53
# Downloading: http://example.webscraping.com/places/default/view/Cook-Islands-52
# Downloading: http://example.webscraping.com/places/default/view/Comoros-51
# Downloading: http://example.webscraping.com/places/default/view/Colombia-50
# Downloading: http://example.webscraping.com/places/default/view/Cocos-Islands-49
# Downloading: http://example.webscraping.com/places/default/view/Christmas-Island-48
# Downloading: http://example.webscraping.com/places/default/view/China-47
# Downloading: http://example.webscraping.com/places/default/view/Chile-46
# Downloading: http://example.webscraping.com/places/default/view/Chad-45
# Downloading: http://example.webscraping.com/places/default/view/Central-African-Republic-44
# Downloading: http://example.webscraping.com/places/default/view/Cayman-Islands-43
# Downloading: http://example.webscraping.com/places/default/view/Cape-Verde-42
# Downloading: http://example.webscraping.com/places/default/view/Canada-41
# Downloading: http://example.webscraping.com/places/default/view/Cameroon-40
# Downloading: http://example.webscraping.com/places/default/view/Cambodia-39
# Downloading: http://example.webscraping.com/places/default/view/Burundi-38
# Downloading: http://example.webscraping.com/places/default/view/Burkina-Faso-37
# Downloading: http://example.webscraping.com/places/default/view/Bulgaria-36
# Downloading: http://example.webscraping.com/places/default/view/Brunei-35
# Downloading: http://example.webscraping.com/places/default/view/British-Virgin-Islands-34
# Downloading: http://example.webscraping.com/places/default/view/British-Indian-Ocean-Territory-33
# Downloading: http://example.webscraping.com/places/default/view/Brazil-32
# Downloading: http://example.webscraping.com/places/default/view/Bouvet-Island-31
# Downloading: http://example.webscraping.com/places/default/view/Botswana-30
# Downloading: http://example.webscraping.com/places/default/view/Bosnia-and-Herzegovina-29
# Downloading: http://example.webscraping.com/places/default/view/Bonaire-Saint-Eustatius-and-Saba-28
# Downloading: http://example.webscraping.com/places/default/view/Bolivia-27
# Downloading: http://example.webscraping.com/places/default/view/Bhutan-26
# Downloading: http://example.webscraping.com/places/default/view/Bermuda-25
# Downloading: http://example.webscraping.com/places/default/view/Benin-24
# Downloading: http://example.webscraping.com/places/default/view/Belize-23
# Downloading: http://example.webscraping.com/places/default/view/Belgium-22
# Downloading: http://example.webscraping.com/places/default/view/Belarus-21
# Downloading: http://example.webscraping.com/places/default/index/0
# Downloading: http://example.webscraping.com/places/default/view/Barbados-20
# Downloading: http://example.webscraping.com/places/default/view/Bangladesh-19
# Downloading: http://example.webscraping.com/places/default/view/Bahrain-18
# Downloading: http://example.webscraping.com/places/default/view/Bahamas-17
# Downloading: http://example.webscraping.com/places/default/view/Azerbaijan-16
# Downloading: http://example.webscraping.com/places/default/view/Austria-15
# Downloading: http://example.webscraping.com/places/default/view/Australia-14
# Downloading: http://example.webscraping.com/places/default/view/Aruba-13
# Downloading: http://example.webscraping.com/places/default/view/Armenia-12
# Downloading: http://example.webscraping.com/places/default/view/Argentina-11
# Downloading: http://example.webscraping.com/places/default/view/Antigua-and-Barbuda-10
# Downloading: http://example.webscraping.com/places/default/view/Antarctica-9
# Downloading: http://example.webscraping.com/places/default/view/Anguilla-8
# Downloading: http://example.webscraping.com/places/default/view/Angola-7
# Downloading: http://example.webscraping.com/places/default/view/Andorra-6
# Downloading: http://example.webscraping.com/places/default/view/American-Samoa-5
# Downloading: http://example.webscraping.com/places/default/view/Algeria-4
# Downloading: http://example.webscraping.com/places/default/view/Albania-3
# Downloading: http://example.webscraping.com/places/default/view/Aland-Islands-2
# Downloading: http://example.webscraping.com/places/default/view/Afghanistan-1
# Downloading: http://example.webscraping.com/places/default/index

# %%
# -*- coding: utf-8 -*-
import re
import urllib.request
import urllib.error
import urllib.parse
import urllib.robotparser
import time
import datetime


user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36'
rp = urllib.robotparser.RobotFileParser()
rp.set_url('http://example.webscraping.com/robots.txt')
rp.read()


class Throttle:
    """Add a delay between downloads to the same domain
    """

    def __init__(self, delay):
        # amount of delay between downloads for each domain
        self.delay = delay
        # timestamp of when a domain was last accessed
        self.domains = {}

    def wait(self, url):
        domain = urllib.parse.urlparse(url).netloc
        last_accessed = self.domains.get(domain)
        if self.delay > 0 and last_accessed is not None:
            sleep_secs = self.delay - \
                (datetime.datetime.now() - last_accessed).seconds
            if sleep_secs > 0:
                # domain has been accessed recently
                # so need to sleep
                time.sleep(sleep_secs)
        # update the last accessed time
        self.domains[domain] = datetime.datetime.now()

        
throttle=Throttle(1)


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    '''Support custom User-Agent, proxy and auto retry
    '''
    print('Downloading:', url)  # url is download function's first arguments
    headers = {'User-agent': user_agent}  # user_agent is the second arguments
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


def link_crawler(seed_url, link_regex):
    """Crawl from the given seed URL following links matched by link_regex
    """
    crawl_queue = [seed_url]
    # keep track which URL's have seen before
    seen = set(crawl_queue)
    while crawl_queue:
        url = crawl_queue.pop()
        # check url passes robots.txt restrictions
        if rp.can_fetch(user_agent, url):
            throttle.wait(url)
            html = download(url, user_agent, proxy, 2)
        else:
            print('Blocked by robots.txt:', url)
            html = None
        # filter for links matching our regular expression
        for link in get_links(html):
            # check if link matches expected regex
            if re.match(link_regex, link):
                # form absolute link
                link = urllib.parse.urljoin(seed_url, link)
                # check if have already seen this link
                if link not in seen:
                    seen.add(link)
                    crawl_queue.append(link)


def get_links(html):
    """Return a list of links from html
    """
    # a regular expression to extract all links from the webpage
    webpage_regex = re.compile('<a[^>]+href=["\'](.*?)["\']', re.IGNORECASE)
    # list of all links from the webpage
    return webpage_regex.findall(html)


proxy = '127.0.0.1:1080'
link_crawler('http://example.webscraping.com', '/places/default/(index|view)')
# Out:
# Downloading: http://example.webscraping.com
# Downloading: http://example.webscraping.com/places/default/index/1
# Downloading: http://example.webscraping.com/places/default/index/2
# Downloading: http://example.webscraping.com/places/default/index/3
# Downloading: http://example.webscraping.com/places/default/index/4
# Downloading: http://example.webscraping.com/places/default/index/5
# Downloading: http://example.webscraping.com/places/default/index/6
# Downloading: http://example.webscraping.com/places/default/index/7
# Downloading: http://example.webscraping.com/places/default/index/8
# Downloading: http://example.webscraping.com/places/default/index/9
# Downloading: http://example.webscraping.com/places/default/index/10
# Downloading: http://example.webscraping.com/places/default/index/11
# Downloading: http://example.webscraping.com/places/default/index/12
# Downloading: http://example.webscraping.com/places/default/index/13
# Downloading: http://example.webscraping.com/places/default/index/14
# Downloading: http://example.webscraping.com/places/default/index/15
# Downloading: http://example.webscraping.com/places/default/index/16
# Downloading: http://example.webscraping.com/places/default/index/17
# Downloading: http://example.webscraping.com/places/default/index/18
# Downloading: http://example.webscraping.com/places/default/index/19
# Downloading: http://example.webscraping.com/places/default/index/20
# Downloading: http://example.webscraping.com/places/default/index/21
# Downloading: http://example.webscraping.com/places/default/index/22
# Downloading: http://example.webscraping.com/places/default/index/23
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/view/Zimbabwe-252
# Downloading: http://example.webscraping.com/places/default/view/Zambia-251
# Downloading: http://example.webscraping.com/places/default/view/Yemen-250
# Downloading: http://example.webscraping.com/places/default/view/Western-Sahara-249
# Downloading: http://example.webscraping.com/places/default/view/Wallis-and-Futuna-248
# Downloading: http://example.webscraping.com/places/default/view/Vietnam-247
# Downloading: http://example.webscraping.com/places/default/view/Venezuela-246
# Downloading: http://example.webscraping.com/places/default/view/Vatican-245
# Downloading: http://example.webscraping.com/places/default/view/Vanuatu-244
# Downloading: http://example.webscraping.com/places/default/view/Uzbekistan-243
# Downloading: http://example.webscraping.com/places/default/view/Uruguay-242
# Downloading: http://example.webscraping.com/places/default/view/United-States-Minor-Outlying-Islands-241
# Downloading: http://example.webscraping.com/places/default/view/United-States-240
# Downloading: http://example.webscraping.com/places/default/view/United-Kingdom-239
# Downloading: http://example.webscraping.com/places/default/view/United-Arab-Emirates-238
# Downloading: http://example.webscraping.com/places/default/view/Ukraine-237
# Downloading: http://example.webscraping.com/places/default/view/Uganda-236
# Downloading: http://example.webscraping.com/places/default/view/US-Virgin-Islands-235
# Downloading: http://example.webscraping.com/places/default/view/Tuvalu-234
# Downloading: http://example.webscraping.com/places/default/view/Turks-and-Caicos-Islands-233
# Downloading: http://example.webscraping.com/places/default/view/Turkmenistan-232
# Downloading: http://example.webscraping.com/places/default/view/Turkey-231
# Downloading: http://example.webscraping.com/places/default/view/Tunisia-230
# Downloading: http://example.webscraping.com/places/default/view/Trinidad-and-Tobago-229
# Downloading: http://example.webscraping.com/places/default/view/Tonga-228
# Downloading: http://example.webscraping.com/places/default/view/Tokelau-227
# Downloading: http://example.webscraping.com/places/default/view/Togo-226
# Downloading: http://example.webscraping.com/places/default/view/Thailand-225
# Downloading: http://example.webscraping.com/places/default/view/Tanzania-224
# Downloading: http://example.webscraping.com/places/default/view/Tajikistan-223
# Downloading: http://example.webscraping.com/places/default/view/Taiwan-222
# Downloading: http://example.webscraping.com/places/default/view/Syria-221
# Downloading: http://example.webscraping.com/places/default/view/Switzerland-220
# Downloading: http://example.webscraping.com/places/default/view/Sweden-219
# Downloading: http://example.webscraping.com/places/default/view/Swaziland-218
# Downloading: http://example.webscraping.com/places/default/view/Svalbard-and-Jan-Mayen-217
# Downloading: http://example.webscraping.com/places/default/view/Suriname-216
# Downloading: http://example.webscraping.com/places/default/view/Sudan-215
# Downloading: http://example.webscraping.com/places/default/view/Sri-Lanka-214
# Downloading: http://example.webscraping.com/places/default/view/Spain-213
# Downloading: http://example.webscraping.com/places/default/view/South-Sudan-212
# Downloading: http://example.webscraping.com/places/default/view/South-Korea-211
# Downloading: http://example.webscraping.com/places/default/view/South-Georgia-and-the-South-Sandwich-Islands-210
# Downloading: http://example.webscraping.com/places/default/view/South-Africa-209
# Downloading: http://example.webscraping.com/places/default/view/Somalia-208
# Downloading: http://example.webscraping.com/places/default/view/Solomon-Islands-207
# Downloading: http://example.webscraping.com/places/default/view/Slovenia-206
# Downloading: http://example.webscraping.com/places/default/view/Slovakia-205
# Downloading: http://example.webscraping.com/places/default/view/Sint-Maarten-204
# Downloading: http://example.webscraping.com/places/default/view/Singapore-203
# Downloading: http://example.webscraping.com/places/default/view/Sierra-Leone-202
# Downloading: http://example.webscraping.com/places/default/view/Seychelles-201
# Downloading: http://example.webscraping.com/places/default/view/Serbia-and-Montenegro-200
# Downloading: http://example.webscraping.com/places/default/view/Serbia-199
# Downloading: http://example.webscraping.com/places/default/view/Senegal-198
# Downloading: http://example.webscraping.com/places/default/view/Saudi-Arabia-197
# Downloading: http://example.webscraping.com/places/default/view/Sao-Tome-and-Principe-196
# Downloading: http://example.webscraping.com/places/default/view/San-Marino-195
# Downloading: http://example.webscraping.com/places/default/view/Samoa-194
# Downloading: http://example.webscraping.com/places/default/view/Saint-Vincent-and-the-Grenadines-193
# Downloading: http://example.webscraping.com/places/default/view/Saint-Pierre-and-Miquelon-192
# Downloading: http://example.webscraping.com/places/default/view/Saint-Martin-191
# Downloading: http://example.webscraping.com/places/default/view/Saint-Lucia-190
# Downloading: http://example.webscraping.com/places/default/view/Saint-Kitts-and-Nevis-189
# Downloading: http://example.webscraping.com/places/default/view/Saint-Helena-188
# Downloading: http://example.webscraping.com/places/default/view/Saint-Barthelemy-187
# Downloading: http://example.webscraping.com/places/default/view/Rwanda-186
# Downloading: http://example.webscraping.com/places/default/view/Russia-185
# Downloading: http://example.webscraping.com/places/default/view/Romania-184
# Downloading: http://example.webscraping.com/places/default/view/Reunion-183
# Downloading: http://example.webscraping.com/places/default/view/Republic-of-the-Congo-182
# Downloading: http://example.webscraping.com/places/default/view/Qatar-181
# Downloading: http://example.webscraping.com/places/default/view/Puerto-Rico-180
# Downloading: http://example.webscraping.com/places/default/view/Portugal-179
# Downloading: http://example.webscraping.com/places/default/view/Poland-178
# Downloading: http://example.webscraping.com/places/default/view/Pitcairn-177
# Downloading: http://example.webscraping.com/places/default/view/Philippines-176
# Downloading: http://example.webscraping.com/places/default/view/Peru-175
# Downloading: http://example.webscraping.com/places/default/view/Paraguay-174
# Downloading: http://example.webscraping.com/places/default/view/Papua-New-Guinea-173
# Downloading: http://example.webscraping.com/places/default/view/Panama-172
# Downloading: http://example.webscraping.com/places/default/view/Palestinian-Territory-171
# Downloading: http://example.webscraping.com/places/default/view/Palau-170
# Downloading: http://example.webscraping.com/places/default/view/Pakistan-169
# Downloading: http://example.webscraping.com/places/default/view/Oman-168
# Downloading: http://example.webscraping.com/places/default/view/Norway-167
# Downloading: http://example.webscraping.com/places/default/view/Northern-Mariana-Islands-166
# Downloading: http://example.webscraping.com/places/default/view/North-Korea-165
# Downloading: http://example.webscraping.com/places/default/view/Norfolk-Island-164
# Downloading: http://example.webscraping.com/places/default/view/Niue-163
# Downloading: http://example.webscraping.com/places/default/view/Nigeria-162
# Downloading: http://example.webscraping.com/places/default/view/Niger-161
# Downloading: http://example.webscraping.com/places/default/view/Nicaragua-160
# Downloading: http://example.webscraping.com/places/default/view/New-Zealand-159
# Downloading: http://example.webscraping.com/places/default/view/New-Caledonia-158
# Downloading: http://example.webscraping.com/places/default/view/Netherlands-Antilles-157
# Downloading: http://example.webscraping.com/places/default/view/Netherlands-156
# Downloading: http://example.webscraping.com/places/default/view/Nepal-155
# Downloading: http://example.webscraping.com/places/default/view/Nauru-154
# Downloading: http://example.webscraping.com/places/default/view/Namibia-153
# Downloading: http://example.webscraping.com/places/default/view/Myanmar-152
# Downloading: http://example.webscraping.com/places/default/view/Mozambique-151
# Downloading: http://example.webscraping.com/places/default/view/Morocco-150
# Downloading: http://example.webscraping.com/places/default/view/Montserrat-149
# Downloading: http://example.webscraping.com/places/default/view/Montenegro-148
# Downloading: http://example.webscraping.com/places/default/view/Mongolia-147
# Downloading: http://example.webscraping.com/places/default/view/Monaco-146
# Downloading: http://example.webscraping.com/places/default/view/Moldova-145
# Downloading: http://example.webscraping.com/places/default/view/Micronesia-144
# Downloading: http://example.webscraping.com/places/default/view/Mexico-143
# Downloading: http://example.webscraping.com/places/default/view/Mayotte-142
# Downloading: http://example.webscraping.com/places/default/view/Mauritius-141
# Downloading: http://example.webscraping.com/places/default/view/Mauritania-140
# Downloading: http://example.webscraping.com/places/default/view/Martinique-139
# Downloading: http://example.webscraping.com/places/default/view/Marshall-Islands-138
# Downloading: http://example.webscraping.com/places/default/view/Malta-137
# Downloading: http://example.webscraping.com/places/default/view/Mali-136
# Downloading: http://example.webscraping.com/places/default/view/Maldives-135
# Downloading: http://example.webscraping.com/places/default/view/Malaysia-134
# Downloading: http://example.webscraping.com/places/default/view/Malawi-133
# Downloading: http://example.webscraping.com/places/default/view/Madagascar-132
# Downloading: http://example.webscraping.com/places/default/view/Macedonia-131
# Downloading: http://example.webscraping.com/places/default/view/Macao-130
# Downloading: http://example.webscraping.com/places/default/view/Luxembourg-129
# Downloading: http://example.webscraping.com/places/default/view/Lithuania-128
# Downloading: http://example.webscraping.com/places/default/view/Liechtenstein-127
# Downloading: http://example.webscraping.com/places/default/view/Libya-126
# Downloading: http://example.webscraping.com/places/default/view/Liberia-125
# Downloading: http://example.webscraping.com/places/default/view/Lesotho-124
# Downloading: http://example.webscraping.com/places/default/view/Lebanon-123
# Downloading: http://example.webscraping.com/places/default/view/Latvia-122
# Downloading: http://example.webscraping.com/places/default/view/Laos-121
# Downloading: http://example.webscraping.com/places/default/view/Kyrgyzstan-120
# Downloading: http://example.webscraping.com/places/default/view/Kuwait-119
# Downloading: http://example.webscraping.com/places/default/view/Kosovo-118
# Downloading: http://example.webscraping.com/places/default/view/Kiribati-117
# Downloading: http://example.webscraping.com/places/default/view/Kenya-116
# Downloading: http://example.webscraping.com/places/default/view/Kazakhstan-115
# Downloading: http://example.webscraping.com/places/default/view/Jordan-114
# Downloading: http://example.webscraping.com/places/default/view/Jersey-113
# Downloading: http://example.webscraping.com/places/default/view/Japan-112
# Downloading: http://example.webscraping.com/places/default/view/Jamaica-111
# Downloading: http://example.webscraping.com/places/default/view/Ivory-Coast-110
# Downloading: http://example.webscraping.com/places/default/view/Italy-109
# Downloading: http://example.webscraping.com/places/default/view/Israel-108
# Downloading: http://example.webscraping.com/places/default/view/Isle-of-Man-107
# Downloading: http://example.webscraping.com/places/default/view/Ireland-106
# Downloading: http://example.webscraping.com/places/default/view/Iraq-105
# Downloading: http://example.webscraping.com/places/default/view/Iran-104
# Downloading: http://example.webscraping.com/places/default/view/Indonesia-103
# Downloading: http://example.webscraping.com/places/default/view/India-102
# Downloading: http://example.webscraping.com/places/default/view/Iceland-101
# Downloading: http://example.webscraping.com/places/default/view/Hungary-100
# Downloading: http://example.webscraping.com/places/default/view/Hong-Kong-99
# Downloading: http://example.webscraping.com/places/default/view/Honduras-98
# Downloading: http://example.webscraping.com/places/default/view/Heard-Island-and-McDonald-Islands-97
# Downloading: http://example.webscraping.com/places/default/view/Haiti-96
# Downloading: http://example.webscraping.com/places/default/view/Guyana-95
# Downloading: http://example.webscraping.com/places/default/view/Guinea-Bissau-94
# Downloading: http://example.webscraping.com/places/default/view/Guinea-93
# Downloading: http://example.webscraping.com/places/default/view/Guernsey-92
# Downloading: http://example.webscraping.com/places/default/view/Guatemala-91
# Downloading: http://example.webscraping.com/places/default/view/Guam-90
# Downloading: http://example.webscraping.com/places/default/view/Guadeloupe-89
# Downloading: http://example.webscraping.com/places/default/view/Grenada-88
# Downloading: http://example.webscraping.com/places/default/view/Greenland-87
# Downloading: http://example.webscraping.com/places/default/view/Greece-86
# Downloading: http://example.webscraping.com/places/default/view/Gibraltar-85
# Downloading: http://example.webscraping.com/places/default/view/Ghana-84
# Downloading: http://example.webscraping.com/places/default/view/Germany-83
# Downloading: http://example.webscraping.com/places/default/view/Georgia-82
# Downloading: http://example.webscraping.com/places/default/view/Gambia-81
# Downloading: http://example.webscraping.com/places/default/view/Gabon-80
# Downloading: http://example.webscraping.com/places/default/view/French-Southern-Territories-79
# Downloading: http://example.webscraping.com/places/default/view/French-Polynesia-78
# Downloading: http://example.webscraping.com/places/default/view/French-Guiana-77
# Downloading: http://example.webscraping.com/places/default/view/France-76
# Downloading: http://example.webscraping.com/places/default/view/Finland-75
# Downloading: http://example.webscraping.com/places/default/view/Fiji-74
# Downloading: http://example.webscraping.com/places/default/view/Faroe-Islands-73
# Downloading: http://example.webscraping.com/places/default/view/Falkland-Islands-72
# Downloading: http://example.webscraping.com/places/default/view/Ethiopia-71
# Downloading: http://example.webscraping.com/places/default/view/Estonia-70
# Downloading: http://example.webscraping.com/places/default/view/Eritrea-69
# Downloading: http://example.webscraping.com/places/default/view/Equatorial-Guinea-68
# Downloading: http://example.webscraping.com/places/default/view/El-Salvador-67
# Downloading: http://example.webscraping.com/places/default/view/Egypt-66
# Downloading: http://example.webscraping.com/places/default/view/Ecuador-65
# Downloading: http://example.webscraping.com/places/default/view/East-Timor-64
# Downloading: http://example.webscraping.com/places/default/view/Dominican-Republic-63
# Downloading: http://example.webscraping.com/places/default/view/Dominica-62
# Downloading: http://example.webscraping.com/places/default/view/Djibouti-61
# Downloading: http://example.webscraping.com/places/default/view/Denmark-60
# Downloading: http://example.webscraping.com/places/default/view/Democratic-Republic-of-the-Congo-59
# Downloading: http://example.webscraping.com/places/default/view/Czech-Republic-58
# Downloading: http://example.webscraping.com/places/default/view/Cyprus-57
# Downloading: http://example.webscraping.com/places/default/view/Curacao-56
# Downloading: http://example.webscraping.com/places/default/view/Cuba-55
# Downloading: http://example.webscraping.com/places/default/view/Croatia-54
# Downloading: http://example.webscraping.com/places/default/view/Costa-Rica-53
# Downloading: http://example.webscraping.com/places/default/view/Cook-Islands-52
# Downloading: http://example.webscraping.com/places/default/view/Comoros-51
# Downloading: http://example.webscraping.com/places/default/view/Colombia-50
# Downloading: http://example.webscraping.com/places/default/view/Cocos-Islands-49
# Downloading: http://example.webscraping.com/places/default/view/Christmas-Island-48
# Downloading: http://example.webscraping.com/places/default/view/China-47
# Downloading: http://example.webscraping.com/places/default/view/Chile-46
# Downloading: http://example.webscraping.com/places/default/view/Chad-45
# Downloading: http://example.webscraping.com/places/default/view/Central-African-Republic-44
# Downloading: http://example.webscraping.com/places/default/view/Cayman-Islands-43
# Downloading: http://example.webscraping.com/places/default/view/Cape-Verde-42
# Downloading: http://example.webscraping.com/places/default/view/Canada-41
# Downloading: http://example.webscraping.com/places/default/view/Cameroon-40
# Downloading: http://example.webscraping.com/places/default/view/Cambodia-39
# Downloading: http://example.webscraping.com/places/default/view/Burundi-38
# Downloading: http://example.webscraping.com/places/default/view/Burkina-Faso-37
# Downloading: http://example.webscraping.com/places/default/view/Bulgaria-36
# Downloading: http://example.webscraping.com/places/default/view/Brunei-35
# Downloading: http://example.webscraping.com/places/default/view/British-Virgin-Islands-34
# Downloading: http://example.webscraping.com/places/default/view/British-Indian-Ocean-Territory-33
# Downloading: http://example.webscraping.com/places/default/view/Brazil-32
# Downloading: http://example.webscraping.com/places/default/view/Bouvet-Island-31
# Downloading: http://example.webscraping.com/places/default/view/Botswana-30
# Downloading: http://example.webscraping.com/places/default/view/Bosnia-and-Herzegovina-29
# Downloading: http://example.webscraping.com/places/default/view/Bonaire-Saint-Eustatius-and-Saba-28
# Downloading: http://example.webscraping.com/places/default/view/Bolivia-27
# Downloading: http://example.webscraping.com/places/default/view/Bhutan-26
# Downloading: http://example.webscraping.com/places/default/view/Bermuda-25
# Downloading: http://example.webscraping.com/places/default/view/Benin-24
# Downloading: http://example.webscraping.com/places/default/view/Belize-23
# Downloading: http://example.webscraping.com/places/default/view/Belgium-22
# Downloading: http://example.webscraping.com/places/default/view/Belarus-21
# Downloading: http://example.webscraping.com/places/default/index/0
# Downloading: http://example.webscraping.com/places/default/view/Barbados-20
# Downloading: http://example.webscraping.com/places/default/view/Bangladesh-19
# Downloading: http://example.webscraping.com/places/default/view/Bahrain-18
# Downloading: http://example.webscraping.com/places/default/view/Bahamas-17
# Downloading: http://example.webscraping.com/places/default/view/Azerbaijan-16
# Downloading: http://example.webscraping.com/places/default/view/Austria-15
# Downloading: http://example.webscraping.com/places/default/view/Australia-14
# Downloading: http://example.webscraping.com/places/default/view/Aruba-13
# Downloading: http://example.webscraping.com/places/default/view/Armenia-12
# Downloading: http://example.webscraping.com/places/default/view/Argentina-11
# Downloading: http://example.webscraping.com/places/default/view/Antigua-and-Barbuda-10
# Downloading: http://example.webscraping.com/places/default/view/Antarctica-9
# Downloading: http://example.webscraping.com/places/default/view/Anguilla-8
# Downloading: http://example.webscraping.com/places/default/view/Angola-7
# Downloading: http://example.webscraping.com/places/default/view/Andorra-6
# Downloading: http://example.webscraping.com/places/default/view/American-Samoa-5
# Downloading: http://example.webscraping.com/places/default/view/Algeria-4
# Downloading: http://example.webscraping.com/places/default/view/Albania-3
# Downloading: http://example.webscraping.com/places/default/view/Aland-Islands-2
# Downloading: http://example.webscraping.com/places/default/view/Afghanistan-1
# Downloading: http://example.webscraping.com/places/default/index

# %%
# coding=utf-8
import datetime
import re
import time
import urllib.error
import urllib.parse
import urllib.request
import urllib.robotparser
import sys


user_agent = 'BadCrawler'
rp = urllib.robotparser.RobotFileParser()
rp.set_url('http://example.webscraping.com/robots.txt')
rp.read()


class Throttle:
    """Add a delay between downloads to the same domain
    """

    def __init__(self, delay):
        # amount of delay between downloads for each domain
        self.delay = delay
        # timestamp of when a domain was last accessed
        self.domains = {}

    def wait(self, url):
        domain = urllib.parse.urlparse(url).netloc
        last_accessed = self.domains.get(domain)
        if self.delay > 0 and last_accessed is not None:
            sleep_secs = self.delay - \
                (datetime.datetime.now() - last_accessed).seconds
            if sleep_secs > 0:
                # domain has been accessed recently
                # so need to sleep
                time.sleep(sleep_secs)
        # update the last accessed time
        self.domains[domain] = datetime.datetime.now()

        
throttle=Throttle(1)


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    '''Support custom User-Agent, proxy and auto retry
    '''
    print('Downloading:', url)  # url is download function's first arguments
    headers = {'User-agent': user_agent}  # user_agent is the second arguments
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


def link_crawler(seed_url, link_regex, max_depth=2):
    """Crawl from the given seed URL following links matched by link_regex
    """
    crawl_queue = [seed_url]
    # keep track which URL's have seen before
    seen = {seed_url: 0}
    while crawl_queue:
        url = crawl_queue.pop()
        # check url passes robots.txt restrictions
        if rp.can_fetch(user_agent, url):
            throttle.wait(url)
            html = download(url, user_agent, proxy, 2)
        else:
            print('Blocked by robots.txt:', url)
            html = None
            sys.exit()
        # filter for links matching our regular expression
        depth = seen[url]
        if depth != max_depth:
            for link in get_links(html):
                # check if link matches expected regex
                if re.match(link_regex, link):
                    # form absolute link
                    link = urllib.parse.urljoin(seed_url, link)
                    # check if have already seen this link
                    if link not in seen:
                        seen[link] = depth + 1
                        crawl_queue.append(link)


def get_links(html):
    """Return a list of links from html
    """
    # a regular expression to extract all links from the webpage
    webpage_regex = re.compile('<a[^>]+href=["\'](.*?)["\']', re.IGNORECASE)
    # list of all links from the webpage
    return webpage_regex.findall(html)


link_crawler('http://example.webscraping.com', '/places/default/(index|view)', 2)
# Out:
# Blocked by robots.txt: http://example.webscraping.com
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# D:\Program Files\Python\lib\site-packages\IPython\core\interactiveshell.py:2918: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# coding=utf-8
import datetime
import re
import time
import urllib.error
import urllib.parse
import urllib.request
import urllib.robotparser
import sys


user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36'
rp = urllib.robotparser.RobotFileParser()
rp.set_url('http://example.webscraping.com/robots.txt')
rp.read()
proxy = None


class Throttle:
    """Add a delay between downloads to the same domain
    """

    def __init__(self, delay):
        # amount of delay between downloads for each domain
        self.delay = delay
        # timestamp of when a domain was last accessed
        self.domains = {}

    def wait(self, url):
        domain = urllib.parse.urlparse(url).netloc
        last_accessed = self.domains.get(domain)
        if self.delay > 0 and last_accessed is not None:
            sleep_secs = self.delay - \
                (datetime.datetime.now() - last_accessed).seconds
            if sleep_secs > 0:
                # domain has been accessed recently
                # so need to sleep
                time.sleep(sleep_secs)
        # update the last accessed time
        self.domains[domain] = datetime.datetime.now()

        
throttle=Throttle(1)


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    '''Support custom User-Agent, proxy and auto retry
    '''
    print('Downloading:', url)  # url is download function's first arguments
    headers = {'User-agent': user_agent}  # user_agent is the second arguments
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


def link_crawler(seed_url, link_regex, max_depth=2):
    """Crawl from the given seed URL following links matched by link_regex
    """
    crawl_queue = [seed_url]
    # keep track which URL's have seen before
    seen = {seed_url: 0}
    while crawl_queue:
        url = crawl_queue.pop()
        # check url passes robots.txt restrictions
        if rp.can_fetch(user_agent, url):
            throttle.wait(url)
            html = download(url, user_agent, proxy, 2)
        else:
            print('Blocked by robots.txt:', url)
            html = None
            sys.exit()
        # filter for links matching our regular expression
        depth = seen[url]
        if depth != max_depth:
            for link in get_links(html):
                # check if link matches expected regex
                if re.match(link_regex, link):
                    # form absolute link
                    link = urllib.parse.urljoin(seed_url, link)
                    # check if have already seen this link
                    if link not in seen:
                        seen[link] = depth + 1
                        crawl_queue.append(link)


def get_links(html):
    """Return a list of links from html
    """
    # a regular expression to extract all links from the webpage
    webpage_regex = re.compile('<a[^>]+href=["\'](.*?)["\']', re.IGNORECASE)
    # list of all links from the webpage
    return webpage_regex.findall(html)


link_crawler('http://example.webscraping.com', '/places/default/(index|view)', 1)
# Out:
# Downloading: http://example.webscraping.com
# Downloading: http://example.webscraping.com/places/default/index/1
# Downloading: http://example.webscraping.com/places/default/view/Antigua-and-Barbuda-10
# Downloading: http://example.webscraping.com/places/default/view/Antarctica-9
# Downloading: http://example.webscraping.com/places/default/view/Anguilla-8
# Downloading: http://example.webscraping.com/places/default/view/Angola-7
# Downloading: http://example.webscraping.com/places/default/view/Andorra-6
# Downloading: http://example.webscraping.com/places/default/view/American-Samoa-5
# Downloading: http://example.webscraping.com/places/default/view/Algeria-4
# Downloading: http://example.webscraping.com/places/default/view/Albania-3
# Downloading: http://example.webscraping.com/places/default/view/Aland-Islands-2
# Downloading: http://example.webscraping.com/places/default/view/Afghanistan-1
# Downloading: http://example.webscraping.com/places/default/index

# %%
import re
import urllib.request
import urllib.parse
import urllib.error


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    '''Support custom User-Agent, proxy and auto retry
    '''
    print('Downloading:', url)  # url is download function's first arguments
    headers = {'User-agent': user_agent}  # user_agent is the second arguments
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


url = 'http://example.webscraping.com/places/default/view/United-Kingdom-239'
ua = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
proxy = None
html = download(url)
re.findall('<td class="w2p_fw">(.*?)</td>', html)
# Out:
# Downloading: http://example.webscraping.com/places/default/view/United-Kingdom-239
# ['<img src="/places/static/images/flags/gb.png" />',
#  '244,820 square kilometres',
#  '62,348,447',
#  'GB',
#  'United Kingdom',
#  'London',
#  '<a href="/places/default/continent/EU">EU</a>',
#  '.uk',
#  'GBP',
#  'Pound',
#  '44',
#  '@# #@@|@## #@@|@@# #@@|@@## #@@|@#@ #@@|@@#@ #@@|GIR0AA',
#  '^(([A-Z]\\d{2}[A-Z]{2})|([A-Z]\\d{3}[A-Z]{2})|([A-Z]{2}\\d{2}[A-Z]{2})|([A-Z]{2}\\d{3}[A-Z]{2})|([A-Z]\\d[A-Z]\\d[A-Z]{2})|([A-Z]{2}\\d[A-Z]\\d[A-Z]{2})|(GIR0AA))$',
#  'en-GB,cy-GB,gd',
#  '<div><a href="/places/default/iso/IE">IE </a></div>']

# %%
import re
import urllib.request
import urllib.parse
import urllib.error


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    '''Support custom User-Agent, proxy and auto retry
    '''
    print('Downloading:', url)  # url is download function's first arguments
    headers = {'User-agent': user_agent}  # user_agent is the second arguments
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


url = 'http://example.webscraping.com/places/default/view/United-Kingdom-239'
ua = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
proxy = None
html = download(url)
re.findall('<td class="w2p_fw">(.*?)</td>', html)[1]
# Out:
# Downloading: http://example.webscraping.com/places/default/view/United-Kingdom-239
# '244,820 square kilometres'

# %%
import re
import urllib.request
import urllib.parse
import urllib.error


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    '''Support custom User-Agent, proxy and auto retry
    '''
    print('Downloading:', url)  # url is download function's first arguments
    headers = {'User-agent': user_agent}  # user_agent is the second arguments
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


url = 'http://example.webscraping.com/places/default/view/United-Kingdom-239'
ua = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
proxy = None
html = download(url)
re.findall('<tr id="places_area__row"><td class="w2p_fl"><label class="readonly" for="places_area" id="places_area__label">Area: </label></td><td class="w2p_fw">(.*?)</td>', html)
# Out:
# Downloading: http://example.webscraping.com/places/default/view/United-Kingdom-239
# ['244,820 square kilometres']

# %%
import re
import urllib.request
import urllib.parse
import urllib.error


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    '''Support custom User-Agent, proxy and auto retry
    '''
    print('Downloading:', url)  # url is download function's first arguments
    headers = {'User-agent': user_agent}  # user_agent is the second arguments
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


url = 'http://example.webscraping.com/places/default/view/United-Kingdom-239'
ua = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
proxy = None
html = download(url)
re.findall('<tr id="places_area__row">.*?<td\s*class=["\']w2p_fw["\']>(.*?)</td>', html)
# Out:
# Downloading: http://example.webscraping.com/places/default/view/United-Kingdom-239
# ['244,820 square kilometres']

# %%
from bs4 import BeautifulSoup


broken_html = '<ul class=country><li>Area<li>Population</ul>'
# parse the HTML
soup = BeautifulSoup(broken_html, 'html.parser')
fixed_html = soup.prettify()
print(fixed_html)
# Out:
# <ul class="country">
#  <li>
#   Area
#   <li>
#    Population
#   </li>
#  </li>
# </ul>

# %%
from bs4 import BeautifulSoup


broken_html = '<ul class=country><li>Area<li>Population</ul>'
# parse the HTML
soup = BeautifulSoup(broken_html, 'lxml')
fixed_html = soup.prettify()
print(fixed_html)
# Out:
# <html>
#  <body>
#   <ul class="country">
#    <li>
#     Area
#    </li>
#    <li>
#     Population
#    </li>
#   </ul>
#  </body>
# </html>

# %% [markdown]
# ##### BeautifulSoup的prettify()方法、find()方法和find_all()方法
# find()方法和find_all()方法貌似包含prettify()的功能

# %%
from bs4 import BeautifulSoup


broken_html = '<ul class=country><li>Area<li>Population</ul>'
# parse the HTML
soup = BeautifulSoup(broken_html, 'lxml')
# fixed_html = soup.prettify()
# print(fixed_html)
ul = soup.find('ul', attrs={'class': 'country'})
print(ul.find('li'))  # returns just the first match
print(ul.find_all('li'))  # returns all matches
# Out:
# <li>Area</li>
# [<li>Area</li>, <li>Population</li>]

# %%
from bs4 import BeautifulSoup


url = 'http://example.webscraping.com/places/default/view/United-Kingdom-239'
html = download(url)
soup = BeautifulSoup(html, 'lxml')
# locate the area row
tr = soup.find(attrs={'id': 'places_area__row'})
td = tr.find(attrs={'class': 'w2p_fw'})  # locate the area tag
area = td.text  # extract the text from this tag
print(area)
# Out:
# Downloading: http://example.webscraping.com/places/default/view/United-Kingdom-239
# 244,820 square kilometres

# %%
import lxml.html


broken_html = '<ul class=country><li>Area<li>Population</ul>'
tree = lxml.html.fromstring(broken_html)  # parse the HTML
fixed_html = lxml.html.tostring(tree, pretty_print=True)
print(fixed_html)
# Out:
# b'<ul class="country">\n<li>Area</li>\n<li>Population</li>\n</ul>\n'

# %%
import lxml.html
import lxml.etree


broken_html = '<ul class=country><li>Area<li>Population</ul>'
tree = lxml.html.fromstring(broken_html)  # parse the HTML
fixed_html = lxml.html.tostring(tree, pretty_print=True, encoding='unicode')
print(fixed_html)
print('---------------------')
etree_html = lxml.etree.tostring(tree, pretty_print=True, encoding='unicode')
print(etree_html)
# Out:
# <ul class="country">
# <li>Area</li>
# <li>Population</li>
# </ul>
#
# ---------------------
# <ul class="country">
#   <li>Area</li>
#   <li>Population</li>
# </ul>

# %%
# -*- coding: utf-8 -*-

import urllib.request
import urllib.parse
import urllib.error
import lxml.html


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    '''Support custom User-Agent, proxy and auto retry
    '''
    print('Downloading:', url)  # url is download function's first arguments
    headers = {'User-agent': user_agent}  # user_agent is the second arguments
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


url= 'http://example.webscraping.com/places/default/view/United-Kingdom-239'
ua = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
html = download(url, ua)
tree = lxml.html.fromstring(html)
td = tree.cssselect('tr#places_area__row > td.w2p_fw')[0]
area = td.text_content()
print(area)
# Out:
# Downloading: http://example.webscraping.com/places/default/view/United-Kingdom-239
# 244,820 square kilometres

# %%
import re
import lxml.html
import time
import urllib.request
import urllib.parse
import urllib.error
from bs4 import BeautifulSoup

FIELDS = ('area', 'population', 'iso', 'country', 'capital', 'continent', \
          'tld', 'currency_code', 'currency_name', 'phone', \
          'postal_code_format', 'postal_code_regex', 'languages', 'neighbours')


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    '''Support custom User-Agent, proxy and auto retry
    '''
    print('Downloading:', url)  # url is download function's first arguments
    headers = {'User-agent': user_agent}  # user_agent is the second arguments
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


def re_scraper(html):
    results = {}
    for field in FIELDS:
        results[field] = re.search('<tr id="places_{}__row">.*?<td class="w2p_fw">(.*?)</td>'.format(field), html).groups()[0]
    return results


def bs_scraper(html):
    soup = BeautifulSoup(html, 'html.parser')
    results = {}
    for field in FIELDS:
        results[field] = soup.find('table').find('tr', id='places_{}__row'.format(field)).find('td', class_='w2p_fw').text
    return results


def lxml_scraper(html):
    tree = lxml.html.fromstring(html)
    results = {}
    for field in FIELDS:
        results[field] = tree.cssselect('table > tr#places_{}__row > td.w2p_fw'.format(field))[0].text_content()
    return results


NUM_ITERATIONS = 1000  # number of times to test each scraper
html = download('http://example.webscraping.com/places/default/view/United-Kingdom-239')
for name, scraper in [('Regular expressions', re_scraper), ('BeautifulSoup', bs_scraper), ('Lxml', lxml_scraper)]:
    # record start time of scrape
    start = time.time()
    for i in range(NUM_ITERATIONS):
        if scraper == re_scraper:
            re.purge()
        result = scraper(html)
        # check scraped result is as expected
        assert(result['area'] == '244,820 square kilometres')
        # record end time of scrape and output the total
        end = time.time()
        print('%s: %.2f seconds' % (name, end - start))
# Out:
# Downloading: http://example.webscraping.com/places/default/view/United-Kingdom-239
# Regular expressions: 0.01 seconds
# Regular expressions: 0.02 seconds
# Regular expressions: 0.03 seconds
# Regular expressions: 0.04 seconds
# Regular expressions: 0.04 seconds
# Regular expressions: 0.05 seconds
# Regular expressions: 0.05 seconds
# Regular expressions: 0.06 seconds
# Regular expressions: 0.06 seconds
# Regular expressions: 0.07 seconds
# Regular expressions: 0.07 seconds
# Regular expressions: 0.08 seconds
# Regular expressions: 0.08 seconds
# Regular expressions: 0.09 seconds
# Regular expressions: 0.09 seconds
# Regular expressions: 0.09 seconds
# Regular expressions: 0.10 seconds
# Regular expressions: 0.10 seconds
# Regular expressions: 0.11 seconds
# Regular expressions: 0.11 seconds
# Regular expressions: 0.12 seconds
# Regular expressions: 0.12 seconds
# Regular expressions: 0.12 seconds
# Regular expressions: 0.13 seconds
# Regular expressions: 0.13 seconds
# Regular expressions: 0.14 seconds
# Regular expressions: 0.14 seconds
# Regular expressions: 0.15 seconds
# Regular expressions: 0.15 seconds
# Regular expressions: 0.15 seconds
# Regular expressions: 0.16 seconds
# Lxml: 7.99 seconds
# Lxml: 8.00 seconds
# Lxml: 8.01 seconds
# Lxml: 8.01 seconds
# Lxml: 8.02 seconds
# Lxml: 8.03 seconds
# Lxml: 8.03 seconds
# Lxml: 8.04 seconds
# Lxml: 8.05 seconds
# Lxml: 8.06 seconds
# Lxml: 8.07 seconds
# Lxml: 8.07 seconds
# Lxml: 8.08 seconds

# %%
import re
import lxml.html
import time
import urllib.request
import urllib.parse
import urllib.error
from bs4 import BeautifulSoup

FIELDS = ('area', 'population', 'iso', 'country', 'capital', 'continent', \
          'tld', 'currency_code', 'currency_name', 'phone', \
          'postal_code_format', 'postal_code_regex', 'languages', 'neighbours')


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    '''Support custom User-Agent, proxy and auto retry
    '''
    print('Downloading:', url)  # url is download function's first arguments
    headers = {'User-agent': user_agent}  # user_agent is the second arguments
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


def re_scraper(html):
    results = {}
    for field in FIELDS:
        results[field] = re.search('<tr id="places_{}__row">.*?<td class="w2p_fw">(.*?)</td>'.format(field), html).groups()[0]
    return results


def bs_scraper(html):
    soup = BeautifulSoup(html, 'html.parser')
    results = {}
    for field in FIELDS:
        results[field] = soup.find('table').find('tr', id='places_{}__row'.format(field)).find('td', class_='w2p_fw').text
    return results


def lxml_scraper(html):
    tree = lxml.html.fromstring(html)
    results = {}
    for field in FIELDS:
        results[field] = tree.cssselect('table > tr#places_{}__row > td.w2p_fw'.format(field))[0].text_content()
    return results


NUM_ITERATIONS = 1000  # number of times to test each scraper
html = download('http://example.webscraping.com/places/default/view/United-Kingdom-239')
for name, scraper in [('Regular expressions', re_scraper), ('BeautifulSoup', bs_scraper), ('Lxml', lxml_scraper)]:
    # record start time of scrape
    start = time.time()
    for i in range(NUM_ITERATIONS):
        if scraper == re_scraper:
            re.purge()
        result = scraper(html)
        # check scraped result is as expected
        assert(result['area'] == '244,820 square kilometres')
    # record end time of scrape and output the total
    end = time.time()
    print('%s: %.2f seconds' % (name, end - start))
# Out:
# Downloading: http://example.webscraping.com/places/default/view/United-Kingdom-239
# Regular expressions: 4.01 seconds
# BeautifulSoup: 33.95 seconds
# Lxml: 5.81 seconds

# %%
# coding=utf-8
import datetime
import re
import time
import urllib.error
import urllib.parse
import urllib.request
import urllib.robotparser
import sys


user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36'
rp = urllib.robotparser.RobotFileParser()
rp.set_url('http://example.webscraping.com/robots.txt')
rp.read()
proxy = None


class Throttle:
    """Add a delay between downloads to the same domain
    """

    def __init__(self, delay):
        # amount of delay between downloads for each domain
        self.delay = delay
        # timestamp of when a domain was last accessed
        self.domains = {}

    def wait(self, url):
        domain = urllib.parse.urlparse(url).netloc
        last_accessed = self.domains.get(domain)
        if self.delay > 0 and last_accessed is not None:
            sleep_secs = self.delay - \
                (datetime.datetime.now() - last_accessed).seconds
            if sleep_secs > 0:
                # domain has been accessed recently
                # so need to sleep
                time.sleep(sleep_secs)
        # update the last accessed time
        self.domains[domain] = datetime.datetime.now()

        
throttle=Throttle(1)


def download(url, user_agent='wswp', proxy=None, num_retries=2):
    '''Support custom User-Agent, proxy and auto retry
    '''
    print('Downloading:', url)  # url is download function's first arguments
    headers = {'User-agent': user_agent}  # user_agent is the second arguments
    request = urllib.request.Request(url, headers=headers)
    opener = urllib.request.build_opener()
    if proxy:
        proxy_params = {urllib.parse.urlparse(url).scheme: proxy}
        opener.add_handler(urllib.request.ProxyHandler(proxy_params))
    try:
        html = opener.open(request).read().decode()
    except urllib.error.URLError as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # retry 5XX HTTP errors
                html = download(url, user_agent, proxy, num_retries - 1)
    return html


def link_crawler(seed_url, link_regex, max_depth=2, scrape_callback=None):
    """Crawl from the given seed URL following links matched by link_regex
    """
    crawl_queue = [seed_url]
    # keep track which URL's have seen before
    seen = {seed_url: 0}
    while crawl_queue:
        url = crawl_queue.pop()
        # check url passes robots.txt restrictions
        if rp.can_fetch(user_agent, url):
            throttle.wait(url)
            html = download(url, user_agent, proxy, 2)
            links = []
            if scrape_callback:
                links.extend(scrape_callback(url, html) or [])
        else:
            print('Blocked by robots.txt:', url)
            html = None
            sys.exit()
        # filter for links matching our regular expression
        depth = seen[url]
        if depth != max_depth:
            for link in get_links(html):
                # check if link matches expected regex
                if re.match(link_regex, link):
                    # form absolute link
                    link = urllib.parse.urljoin(seed_url, link)
                    # check if have already seen this link
                    if link not in seen:
                        seen[link] = depth + 1
                        crawl_queue.append(link)


def get_links(html):
    """Return a list of links from html
    """
    # a regular expression to extract all links from the webpage
    webpage_regex = re.compile('<a[^>]+href=["\'](.*?)["\']', re.IGNORECASE)
    # list of all links from the webpage
    return webpage_regex.findall(html)

# %%
import csv
import lxml.html
import re


class ScrapeCallback:

    def __init__(self):
        self.writer = csv.writer(open('countries_jupyter.csv', 'w', newline=''))
        self.fields = ('area', 'population', 'iso', 'country', 'capital',
                       'continent', 'tld', 'currency_code', 'currency_name',
                       'phone', 'postal_code_format', 'postal_code_regex',
                       'languages', 'neighbours')
        self.writer.writerow(self.fields)

    def __call__(self, url, html):
        if re.search('/view/', url):
            tree = lxml.html.fromstring(html)
            row = []
            for field in self.fields:
                row.append(tree.cssselect(
                    'table > tr#places_{}__row > td.w2p_fw'.format(field))[0].text_content())
            self.writer.writerow(row)


if __name__ == '__main__':
    link_crawler('http://example.webscraping.com', '/places/default/(index|view)',
                 max_depth=-1, scrape_callback=ScrapeCallback())
# Out:
# Downloading: http://example.webscraping.com
# Downloading: http://example.webscraping.com/places/default/index/1
# Downloading: http://example.webscraping.com/places/default/index/2
# Downloading: http://example.webscraping.com/places/default/index/3
# Downloading: http://example.webscraping.com/places/default/index/4
# Downloading: http://example.webscraping.com/places/default/index/5
# Downloading: http://example.webscraping.com/places/default/index/6
# Downloading: http://example.webscraping.com/places/default/index/7
# Downloading: http://example.webscraping.com/places/default/index/8
# Downloading: http://example.webscraping.com/places/default/index/9
# Downloading: http://example.webscraping.com/places/default/index/10
# Downloading: http://example.webscraping.com/places/default/index/11
# Downloading: http://example.webscraping.com/places/default/index/12
# Downloading: http://example.webscraping.com/places/default/index/13
# Downloading: http://example.webscraping.com/places/default/index/14
# Downloading: http://example.webscraping.com/places/default/index/15
# Downloading: http://example.webscraping.com/places/default/index/16
# Downloading: http://example.webscraping.com/places/default/index/17
# Downloading: http://example.webscraping.com/places/default/index/18
# Downloading: http://example.webscraping.com/places/default/index/19
# Downloading: http://example.webscraping.com/places/default/index/20
# Downloading: http://example.webscraping.com/places/default/index/21
# Downloading: http://example.webscraping.com/places/default/index/22
# Downloading: http://example.webscraping.com/places/default/index/23
# Downloading: http://example.webscraping.com/places/default/index/24
# Downloading: http://example.webscraping.com/places/default/index/25
# Downloading: http://example.webscraping.com/places/default/view/Zimbabwe-252
# Downloading: http://example.webscraping.com/places/default/view/Zambia-251
# Downloading: http://example.webscraping.com/places/default/view/Yemen-250
# Downloading: http://example.webscraping.com/places/default/view/Western-Sahara-249
# Downloading: http://example.webscraping.com/places/default/view/Wallis-and-Futuna-248
# Downloading: http://example.webscraping.com/places/default/view/Vietnam-247
# Downloading: http://example.webscraping.com/places/default/view/Venezuela-246
# Downloading: http://example.webscraping.com/places/default/view/Vatican-245
# Downloading: http://example.webscraping.com/places/default/view/Vanuatu-244
# Downloading: http://example.webscraping.com/places/default/view/Uzbekistan-243
# Downloading: http://example.webscraping.com/places/default/view/Uruguay-242
# Downloading: http://example.webscraping.com/places/default/view/United-States-Minor-Outlying-Islands-241
# Downloading: http://example.webscraping.com/places/default/view/United-States-240
# Downloading: http://example.webscraping.com/places/default/view/United-Kingdom-239
# Downloading: http://example.webscraping.com/places/default/view/United-Arab-Emirates-238
# Downloading: http://example.webscraping.com/places/default/view/Ukraine-237
# Downloading: http://example.webscraping.com/places/default/view/Uganda-236
# Downloading: http://example.webscraping.com/places/default/view/US-Virgin-Islands-235
# Downloading: http://example.webscraping.com/places/default/view/Tuvalu-234
# Downloading: http://example.webscraping.com/places/default/view/Turks-and-Caicos-Islands-233
# Downloading: http://example.webscraping.com/places/default/view/Turkmenistan-232
# Downloading: http://example.webscraping.com/places/default/view/Turkey-231
# Downloading: http://example.webscraping.com/places/default/view/Tunisia-230
# Downloading: http://example.webscraping.com/places/default/view/Trinidad-and-Tobago-229
# Downloading: http://example.webscraping.com/places/default/view/Tonga-228
# Downloading: http://example.webscraping.com/places/default/view/Tokelau-227
# Downloading: http://example.webscraping.com/places/default/view/Togo-226
# Downloading: http://example.webscraping.com/places/default/view/Thailand-225
# Downloading: http://example.webscraping.com/places/default/view/Tanzania-224
# Downloading: http://example.webscraping.com/places/default/view/Tajikistan-223
# Downloading: http://example.webscraping.com/places/default/view/Taiwan-222
# Downloading: http://example.webscraping.com/places/default/view/Syria-221
# Downloading: http://example.webscraping.com/places/default/view/Switzerland-220
# Downloading: http://example.webscraping.com/places/default/view/Sweden-219
# Downloading: http://example.webscraping.com/places/default/view/Swaziland-218
# Downloading: http://example.webscraping.com/places/default/view/Svalbard-and-Jan-Mayen-217
# Downloading: http://example.webscraping.com/places/default/view/Suriname-216
# Downloading: http://example.webscraping.com/places/default/view/Sudan-215
# Downloading: http://example.webscraping.com/places/default/view/Sri-Lanka-214
# Downloading: http://example.webscraping.com/places/default/view/Spain-213
# Downloading: http://example.webscraping.com/places/default/view/South-Sudan-212
# Downloading: http://example.webscraping.com/places/default/view/South-Korea-211
# Downloading: http://example.webscraping.com/places/default/view/South-Georgia-and-the-South-Sandwich-Islands-210
# Downloading: http://example.webscraping.com/places/default/view/South-Africa-209
# Downloading: http://example.webscraping.com/places/default/view/Somalia-208
# Downloading: http://example.webscraping.com/places/default/view/Solomon-Islands-207
# Downloading: http://example.webscraping.com/places/default/view/Slovenia-206
# Downloading: http://example.webscraping.com/places/default/view/Slovakia-205
# Downloading: http://example.webscraping.com/places/default/view/Sint-Maarten-204
# Downloading: http://example.webscraping.com/places/default/view/Singapore-203
# Downloading: http://example.webscraping.com/places/default/view/Sierra-Leone-202
# Downloading: http://example.webscraping.com/places/default/view/Seychelles-201
# Downloading: http://example.webscraping.com/places/default/view/Serbia-and-Montenegro-200
# Downloading: http://example.webscraping.com/places/default/view/Serbia-199
# Downloading: http://example.webscraping.com/places/default/view/Senegal-198
# Downloading: http://example.webscraping.com/places/default/view/Saudi-Arabia-197
# Downloading: http://example.webscraping.com/places/default/view/Sao-Tome-and-Principe-196
# Downloading: http://example.webscraping.com/places/default/view/San-Marino-195
# Downloading: http://example.webscraping.com/places/default/view/Samoa-194
# Downloading: http://example.webscraping.com/places/default/view/Saint-Vincent-and-the-Grenadines-193
# Downloading: http://example.webscraping.com/places/default/view/Saint-Pierre-and-Miquelon-192
# Downloading: http://example.webscraping.com/places/default/view/Saint-Martin-191
# Downloading: http://example.webscraping.com/places/default/view/Saint-Lucia-190
# Downloading: http://example.webscraping.com/places/default/view/Saint-Kitts-and-Nevis-189
# Downloading: http://example.webscraping.com/places/default/view/Saint-Helena-188
# Downloading: http://example.webscraping.com/places/default/view/Saint-Barthelemy-187
# Downloading: http://example.webscraping.com/places/default/view/Rwanda-186
# Downloading: http://example.webscraping.com/places/default/view/Russia-185
# Downloading: http://example.webscraping.com/places/default/view/Romania-184
# Downloading: http://example.webscraping.com/places/default/view/Reunion-183
# Downloading: http://example.webscraping.com/places/default/view/Republic-of-the-Congo-182
# Downloading: http://example.webscraping.com/places/default/view/Qatar-181
# Downloading: http://example.webscraping.com/places/default/view/Puerto-Rico-180
# Downloading: http://example.webscraping.com/places/default/view/Portugal-179
# Downloading: http://example.webscraping.com/places/default/view/Poland-178
# Downloading: http://example.webscraping.com/places/default/view/Pitcairn-177
# Downloading: http://example.webscraping.com/places/default/view/Philippines-176
# Downloading: http://example.webscraping.com/places/default/view/Peru-175
# Downloading: http://example.webscraping.com/places/default/view/Paraguay-174
# Downloading: http://example.webscraping.com/places/default/view/Papua-New-Guinea-173
# Downloading: http://example.webscraping.com/places/default/view/Panama-172
# Downloading: http://example.webscraping.com/places/default/view/Palestinian-Territory-171
# Downloading: http://example.webscraping.com/places/default/view/Palau-170
# Downloading: http://example.webscraping.com/places/default/view/Pakistan-169
# Downloading: http://example.webscraping.com/places/default/view/Oman-168
# Downloading: http://example.webscraping.com/places/default/view/Norway-167
# Downloading: http://example.webscraping.com/places/default/view/Northern-Mariana-Islands-166
# Downloading: http://example.webscraping.com/places/default/view/North-Korea-165
# Downloading: http://example.webscraping.com/places/default/view/Norfolk-Island-164
# Downloading: http://example.webscraping.com/places/default/view/Niue-163
# Downloading: http://example.webscraping.com/places/default/view/Nigeria-162
# Downloading: http://example.webscraping.com/places/default/view/Niger-161
# Downloading: http://example.webscraping.com/places/default/view/Nicaragua-160
# Downloading: http://example.webscraping.com/places/default/view/New-Zealand-159
# Downloading: http://example.webscraping.com/places/default/view/New-Caledonia-158
# Downloading: http://example.webscraping.com/places/default/view/Netherlands-Antilles-157
# Downloading: http://example.webscraping.com/places/default/view/Netherlands-156
# Downloading: http://example.webscraping.com/places/default/view/Nepal-155
# Downloading: http://example.webscraping.com/places/default/view/Nauru-154
# Downloading: http://example.webscraping.com/places/default/view/Namibia-153
# Downloading: http://example.webscraping.com/places/default/view/Myanmar-152
# Downloading: http://example.webscraping.com/places/default/view/Mozambique-151
# Downloading: http://example.webscraping.com/places/default/view/Morocco-150
# Downloading: http://example.webscraping.com/places/default/view/Montserrat-149
# Downloading: http://example.webscraping.com/places/default/view/Montenegro-148
# Downloading: http://example.webscraping.com/places/default/view/Mongolia-147
# Downloading: http://example.webscraping.com/places/default/view/Monaco-146
# Downloading: http://example.webscraping.com/places/default/view/Moldova-145
# Downloading: http://example.webscraping.com/places/default/view/Micronesia-144
# Downloading: http://example.webscraping.com/places/default/view/Mexico-143
# Downloading: http://example.webscraping.com/places/default/view/Mayotte-142
# Downloading: http://example.webscraping.com/places/default/view/Mauritius-141
# Downloading: http://example.webscraping.com/places/default/view/Mauritania-140
# Downloading: http://example.webscraping.com/places/default/view/Martinique-139
# Downloading: http://example.webscraping.com/places/default/view/Marshall-Islands-138
# Downloading: http://example.webscraping.com/places/default/view/Malta-137
# Downloading: http://example.webscraping.com/places/default/view/Mali-136
# Downloading: http://example.webscraping.com/places/default/view/Maldives-135
# Downloading: http://example.webscraping.com/places/default/view/Malaysia-134
# Downloading: http://example.webscraping.com/places/default/view/Malawi-133
# Downloading: http://example.webscraping.com/places/default/view/Madagascar-132
# Downloading: http://example.webscraping.com/places/default/view/Macedonia-131
# Downloading: http://example.webscraping.com/places/default/view/Macao-130
# Downloading: http://example.webscraping.com/places/default/view/Luxembourg-129
# Downloading: http://example.webscraping.com/places/default/view/Lithuania-128
# Downloading: http://example.webscraping.com/places/default/view/Liechtenstein-127
# Downloading: http://example.webscraping.com/places/default/view/Libya-126
# Downloading: http://example.webscraping.com/places/default/view/Liberia-125
# Downloading: http://example.webscraping.com/places/default/view/Lesotho-124
# Downloading: http://example.webscraping.com/places/default/view/Lebanon-123
# Downloading: http://example.webscraping.com/places/default/view/Latvia-122
# Downloading: http://example.webscraping.com/places/default/view/Laos-121
# Downloading: http://example.webscraping.com/places/default/view/Kyrgyzstan-120
# Downloading: http://example.webscraping.com/places/default/view/Kuwait-119
# Downloading: http://example.webscraping.com/places/default/view/Kosovo-118
# Downloading: http://example.webscraping.com/places/default/view/Kiribati-117
# Downloading: http://example.webscraping.com/places/default/view/Kenya-116
# Downloading: http://example.webscraping.com/places/default/view/Kazakhstan-115
# Downloading: http://example.webscraping.com/places/default/view/Jordan-114
# Downloading: http://example.webscraping.com/places/default/view/Jersey-113
# Downloading: http://example.webscraping.com/places/default/view/Japan-112
# Downloading: http://example.webscraping.com/places/default/view/Jamaica-111
# Downloading: http://example.webscraping.com/places/default/view/Ivory-Coast-110
# Downloading: http://example.webscraping.com/places/default/view/Italy-109
# Downloading: http://example.webscraping.com/places/default/view/Israel-108
# Downloading: http://example.webscraping.com/places/default/view/Isle-of-Man-107
# Downloading: http://example.webscraping.com/places/default/view/Ireland-106
# Downloading: http://example.webscraping.com/places/default/view/Iraq-105
# Downloading: http://example.webscraping.com/places/default/view/Iran-104
# Downloading: http://example.webscraping.com/places/default/view/Indonesia-103
# Downloading: http://example.webscraping.com/places/default/view/India-102
# Downloading: http://example.webscraping.com/places/default/view/Iceland-101
# Downloading: http://example.webscraping.com/places/default/view/Hungary-100
# Downloading: http://example.webscraping.com/places/default/view/Hong-Kong-99
# Downloading: http://example.webscraping.com/places/default/view/Honduras-98
# Downloading: http://example.webscraping.com/places/default/view/Heard-Island-and-McDonald-Islands-97
# Downloading: http://example.webscraping.com/places/default/view/Haiti-96
# Downloading: http://example.webscraping.com/places/default/view/Guyana-95
# Downloading: http://example.webscraping.com/places/default/view/Guinea-Bissau-94
# Downloading: http://example.webscraping.com/places/default/view/Guinea-93
# Downloading: http://example.webscraping.com/places/default/view/Guernsey-92
# Downloading: http://example.webscraping.com/places/default/view/Guatemala-91
# Downloading: http://example.webscraping.com/places/default/view/Guam-90
# Downloading: http://example.webscraping.com/places/default/view/Guadeloupe-89
# Downloading: http://example.webscraping.com/places/default/view/Grenada-88
# Downloading: http://example.webscraping.com/places/default/view/Greenland-87
# Downloading: http://example.webscraping.com/places/default/view/Greece-86
# Downloading: http://example.webscraping.com/places/default/view/Gibraltar-85
# Downloading: http://example.webscraping.com/places/default/view/Ghana-84
# Downloading: http://example.webscraping.com/places/default/view/Germany-83
# Downloading: http://example.webscraping.com/places/default/view/Georgia-82
# Downloading: http://example.webscraping.com/places/default/view/Gambia-81
# Downloading: http://example.webscraping.com/places/default/view/Gabon-80
# Downloading: http://example.webscraping.com/places/default/view/French-Southern-Territories-79
# Downloading: http://example.webscraping.com/places/default/view/French-Polynesia-78
# Downloading: http://example.webscraping.com/places/default/view/French-Guiana-77
# Downloading: http://example.webscraping.com/places/default/view/France-76
# Downloading: http://example.webscraping.com/places/default/view/Finland-75
# Downloading: http://example.webscraping.com/places/default/view/Fiji-74
# Downloading: http://example.webscraping.com/places/default/view/Faroe-Islands-73
# Downloading: http://example.webscraping.com/places/default/view/Falkland-Islands-72
# Downloading: http://example.webscraping.com/places/default/view/Ethiopia-71
# Downloading: http://example.webscraping.com/places/default/view/Estonia-70
# Downloading: http://example.webscraping.com/places/default/view/Eritrea-69
# Downloading: http://example.webscraping.com/places/default/view/Equatorial-Guinea-68
# Downloading: http://example.webscraping.com/places/default/view/El-Salvador-67
# Downloading: http://example.webscraping.com/places/default/view/Egypt-66
# Downloading: http://example.webscraping.com/places/default/view/Ecuador-65
# Downloading: http://example.webscraping.com/places/default/view/East-Timor-64
# Downloading: http://example.webscraping.com/places/default/view/Dominican-Republic-63
# Downloading: http://example.webscraping.com/places/default/view/Dominica-62
# Downloading: http://example.webscraping.com/places/default/view/Djibouti-61
# Downloading: http://example.webscraping.com/places/default/view/Denmark-60
# Downloading: http://example.webscraping.com/places/default/view/Democratic-Republic-of-the-Congo-59
# Downloading: http://example.webscraping.com/places/default/view/Czech-Republic-58
# Downloading: http://example.webscraping.com/places/default/view/Cyprus-57
# Downloading: http://example.webscraping.com/places/default/view/Curacao-56
# Downloading: http://example.webscraping.com/places/default/view/Cuba-55
# Downloading: http://example.webscraping.com/places/default/view/Croatia-54
# Downloading: http://example.webscraping.com/places/default/view/Costa-Rica-53
# Downloading: http://example.webscraping.com/places/default/view/Cook-Islands-52
# Downloading: http://example.webscraping.com/places/default/view/Comoros-51
# Downloading: http://example.webscraping.com/places/default/view/Colombia-50
# Downloading: http://example.webscraping.com/places/default/view/Cocos-Islands-49
# Downloading: http://example.webscraping.com/places/default/view/Christmas-Island-48
# Downloading: http://example.webscraping.com/places/default/view/China-47
# Downloading: http://example.webscraping.com/places/default/view/Chile-46
# Downloading: http://example.webscraping.com/places/default/view/Chad-45
# Downloading: http://example.webscraping.com/places/default/view/Central-African-Republic-44
# Downloading: http://example.webscraping.com/places/default/view/Cayman-Islands-43
# Downloading: http://example.webscraping.com/places/default/view/Cape-Verde-42
# Downloading: http://example.webscraping.com/places/default/view/Canada-41
# Downloading: http://example.webscraping.com/places/default/view/Cameroon-40
# Downloading: http://example.webscraping.com/places/default/view/Cambodia-39
# Downloading: http://example.webscraping.com/places/default/view/Burundi-38
# Downloading: http://example.webscraping.com/places/default/view/Burkina-Faso-37
# Downloading: http://example.webscraping.com/places/default/view/Bulgaria-36
# Downloading: http://example.webscraping.com/places/default/view/Brunei-35
# Downloading: http://example.webscraping.com/places/default/view/British-Virgin-Islands-34
# Downloading: http://example.webscraping.com/places/default/view/British-Indian-Ocean-Territory-33
# Downloading: http://example.webscraping.com/places/default/view/Brazil-32
# Downloading: http://example.webscraping.com/places/default/view/Bouvet-Island-31
# Downloading: http://example.webscraping.com/places/default/view/Botswana-30
# Downloading: http://example.webscraping.com/places/default/view/Bosnia-and-Herzegovina-29
# Downloading: http://example.webscraping.com/places/default/view/Bonaire-Saint-Eustatius-and-Saba-28
# Downloading: http://example.webscraping.com/places/default/view/Bolivia-27
# Downloading: http://example.webscraping.com/places/default/view/Bhutan-26
# Downloading: http://example.webscraping.com/places/default/view/Bermuda-25
# Downloading: http://example.webscraping.com/places/default/view/Benin-24
# Downloading: http://example.webscraping.com/places/default/view/Belize-23
# Downloading: http://example.webscraping.com/places/default/view/Belgium-22
# Downloading: http://example.webscraping.com/places/default/view/Belarus-21
# Downloading: http://example.webscraping.com/places/default/index/0
# Downloading: http://example.webscraping.com/places/default/view/Barbados-20
# Downloading: http://example.webscraping.com/places/default/view/Bangladesh-19
# Downloading: http://example.webscraping.com/places/default/view/Bahrain-18
# Downloading: http://example.webscraping.com/places/default/view/Bahamas-17
# Downloading: http://example.webscraping.com/places/default/view/Azerbaijan-16
# Downloading: http://example.webscraping.com/places/default/view/Austria-15
# Downloading: http://example.webscraping.com/places/default/view/Australia-14
# Downloading: http://example.webscraping.com/places/default/view/Aruba-13
# Downloading: http://example.webscraping.com/places/default/view/Armenia-12
# Downloading: http://example.webscraping.com/places/default/view/Argentina-11
# Downloading: http://example.webscraping.com/places/default/view/Antigua-and-Barbuda-10
# Downloading: http://example.webscraping.com/places/default/view/Antarctica-9
# Downloading: http://example.webscraping.com/places/default/view/Anguilla-8
# Downloading: http://example.webscraping.com/places/default/view/Angola-7
# Downloading: http://example.webscraping.com/places/default/view/Andorra-6
# Downloading: http://example.webscraping.com/places/default/view/American-Samoa-5
# Downloading: http://example.webscraping.com/places/default/view/Algeria-4
# Downloading: http://example.webscraping.com/places/default/view/Albania-3
# Downloading: http://example.webscraping.com/places/default/view/Aland-Islands-2
# Downloading: http://example.webscraping.com/places/default/view/Afghanistan-1
# Downloading: http://example.webscraping.com/places/default/index

# %%
import re


url = 'http://example.webscraping.com/places/default/view/Australia-1'
re.sub('[^/0-9a-zA-Z\-.,; _]', '_', url)
# Out:
# 'http_//example.webscraping.com/places/default/view/Australia-1'

# %%
filename = 'http_//example.webscraping.com/places/default/view/Australia-1'
filename.split('/')
# Out:
# ['http_',
#  '',
#  'example.webscraping.com',
#  'places',
#  'default',
#  'view',
#  'Australia-1']

# %%
for segment in filename.split('/'):
    print(segment)
# Out:
# http_
#
# example.webscraping.com
# places
# default
# view
# Australia-1

# %%
segment[:255] for segment in filename.split('/')
# Out:
#   File "<ipython-input-6-2073b4879b1b>", line 1
#     segment[:255] for segment in filename.split('/')
#                     ^
# SyntaxError: invalid syntax

# %%
s = [segment[:255] for segment in filename.split('/')]

# %%
print(s)
# Out:
# ['http_', '', 'example.webscraping.com', 'places', 'default', 'view', 'Australia-1']

# %%
from urllib.parse import urlsplit


components = urlsplit('http://example.webscraping.com/index/')
print(components)
print(components.path)
path = components.path
if not path:
    path = '/index.html'
elif path.endswith('/'):
    path += 'index.html'
filename = components.netloc + path + components.query
print(filename)
# Out:
# SplitResult(scheme='http', netloc='example.webscraping.com', path='/index/', query='', fragment='')
# /index/
# example.webscraping.com/index/index.html

# %%
import os
import re
import urllib.parse


class DiskCache:
    def __init__(self, cache_dir='cache'):
        self.cache_dir = cache_dir
        self.max_length = max_length

    def url_to_path(self, url):
        """Create file system path for this URL
        """
        components = urllib.parse.urlsplit(url)
        # append index.html to empty paths
        path = components.path
        if not path:
            path = '/index.html'
        elif path.endswith('/'):
            path += 'index.html'
        filename = components.netloc + path + components.query
        # replace invalid characters
        filename = re.sub('[^/0-9a-zA-Z\-.,; _]', '_', filename)
        # restric maximum number of characters
        filename = '/'.join(segment[:255] for segment in filename.split('/'))
        return os.path.join(self.cache_dir, filename)
